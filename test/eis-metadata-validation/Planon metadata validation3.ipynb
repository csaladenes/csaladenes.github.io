# %% [markdown]
# # EIS metadata validation script
# Used to validate Planon output with spreadsheet input

# %% [markdown]
# ## 1. Data import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read data. There are two datasets: Planon and Master. The latter is the EIS data nomencalture that was created. Master is made up of two subsets: loggers and meters. Loggers are sometimes called controllers and meters are sometimes called sensors. In rare cases meters or sensors are also called channels.

# %%
planon=pd.read_excel('Data Loggers.xlsx',index_col = 'Code')
master_loggerscontrollers = pd.read_csv('LoggersControllers.csv', index_col = 'Asset Code')
master_meterssensors = pd.read_csv('MetersSensors.csv', encoding = 'macroman', index_col = 'Asset Code')

# %% [markdown]
# Unify index, caps everything and strip of trailing spaces.

# %%
planon.index=[str(i).upper().strip() for i in planon.index]
master_loggerscontrollers.index=[str(i).upper().strip() for i in master_loggerscontrollers.index]
master_meterssensors.index=[str(i).upper().strip() for i in master_meterssensors.index]

# %% [markdown]
# Drop duplicates (shouldn't be any)

# %%
planon.drop_duplicates(inplace=True)
master_loggerscontrollers.drop_duplicates(inplace=True)
master_meterssensors.drop_duplicates(inplace=True)

# %% [markdown]
# Split Planon import into loggers and meters
# Drop duplicates (shouldn't be any)

# %%
# Split the Planon file into 2, one for loggers & controllers, and one for meters & sensors.
planon_loggerscontrollers = planon.loc[(planon['Classification Group'] == 'EN.EN4 BMS Controller') | (planon['Classification Group'] == 'EN.EN1 Data Logger')]
planon_meterssensors = planon.loc[(planon['Classification Group'] == 'EN.EN2 Energy Meter') | (planon['Classification Group'] == 'EN.EN3 Energy Sensor')]
planon_loggerscontrollers.drop_duplicates(inplace=True)
planon_meterssensors.drop_duplicates(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Index unique? show number of duplicates in index

# %%
len(planon_loggerscontrollers.index[planon_loggerscontrollers.index.duplicated()])
# Out:
# 0

# %%
len(planon_meterssensors.index[planon_meterssensors.index.duplicated()])
# Out:
# 538

# %% [markdown]
# Meters are not unique. This is becasue of the spaces served. This is ok for now, we will deal with duplicates at the comparison stage. Same is true for loggers - in the unlikely event that there are duplicates in the future.

# %%
planon_meterssensors.head(3)
# Out:
#                BuildingNo.      Building Locations.Space.Space number  \
# MC046-L08/M001       MC046  Bowland Main                          NaN
# MC046-L08/M001       MC046  Bowland Main                          D80
# MC046-L08/M001       MC046  Bowland Main                          D81
#
#                Space Name  Additional Location Info           Description  \
# MC046-L08/M001        NaN                       NaN  Bowland Main Flat 15
# MC046-L08/M001      Lobby                       NaN  Bowland Main Flat 15
# MC046-L08/M001          .                       NaN  Bowland Main Flat 15
#
#                Classification Group  Record  HVAC Ref  Element Description  \
# MC046-L08/M001  EN.EN2 Energy Meter     NaN       NaN                  NaN
# MC046-L08/M001  EN.EN2 Energy Meter     NaN       NaN                  NaN
# MC046-L08/M001  EN.EN2 Energy Meter     NaN       NaN                  NaN
#
#                       ...          Logger MAC Address Logger SIM  \
# MC046-L08/M001        ...                         NaN        NaN
# MC046-L08/M001        ...                         NaN        NaN
# MC046-L08/M001        ...                         NaN        NaN
#
#                Meter Pulse Value Meter Units  Meter Capacity  \
# MC046-L08/M001               NaN         NaN             NaN
# MC046-L08/M001               NaN         NaN             NaN
# MC046-L08/M001               NaN         NaN             NaN
#
#                 Network Point ID  Tenant Meter.Name  Fiscal Meter.Name  \
# MC046-L08/M001               NaN                 No                 No
# MC046-L08/M001               NaN                 No                 No
# MC046-L08/M001               NaN                 No                 No
#
#                 EIS Space.Space number  Utility Type.Name
# MC046-L08/M001                     NaN                NaN
# MC046-L08/M001                     NaN                NaN
# MC046-L08/M001                     NaN                NaN
#
# [3 rows x 29 columns]

# %% [markdown]
# ## 2. Validation

# %% [markdown]
# Create list of all buildings present in Planon export. These are buildings to check the data against from Master.

# %%
buildings=set(planon_meterssensors['BuildingNo.'])
buildings
# Out:
# {'MC046', 'MC063', 'MC071'}

# %% [markdown]
# ### 2.1. Meters

# %% [markdown]
# Create dataframe slice for validation from `master_meterssensors` where the only the buildings located in `buildings` are contained. Save this new slice into `master_meterssensors_for_validation`. This is done by creating sub-slices of the dataframe for each building, then concatenating them all together.

# %%
master_meterssensors_for_validation = \
    pd.concat([master_meterssensors.loc[master_meterssensors['Building Code'] == building] \
           for building in buildings])
master_meterssensors_for_validation.head(2)
# Out:
#                                    Logger Asset Code    Description Make  \
# MC063-B01/C1  {54561EAD-15A2-4A32-9DAC-ECD49A2F7506}  Virtual CNC 1  NaN
# MC063-B01/D1  {54561EAD-15A2-4A32-9DAC-ECD49A2F7506}   VT Pump 1 En  NaN
#
#              Model Meter Units  Meter Pulse Value Classification Group  \
# MC063-B01/C1   NaN         NaN                NaN        Energy sensor
# MC063-B01/D1   NaN         NaN                NaN        Energy sensor
#
#              Logger Channel Utility Type  ??         ...           \
# MC063-B01/C1             C1          NaN NaN         ...
# MC063-B01/D1             D1          NaN NaN         ...
#
#               Building Code    Building Name Space Additional Location Info  \
# MC063-B01/C1          MC063  Slaidburn House   NaN                      NaN
# MC063-B01/D1          MC063  Slaidburn House   NaN                      NaN
#
#              Tenant meter  Fiscal meter  Parent meter Child meters  \
# MC063-B01/C1          0.0           0.0           NaN          NaN
# MC063-B01/D1          0.0           0.0           NaN          NaN
#
#               Communications type  Electrical panel ID
# MC063-B01/C1                  NaN                  NaN
# MC063-B01/D1                  NaN                  NaN
#
# [2 rows x 21 columns]

# %%
#alternative method
master_meterssensors_for_validation2 = \
    master_meterssensors[master_meterssensors['Building Code'].isin(buildings)]
master_meterssensors_for_validation2.head(2)
# Out:
#                                    Logger Asset Code            Description  \
# MC071-B01/C1  {B9940A04-170E-4DBA-A49A-27721AC37F8B}          Virtual CNC 1
# MC071-B01/D1  {B9940A04-170E-4DBA-A49A-27721AC37F8B}  PHX No1 Control Valve
#
#              Make Model Meter Units  Meter Pulse Value Classification Group  \
# MC071-B01/C1  NaN   NaN         NaN                NaN        Energy sensor
# MC071-B01/D1  NaN   NaN         NaN                NaN        Energy sensor
#
#              Logger Channel Utility Type  ??         ...           \
# MC071-B01/C1             C1          NaN NaN         ...
# MC071-B01/D1             D1          NaN NaN         ...
#
#               Building Code    Building Name Space Additional Location Info  \
# MC071-B01/C1          MC071  Furness College   NaN                      NaN
# MC071-B01/D1          MC071  Furness College   NaN                      NaN
#
#              Tenant meter  Fiscal meter  Parent meter Child meters  \
# MC071-B01/C1          0.0           0.0           NaN          NaN
# MC071-B01/D1          0.0           0.0           NaN          NaN
#
#               Communications type  Electrical panel ID
# MC071-B01/C1                  NaN                  NaN
# MC071-B01/D1                  NaN                  NaN
#
# [2 rows x 21 columns]

# %% [markdown]
# Planon sensors are not unique because of the spaces served convention in the two data architectures. The Planon architecture devotes a new line for each space served - hence the not unique index. The Master architecture lists all the spaces only once, as a list, therefore it has a unique index. We will need to take this into account and create matching dataframe out of planon for comparison, with a unique index.

# %%
len(master_meterssensors_for_validation)
# Out:
# 1401

# %%
len(planon_meterssensors)-len(planon_meterssensors.index[planon_meterssensors.index.duplicated()])
# Out:
# 1354

# %% [markdown]
# Sort datasets after index for easier comparison.

# %%
master_meterssensors_for_validation.sort_index(inplace=True)
planon_meterssensors.sort_index(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# #### 2.1.1 Slicing of meters to  only certain columns of comparison

# %%
planon_meterssensors.T
# Out:
#                                              MC046-B01/A1  \
# BuildingNo.                                         MC046
# Building                                     Bowland Main
# Locations.Space.Space number                          NaN
# Space Name                                            NaN
# Additional Location Info                              NaN
# Description                   Learning Zone - Zone 1 Temp
# Classification Group                 EN.EN3 Energy Sensor
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                                 NaN
# Make                                                  NaN
# EIS ID                                                 A1
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                                     NaN
# Logger Serial Number                                  NaN
# Logger MAC Address                                    NaN
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                      No
# Fiscal Meter.Name                                      No
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
#
#                                        MC046-B01/A101  \
# BuildingNo.                                     MC046
# Building                                 Bowland Main
# Locations.Space.Space number                      NaN
# Space Name                                        NaN
# Additional Location Info                          NaN
# Description                   Outside air temperature
# Classification Group             EN.EN3 Energy Sensor
# Record                                            NaN
# HVAC Ref                                          NaN
# Element Description                               NaN
# Servicable Area                                   NaN
# Model                                             NaN
# Make                                              NaN
# EIS ID                                           A101
# Logger Channel                                      0
# Logger Upstream Comms Target                      NaN
# Logger Modem Serial Number                        NaN
# Logger IP Address                                 NaN
# Logger Serial Number                              NaN
# Logger MAC Address                                NaN
# Logger SIM                                        NaN
# Meter Pulse Value                                 NaN
# Meter Units                                       NaN
# Meter Capacity                                    NaN
# Network Point ID                                  NaN
# Tenant Meter.Name                                  No
# Fiscal Meter.Name                                  No
# EIS Space.Space number                            NaN
# Utility Type.Name                                 NaN
#
#                                              MC046-B01/A2  \
# BuildingNo.                                         MC046
# Building                                     Bowland Main
# Locations.Space.Space number                          NaN
# Space Name                                            NaN
# Additional Location Info                              NaN
# Description                   Learning Zone - Zone 2 Temp
# Classification Group                 EN.EN3 Energy Sensor
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                                 NaN
# Make                                                  NaN
# EIS ID                                                 A2
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                                     NaN
# Logger Serial Number                                  NaN
# Logger MAC Address                                    NaN
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                      No
# Fiscal Meter.Name                                      No
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
#
#                                              MC046-B01/A3  \
# BuildingNo.                                         MC046
# Building                                     Bowland Main
# Locations.Space.Space number                          NaN
# Space Name                                            NaN
# Additional Location Info                              NaN
# Description                   Learning Zone - Zone 3 Temp
# Classification Group                 EN.EN3 Energy Sensor
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                                 NaN
# Make                                                  NaN
# EIS ID                                                 A3
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                                     NaN
# Logger Serial Number                                  NaN
# Logger MAC Address                                    NaN
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                      No
# Fiscal Meter.Name                                      No
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
#
#                                       MC046-B01/C1         MC046-B01/D10  \
# BuildingNo.                                  MC046                 MC046
# Building                              Bowland Main          Bowland Main
# Locations.Space.Space number                   NaN                   NaN
# Space Name                                     NaN                   NaN
# Additional Location Info                       NaN                   NaN
# Description                          Virtual CNC 1       Office VT valve
# Classification Group          EN.EN3 Energy Sensor  EN.EN3 Energy Sensor
# Record                                         NaN                   NaN
# HVAC Ref                                       NaN                   NaN
# Element Description                            NaN                   NaN
# Servicable Area                                NaN                   NaN
# Model                                          NaN                   NaN
# Make                                           NaN                   NaN
# EIS ID                                          C1                   D10
# Logger Channel                                   0                     0
# Logger Upstream Comms Target                   NaN                   NaN
# Logger Modem Serial Number                     NaN                   NaN
# Logger IP Address                              NaN                   NaN
# Logger Serial Number                           NaN                   NaN
# Logger MAC Address                             NaN                   NaN
# Logger SIM                                     NaN                   NaN
# Meter Pulse Value                              NaN                   NaN
# Meter Units                                    NaN                   NaN
# Meter Capacity                                 NaN                   NaN
# Network Point ID                               NaN                   NaN
# Tenant Meter.Name                               No                    No
# Fiscal Meter.Name                               No                    No
# EIS Space.Space number                         NaN                   NaN
# Utility Type.Name                              NaN                   NaN
#
#                                      MC046-B01/D11         MC046-B01/D12  \
# BuildingNo.                                  MC046                 MC046
# Building                              Bowland Main          Bowland Main
# Locations.Space.Space number                   NaN                   NaN
# Space Name                                     NaN                   NaN
# Additional Location Info                       NaN                   NaN
# Description                          P3 Enable 2RM         P4 Enable 2RM
# Classification Group          EN.EN3 Energy Sensor  EN.EN3 Energy Sensor
# Record                                         NaN                   NaN
# HVAC Ref                                       NaN                   NaN
# Element Description                            NaN                   NaN
# Servicable Area                                NaN                   NaN
# Model                                          NaN                   NaN
# Make                                           NaN                   NaN
# EIS ID                                         D11                   D12
# Logger Channel                                   0                     0
# Logger Upstream Comms Target                   NaN                   NaN
# Logger Modem Serial Number                     NaN                   NaN
# Logger IP Address                              NaN                   NaN
# Logger Serial Number                           NaN                   NaN
# Logger MAC Address                             NaN                   NaN
# Logger SIM                                     NaN                   NaN
# Meter Pulse Value                              NaN                   NaN
# Meter Units                                    NaN                   NaN
# Meter Capacity                                 NaN                   NaN
# Network Point ID                               NaN                   NaN
# Tenant Meter.Name                               No                    No
# Fiscal Meter.Name                               No                    No
# EIS Space.Space number                         NaN                   NaN
# Utility Type.Name                              NaN                   NaN
#
#                                      MC046-B01/D13         MC046-B01/D14  \
# BuildingNo.                                  MC046                 MC046
# Building                              Bowland Main          Bowland Main
# Locations.Space.Space number                   NaN                   NaN
# Space Name                                     NaN                   NaN
# Additional Location Info                       NaN                   NaN
# Description                        DHW Systems 4RM   DHW 1 system 4-20Ma
# Classification Group          EN.EN3 Energy Sensor  EN.EN3 Energy Sensor
# Record                                         NaN                   NaN
# HVAC Ref                                       NaN                   NaN
# Element Description                            NaN                   NaN
# Servicable Area                                NaN                   NaN
# Model                                          NaN                   NaN
# Make                                           NaN                   NaN
# EIS ID                                         D13                   D14
# Logger Channel                                   0                     0
# Logger Upstream Comms Target                   NaN                   NaN
# Logger Modem Serial Number                     NaN                   NaN
# Logger IP Address                              NaN                   NaN
# Logger Serial Number                           NaN                   NaN
# Logger MAC Address                             NaN                   NaN
# Logger SIM                                     NaN                   NaN
# Meter Pulse Value                              NaN                   NaN
# Meter Units                                    NaN                   NaN
# Meter Capacity                                 NaN                   NaN
# Network Point ID                               NaN                   NaN
# Tenant Meter.Name                               No                    No
# Fiscal Meter.Name                               No                    No
# EIS Space.Space number                         NaN                   NaN
# Utility Type.Name                              NaN                   NaN
#
#                                      ...                MC071-L15/M003  \
# BuildingNo.                          ...                         MC071
# Building                             ...               Furness College
# Locations.Space.Space number         ...                            A0
# Space Name                           ...                Whole Building
# Additional Location Info             ...                           NaN
# Description                          ...               Furness College
# Classification Group                 ...           EN.EN2 Energy Meter
# Record                               ...                           NaN
# HVAC Ref                             ...                           NaN
# Element Description                  ...                           NaN
# Servicable Area                      ...                           NaN
# Model                                ...                           NaN
# Make                                 ...                           NaN
# EIS ID                               ...                             3
# Logger Channel                       ...                             0
# Logger Upstream Comms Target         ...                           NaN
# Logger Modem Serial Number           ...                           NaN
# Logger IP Address                    ...                           NaN
# Logger Serial Number                 ...                           NaN
# Logger MAC Address                   ...                           NaN
# Logger SIM                           ...                           NaN
# Meter Pulse Value                    ...                           NaN
# Meter Units                          ...                           NaN
# Meter Capacity                       ...                           NaN
# Network Point ID                     ...                           NaN
# Tenant Meter.Name                    ...                            No
# Fiscal Meter.Name                    ...                            No
# EIS Space.Space number               ...                           NaN
# Utility Type.Name                    ...                           NaN
#
#                                    MC071-L15/M004       MC071-L15/M004  \
# BuildingNo.                                 MC071                MC071
# Building                          Furness College      Furness College
# Locations.Space.Space number                   A0                  NaN
# Space Name                         Whole Building                  NaN
# Additional Location Info                      NaN                  NaN
# Description                       Furness College      Furness College
# Classification Group          EN.EN2 Energy Meter  EN.EN2 Energy Meter
# Record                                        NaN                  NaN
# HVAC Ref                                      NaN                  NaN
# Element Description                           NaN                  NaN
# Servicable Area                               NaN                  NaN
# Model                                         NaN                  NaN
# Make                                          NaN                  NaN
# EIS ID                                          4                    4
# Logger Channel                                  0                    0
# Logger Upstream Comms Target                  NaN                  NaN
# Logger Modem Serial Number                    NaN                  NaN
# Logger IP Address                             NaN                  NaN
# Logger Serial Number                          NaN                  NaN
# Logger MAC Address                            NaN                  NaN
# Logger SIM                                    NaN                  NaN
# Meter Pulse Value                             NaN                  NaN
# Meter Units                                   NaN                  NaN
# Meter Capacity                                NaN                  NaN
# Network Point ID                              NaN                  NaN
# Tenant Meter.Name                              No                   No
# Fiscal Meter.Name                              No                   No
# EIS Space.Space number                        NaN                  NaN
# Utility Type.Name                             NaN                  NaN
#
#                                                 MC071-L15/M005  \
# BuildingNo.                                              MC071
# Building                                       Furness College
# Locations.Space.Space number                                A0
# Space Name                                      Whole Building
# Additional Location Info                                   NaN
# Description                   Furness College Immersion heater
# Classification Group                       EN.EN2 Energy Meter
# Record                                                     NaN
# HVAC Ref                                                   NaN
# Element Description                                        NaN
# Servicable Area                                            NaN
# Model                                                      NaN
# Make                                                       NaN
# EIS ID                                                       5
# Logger Channel                                               0
# Logger Upstream Comms Target                               NaN
# Logger Modem Serial Number                                 NaN
# Logger IP Address                                          NaN
# Logger Serial Number                                       NaN
# Logger MAC Address                                         NaN
# Logger SIM                                                 NaN
# Meter Pulse Value                                          NaN
# Meter Units                                                NaN
# Meter Capacity                                             NaN
# Network Point ID                                           NaN
# Tenant Meter.Name                                           No
# Fiscal Meter.Name                                           No
# EIS Space.Space number                                     NaN
# Utility Type.Name                                          NaN
#
#                                                 MC071-L15/M005  \
# BuildingNo.                                              MC071
# Building                                       Furness College
# Locations.Space.Space number                               NaN
# Space Name                                                 NaN
# Additional Location Info                                   NaN
# Description                   Furness College Immersion heater
# Classification Group                       EN.EN2 Energy Meter
# Record                                                     NaN
# HVAC Ref                                                   NaN
# Element Description                                        NaN
# Servicable Area                                            NaN
# Model                                                      NaN
# Make                                                       NaN
# EIS ID                                                       5
# Logger Channel                                               0
# Logger Upstream Comms Target                               NaN
# Logger Modem Serial Number                                 NaN
# Logger IP Address                                          NaN
# Logger Serial Number                                       NaN
# Logger MAC Address                                         NaN
# Logger SIM                                                 NaN
# Meter Pulse Value                                          NaN
# Meter Units                                                NaN
# Meter Capacity                                             NaN
# Network Point ID                                           NaN
# Tenant Meter.Name                                           No
# Fiscal Meter.Name                                           No
# EIS Space.Space number                                     NaN
# Utility Type.Name                                          NaN
#
#                                    MC071-L16/M001       MC071-L16/M002  \
# BuildingNo.                                 MC071                MC071
# Building                          Furness College      Furness College
# Locations.Space.Space number                  NaN                  NaN
# Space Name                                    NaN                  NaN
# Additional Location Info                      NaN                  NaN
# Description                        Santander Bank                  NaN
# Classification Group          EN.EN2 Energy Meter  EN.EN2 Energy Meter
# Record                                        NaN                  NaN
# HVAC Ref                                      NaN                  NaN
# Element Description                           NaN                  NaN
# Servicable Area                               NaN                  NaN
# Model                                         NaN                  NaN
# Make                                          NaN                  NaN
# EIS ID                                          1                    2
# Logger Channel                                  0                    0
# Logger Upstream Comms Target                  NaN                  NaN
# Logger Modem Serial Number                    NaN                  NaN
# Logger IP Address                             NaN                  NaN
# Logger Serial Number                          NaN                  NaN
# Logger MAC Address                            NaN                  NaN
# Logger SIM                                    NaN                  NaN
# Meter Pulse Value                             NaN                  NaN
# Meter Units                                   NaN                  NaN
# Meter Capacity                                NaN                  NaN
# Network Point ID                              NaN                  NaN
# Tenant Meter.Name                             Yes                  Yes
# Fiscal Meter.Name                              No                   No
# EIS Space.Space number                        NaN                  NaN
# Utility Type.Name                             NaN                  NaN
#
#                                    MC071-L17/M001       MC071-L17/M002  \
# BuildingNo.                                 MC071                MC071
# Building                          Furness College      Furness College
# Locations.Space.Space number                  NaN                  NaN
# Space Name                                    NaN                  NaN
# Additional Location Info                      NaN                  NaN
# Description                           LUSU Living                  NOK
# Classification Group          EN.EN2 Energy Meter  EN.EN2 Energy Meter
# Record                                        NaN                  NaN
# HVAC Ref                                      NaN                  NaN
# Element Description                           NaN                  NaN
# Servicable Area                               NaN                  NaN
# Model                                         NaN                  NaN
# Make                                          NaN                  NaN
# EIS ID                                          1                    2
# Logger Channel                                  0                    0
# Logger Upstream Comms Target                  NaN                  NaN
# Logger Modem Serial Number                    NaN                  NaN
# Logger IP Address                             NaN                  NaN
# Logger Serial Number                          NaN                  NaN
# Logger MAC Address                            NaN                  NaN
# Logger SIM                                    NaN                  NaN
# Meter Pulse Value                             NaN                  NaN
# Meter Units                                   NaN                  NaN
# Meter Capacity                                NaN                  NaN
# Network Point ID                              NaN                  NaN
# Tenant Meter.Name                             Yes                  Yes
# Fiscal Meter.Name                              No                   No
# EIS Space.Space number                        NaN                  NaN
# Utility Type.Name                             NaN                  NaN
#
#                                    MC071-L17/M003
# BuildingNo.                                 MC071
# Building                          Furness College
# Locations.Space.Space number                  NaN
# Space Name                                    NaN
# Additional Location Info                      NaN
# Description                           LUSU Living
# Classification Group          EN.EN2 Energy Meter
# Record                                        NaN
# HVAC Ref                                      NaN
# Element Description                           NaN
# Servicable Area                               NaN
# Model                                         NaN
# Make                                          NaN
# EIS ID                                          3
# Logger Channel                                  0
# Logger Upstream Comms Target                  NaN
# Logger Modem Serial Number                    NaN
# Logger IP Address                             NaN
# Logger Serial Number                          NaN
# Logger MAC Address                            NaN
# Logger SIM                                    NaN
# Meter Pulse Value                             NaN
# Meter Units                                   NaN
# Meter Capacity                                NaN
# Network Point ID                              NaN
# Tenant Meter.Name                             Yes
# Fiscal Meter.Name                              No
# EIS Space.Space number                        NaN
# Utility Type.Name                             NaN
#
# [29 rows x 1892 columns]

# %%
master_meterssensors_for_validation.T
# Out:
#                                                     MC046-B01/A1  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                          Learning Zone - Zone 1 Temp
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                      Degrees Celsius
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                                A1
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                   MC046-B01/A101  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                              Outside air temperature
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                      Degrees Celsius
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                              A101
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                     MC046-B01/A2  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                          Learning Zone - Zone 2 Temp
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                      Degrees Celsius
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                                A2
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                     MC046-B01/A3  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                          Learning Zone - Zone 3 Temp
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                      Degrees Celsius
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                                A3
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                     MC046-B01/C1  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                                        Virtual CNC 1
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                                  NaN
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                                C1
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                    MC046-B01/D10  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                                      Office VT valve
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                                  NaN
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                               D10
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                    MC046-B01/D11  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                                        P3 Enable 2RM
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                                  NaN
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                               D11
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                    MC046-B01/D12  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                                        P4 Enable 2RM
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                                  NaN
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                               D12
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                    MC046-B01/D13  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                                      DHW Systems 4RM
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                                  NaN
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                               D13
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                                    MC046-B01/D14  \
# Logger Asset Code         {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Description                                  DHW 1 system 4-20Ma
# Make                                                         NaN
# Model                                                        NaN
# Meter Units                                                  NaN
# Meter Pulse Value                                            NaN
# Classification Group                               Energy sensor
# Logger Channel                                               D14
# Utility Type                                                 NaN
# ??                                                           NaN
# Meter Type                                                   NaN
# Building Code                                              MC046
# Building Name                                       Bowland Main
# Space                                                        NaN
# Additional Location Info                                     NaN
# Tenant meter                                                   0
# Fiscal meter                                                   0
# Parent meter                                                 NaN
# Child meters                                                 NaN
# Communications type                                          NaN
# Electrical panel ID                                          NaN
#
#                                           ...                   \
# Logger Asset Code                         ...
# Description                               ...
# Make                                      ...
# Model                                     ...
# Meter Units                               ...
# Meter Pulse Value                         ...
# Classification Group                      ...
# Logger Channel                            ...
# Utility Type                              ...
# ??                                        ...
# Meter Type                                ...
# Building Code                             ...
# Building Name                             ...
# Space                                     ...
# Additional Location Info                  ...
# Tenant meter                              ...
# Fiscal meter                              ...
# Parent meter                              ...
# Child meters                              ...
# Communications type                       ...
# Electrical panel ID                       ...
#
#                                       NAN                   NAN           NAN  \
# Logger Asset Code                     NaN                   NaN           NaN
# Description                           NaN                   NaN      DB C1 NW
# Make                              Danfoss  BU.G.I (meters) Ltd.           NaN
# Model                           INFOCAL 8                608819           NaN
# Meter Units                           NaN                   NaN           NaN
# Meter Pulse Value                     NaN                   NaN           NaN
# Classification Group         Energy meter          Energy meter  Energy meter
# Logger Channel                        NaN                   NaN           NaN
# Utility Type                          DH            Natural Gas   Electricity
# ??                                    NaN                   NaN           NaN
# Meter Type                            NaN                   NaN           NaN
# Building Code                       MC071                 MC046         MC046
# Building Name             Furness College          Bowland Main  Bowland Main
# Space                                 NaN                   NaN           NaN
# Additional Location Info             A006  Bt6 Store (Basement)           NaN
# Tenant meter                            0                     0             0
# Fiscal meter                            0                     0             0
# Parent meter                          NaN                   NaN           NaN
# Child meters                          NaN                   NaN           NaN
# Communications type                   NaN                   NaN           NaN
# Electrical panel ID                   NaN                   NaN           NaN
#
#                                    NAN           NAN           NAN  \
# Logger Asset Code                  NaN           NaN           NaN
# Description                   DB C2 NW      DB B1 NW      DB B2 NW
# Make                               NaN         Selec         Selec
# Model                              NaN       MFM 384       MFM 384
# Meter Units                        NaN           NaN           NaN
# Meter Pulse Value                  NaN           NaN           NaN
# Classification Group      Energy meter  Energy meter  Energy meter
# Logger Channel                     NaN           NaN           NaN
# Utility Type               Electricity   Electricity   Electricity
# ??                                 NaN           NaN           NaN
# Meter Type                         NaN           NaN           NaN
# Building Code                    MC046         MC046         MC046
# Building Name             Bowland Main  Bowland Main  Bowland Main
# Space                              NaN           NaN           NaN
# Additional Location Info           NaN        B01.r1        B01.r1
# Tenant meter                         0             0             0
# Fiscal meter                         0             0             0
# Parent meter                       NaN           NaN           NaN
# Child meters                       NaN           NaN           NaN
# Communications type                NaN           NaN           NaN
# Electrical panel ID                NaN           NaN           NaN
#
#                                    NAN           NAN              NAN  \
# Logger Asset Code                  NaN           NaN     0501987F8800
# Description                  Landlords        Flat 1   LUSU - Housing
# Make                             Selec      Ri Meter              NaN
# Model                           MFM384        CT-2EA              NaN
# Meter Units                        NaN           NaN              NaN
# Meter Pulse Value                  NaN           NaN              NaN
# Classification Group      Energy meter  Energy meter     Energy meter
# Logger Channel                     NaN           NaN                1
# Utility Type               Electricity   Electricity              NaN
# ??                                 NaN           NaN              NaN
# Meter Type                         NaN           NaN              NaN
# Building Code                    MC046         MC046            MC071
# Building Name             Bowland Main  Bowland Main  Furness College
# Space                              NaN           NaN              NaN
# Additional Location Info        D03.r1        D03.r1              NaN
# Tenant meter                         0             0                1
# Fiscal meter                         0             0                0
# Parent meter                       NaN           NaN              NaN
# Child meters                       NaN           NaN              NaN
# Communications type                NaN           NaN              NaN
# Electrical panel ID                NaN           NaN              NaN
#
#                                                            NAN
# Logger Asset Code                                          NaN
# Description                                                NaN
# Make                                                       NaN
# Model                                                      NaN
# Meter Units                                                NaN
# Meter Pulse Value                                          NaN
# Classification Group                              Energy meter
# Logger Channel                                             NaN
# Utility Type                                             Water
# ??                                                         NaN
# Meter Type                                                 NaN
# Building Code                                            MC071
# Building Name                                  Furness College
# Space                                                      NaN
# Additional Location Info  Furness College LG  PL02, Plant room
# Tenant meter                                                 0
# Fiscal meter                                                 0
# Parent meter                                               NaN
# Child meters                                               NaN
# Communications type                                        NaN
# Electrical panel ID                                        NaN
#
# [21 rows x 1401 columns]

# %% [markdown]
# Create dictionary that maps Planon column names onto Master.
#
# From Nicola:
# - Code (Asset Code)
# - Description
# - EIS ID (Channel)
# - Utility Type
# - Fiscal Meter
# - Tenant Meter
#
# `Building code` and `Building name` are implicitly included. `Logger Serial Number`, `IP` or `MAC` would be essential to include, as well as `Make` and `Model`. `Additional Location Info` is not essnetial but would be useful to have. Locations (`Locations.Space.Space number` and `Space Name`) are included in the Planon export - but this is their only viable data source, therefore are not validated against.

# %%
#Planon:Master
meters_match_dict={
      "BuildingNo.":"Building Code",
      "Building":"Building Name",
      "Description":"Description",
      "EIS ID":"Logger Channel",
      "Tenant Meter.Name":"Tenant meter",
      "Fiscal Meter.Name":"Fiscal meter"
      }

# %% [markdown]
# Filter both dataframes based on these new columns. Then remove duplicates. Currently, this leads to loss of information of spaces served, but also a unique index for the Planon dataframe, therefore bringing the dataframes closer to each other. When including spaces explicitly in the comparison (if we want to - or just trust the  Planon space mapping), this needs to be modified.

# %%
master_meterssensors_for_validation_filtered=master_meterssensors_for_validation[list(meters_match_dict.values())]
planon_meterssensors_filtered=planon_meterssensors[list(meters_match_dict.keys())]

# %%
master_meterssensors_for_validation_filtered.head(2)
# Out:
#                Building Code Building Name                  Description  \
# MC046-B01/A1           MC046  Bowland Main  Learning Zone - Zone 1 Temp
# MC046-B01/A101         MC046  Bowland Main      Outside air temperature
#
#                Logger Channel  Tenant meter  Fiscal meter
# MC046-B01/A1               A1           0.0           0.0
# MC046-B01/A101           A101           0.0           0.0

# %%
planon_meterssensors_filtered.head(2)
# Out:
#                BuildingNo.      Building                  Description EIS ID  \
# MC046-B01/A1         MC046  Bowland Main  Learning Zone - Zone 1 Temp     A1
# MC046-B01/A101       MC046  Bowland Main      Outside air temperature   A101
#
#                Tenant Meter.Name Fiscal Meter.Name
# MC046-B01/A1                  No                No
# MC046-B01/A101                No                No

# %% [markdown]
# Unify headers, drop duplicates (bear the mind the spaces argument, this where it needs to be brought back in in the future!).

# %%
planon_meterssensors_filtered.columns=[meters_match_dict[i] for i in planon_meterssensors_filtered]

# %%
planon_meterssensors_filtered.drop_duplicates(inplace=True)
master_meterssensors_for_validation_filtered.drop_duplicates(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
planon_meterssensors_filtered.head(2)
# Out:
#                Building Code Building Name                  Description  \
# MC046-B01/A1           MC046  Bowland Main  Learning Zone - Zone 1 Temp
# MC046-B01/A101         MC046  Bowland Main      Outside air temperature
#
#                Logger Channel Tenant meter Fiscal meter
# MC046-B01/A1               A1           No           No
# MC046-B01/A101           A101           No           No

# %% [markdown]
# Fiscal/Tenant meter name needs fixing from Yes/No and 1/0.

# %%
planon_meterssensors_filtered['Fiscal meter']=planon_meterssensors_filtered['Fiscal meter'].isin(['Yes'])
planon_meterssensors_filtered['Tenant meter']=planon_meterssensors_filtered['Tenant meter'].isin(['Yes'])
master_meterssensors_for_validation_filtered['Fiscal meter']=master_meterssensors_for_validation_filtered['Fiscal meter'].isin([1])
master_meterssensors_for_validation_filtered['Tenant meter']=master_meterssensors_for_validation_filtered['Tenant meter'].isin([1])
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
master_meterssensors_for_validation_filtered.head(2)
# Out:
#                Building Code Building Name                  Description  \
# MC046-B01/A1           MC046  Bowland Main  Learning Zone - Zone 1 Temp
# MC046-B01/A101         MC046  Bowland Main      Outside air temperature
#
#                Logger Channel  Tenant meter  Fiscal meter
# MC046-B01/A1               A1         False         False
# MC046-B01/A101           A101         False         False

# %%
planon_meterssensors_filtered.head(2)
# Out:
#                Building Code Building Name                  Description  \
# MC046-B01/A1           MC046  Bowland Main  Learning Zone - Zone 1 Temp
# MC046-B01/A101         MC046  Bowland Main      Outside air temperature
#
#                Logger Channel  Tenant meter  Fiscal meter
# MC046-B01/A1               A1         False         False
# MC046-B01/A101           A101         False         False

# %% [markdown]
# Cross-check missing meters

# %%
a=np.sort(list(set(planon_meterssensors_filtered.index)))
b=np.sort(list(set(master_meterssensors_for_validation_filtered.index)))
meterssensors_not_in_planon=[]
for i in b:
    if i not in a:
        print(i+',',end=" "),
        meterssensors_not_in_planon.append(i)
print('\n\nMeters in Master, but not in Planon:',
      len(meterssensors_not_in_planon),'/',len(b),':',
      round(len(meterssensors_not_in_planon)/len(b)*100,3),'%')
# Out:
# MC046-L07/M001, MC046-L07/M002, MC046-L07/M003, MC071-L08/M001, MC071-L08/M004, NAN,
#
# Meters in Master, but not in Planon: 6 / 1352 : 0.444 %

# %%
a=np.sort(list(set(planon_meterssensors_filtered.index)))
b=np.sort(list(set(master_meterssensors_for_validation_filtered.index)))
meterssensors_not_in_master=[]
for i in a:
    if i not in b:
        print(i+',',end=" "),
        meterssensors_not_in_master.append(i)
print('\n\nMeters in Planon, not in Master:',
      len(meterssensors_not_in_master),'/',len(a),':',
      round(len(meterssensors_not_in_master)/len(a)*100,3),'%')
# Out:
# MC046-L08/M001, MC046-L08/M002, MC046-L08/M003, MC071-L09/M001, MC071-L09/M004,
#
# Meters in Planon, not in Master: 5 / 1351 : 0.37 %

# %% [markdown]
# Check for duplicates in index, but not duplicates over the entire row

# %%
print(len(planon_meterssensors_filtered.index))
print(len(set(planon_meterssensors_filtered.index)))
print(len(master_meterssensors_for_validation_filtered.index))
print(len(set(master_meterssensors_for_validation_filtered.index)))
# Out:
# 1351
# 1351
# 1391
# 1352

# %%
master_meterssensors_for_validation_filtered[master_meterssensors_for_validation_filtered.index.duplicated()]
# Out:
#              Building Code    Building Name                    Description  \
# MC046-B01/I1         MC046     Bowland Main                    Mod 1 - 8Ao
# MC046-B01/I2         MC046     Bowland Main           Pressurisation Unit
# MC046-B01/I3         MC046     Bowland Main                    Mod 3 - 8Ao
# MC046-B01/I4         MC046     Bowland Main                    Mod 4 - 8Ui
# MC046-B01/I5         MC046     Bowland Main                    Mod 5 - 8Ui
# MC046-B01/I6         MC046     Bowland Main                  Cal 1 18kw On
# MC046-B01/I7         MC046     Bowland Main                  Cal 2   45KW
# MC046-B01/I8         MC046     Bowland Main                 P1 Flow switch
# MC046-B01/O1         MC046     Bowland Main                  Alarm Route 1
# MC046-B01/O2         MC046     Bowland Main                        Heating
# MC046-B01/O3         MC046     Bowland Main           Optimum Start Stop 3
# MC063-B01/I1         MC063  Slaidburn House              Fire alarm active
# MC063-B01/I2         MC063  Slaidburn House        Shower Fans North Fault
# MC063-B01/I3         MC063  Slaidburn House                       Module 3
# MC071-B01/I1         MC071  Furness College                  16DI_Module 1
# MC071-B01/I2         MC071  Furness College                   8UI_Module 2
# MC071-B01/I3         MC071  Furness College                   8AO_Module 3
# MC071-B01/I4         MC071  Furness College  Toilet Extract Fan B013 Fault
# MC071-B01/I5         MC071  Furness College                   8DO_Module 1
# MC071-B01/I6         MC071  Furness College                4UI4AO_Module 6
# MC071-B01/I7         MC071  Furness College  Toilet Extract Fan B070 Fault
# MC071-B01/I8         MC071  Furness College                4UI4AO_Module 8
# MC071-B01/N1         MC071  Furness College                     IC Comms 1
# MC071-B01/O1         MC071  Furness College                  Alarm Route 1
# NAN                  MC071  Furness College                  Adj. DB Board
# NAN                  MC071  Furness College                     A5 Furness
# NAN                  MC046     Bowland Main                         Flat 2
# NAN                  MC046     Bowland Main                         Flat 3
# NAN                  MC063  Slaidburn House                 Slaidburn Main
# NAN                  MC063  Slaidburn House      Slaidburn House Hot Water
# NAN                  MC071  Furness College                            NaN
# NAN                  MC046     Bowland Main                            NaN
# NAN                  MC046     Bowland Main                       DB C1 NW
# NAN                  MC046     Bowland Main                       DB C2 NW
# NAN                  MC046     Bowland Main                       DB B1 NW
# NAN                  MC046     Bowland Main                       DB B2 NW
# NAN                  MC046     Bowland Main                      Landlords
# NAN                  MC046     Bowland Main                         Flat 1
# NAN                  MC071  Furness College                 LUSU - Housing
#
#              Logger Channel  Tenant meter  Fiscal meter
# MC046-B01/I1             i1         False         False
# MC046-B01/I2             I2         False         False
# MC046-B01/I3             i3         False         False
# MC046-B01/I4             i4         False         False
# MC046-B01/I5             i5         False         False
# MC046-B01/I6             I6         False         False
# MC046-B01/I7             I7         False         False
# MC046-B01/I8             I8         False         False
# MC046-B01/O1             o1         False         False
# MC046-B01/O2             O2         False         False
# MC046-B01/O3             O3         False         False
# MC063-B01/I1             I1         False         False
# MC063-B01/I2             I2         False         False
# MC063-B01/I3             i3         False         False
# MC071-B01/I1             i1         False         False
# MC071-B01/I2             i2         False         False
# MC071-B01/I3             i3         False         False
# MC071-B01/I4             I4         False         False
# MC071-B01/I5             i5         False         False
# MC071-B01/I6             i6         False         False
# MC071-B01/I7             I7         False         False
# MC071-B01/I8             i8         False         False
# MC071-B01/N1             N1         False         False
# MC071-B01/O1             o1         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                       1         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                     NaN         False         False
# NAN                       1          True         False

# %% [markdown]
# The duplicates are the `nan`s. Remove these for now. Could revisit later to do an index-less comparison, only over row contents.

# %%
good_index=[i for i in master_meterssensors_for_validation_filtered.index if str(i).lower().strip()!='nan']
master_meterssensors_for_validation_filtered=master_meterssensors_for_validation_filtered.loc[good_index]
master_meterssensors_for_validation_filtered.drop_duplicates(inplace=True)

# %%
len(planon_meterssensors_filtered)
# Out:
# 1351

# %%
len(master_meterssensors_for_validation_filtered)
# Out:
# 1375

# %% [markdown]
# Do comparison only on common indices. Need to revisit and identify the cause missing meters, both ways (5 Planon->Meters and 30 Meters->Planon in this example).

# %%
comon_index=list(set(master_meterssensors_for_validation_filtered.index).intersection(set(planon_meterssensors_filtered.index)))

# %%
len(comon_index)
# Out:
# 1346

# %%
master_meterssensors_for_validation_intersected=master_meterssensors_for_validation_filtered.loc[comon_index].sort_index()
planon_meterssensors_intersected=planon_meterssensors_filtered.loc[comon_index].sort_index()

# %%
len(master_meterssensors_for_validation_intersected)
# Out:
# 1370

# %%
len(planon_meterssensors_intersected)
# Out:
# 1346

# %% [markdown]
# Still have duplicate indices. For now we just drop and keep the first.

# %%
master_meterssensors_for_validation_intersected = master_meterssensors_for_validation_intersected[~master_meterssensors_for_validation_intersected.index.duplicated(keep='first')]

# %%
master_meterssensors_for_validation_intersected.head(2)
# Out:
#                Building Code Building Name                  Description  \
# MC046-B01/A1           MC046  Bowland Main  Learning Zone - Zone 1 Temp
# MC046-B01/A101         MC046  Bowland Main      Outside air temperature
#
#                Logger Channel  Tenant meter  Fiscal meter
# MC046-B01/A1               A1         False         False
# MC046-B01/A101           A101         False         False

# %%
planon_meterssensors_intersected.head(2)
# Out:
#                Building Code Building Name                  Description  \
# MC046-B01/A1           MC046  Bowland Main  Learning Zone - Zone 1 Temp
# MC046-B01/A101         MC046  Bowland Main      Outside air temperature
#
#                Logger Channel  Tenant meter  Fiscal meter
# MC046-B01/A1               A1         False         False
# MC046-B01/A101           A101         False         False

# %% [markdown]
# #### 2.1.2. Primitive comparison

# %%
planon_meterssensors_intersected==master_meterssensors_for_validation_intersected
# Out:
#                 Building Code  Building Name  Description  Logger Channel  \
# MC046-B01/A1             True           True         True            True
# MC046-B01/A101           True           True         True            True
# MC046-B01/A2             True           True         True            True
# MC046-B01/A3             True           True         True            True
# MC046-B01/C1             True           True         True            True
# MC046-B01/D10            True           True         True            True
# MC046-B01/D11            True           True         True            True
# MC046-B01/D12            True           True         True            True
# MC046-B01/D13            True           True         True            True
# MC046-B01/D14            True           True         True            True
# MC046-B01/D15            True           True         True            True
# MC046-B01/D16            True           True         True            True
# MC046-B01/D17            True           True         True            True
# MC046-B01/D18            True           True         True            True
# MC046-B01/D19            True           True         True            True
# MC046-B01/D20            True           True         True            True
# MC046-B01/D21            True           True         True            True
# MC046-B01/D22            True           True         True            True
# MC046-B01/D23            True           True         True            True
# MC046-B01/D24            True           True         True            True
# MC046-B01/D25            True           True         True            True
# MC046-B01/D26            True           True         True            True
# MC046-B01/D27            True           True         True            True
# MC046-B01/D28            True           True         True            True
# MC046-B01/D29            True           True         True            True
# MC046-B01/D30            True           True         True            True
# MC046-B01/D31            True           True         True            True
# MC046-B01/D6             True           True         True            True
# MC046-B01/D7             True           True         True            True
# MC046-B01/D8             True           True         True            True
# ...                       ...            ...          ...             ...
# MC071-L10/M008           True           True         True           False
# MC071-L11/M001           True           True         True           False
# MC071-L11/M002           True           True         True           False
# MC071-L11/M003           True           True         True           False
# MC071-L11/M004           True           True         True           False
# MC071-L11/M005           True           True         True           False
# MC071-L11/M006           True           True         True           False
# MC071-L11/M007           True           True         True           False
# MC071-L11/M008           True           True         True           False
# MC071-L12/M001           True           True         True           False
# MC071-L12/M002           True           True         True           False
# MC071-L12/M003           True           True         True           False
# MC071-L12/M004           True           True         True           False
# MC071-L12/M005           True           True         True           False
# MC071-L12/M006           True           True         True           False
# MC071-L12/M007           True           True         True           False
# MC071-L12/M008           True           True         True           False
# MC071-L14/M001           True           True         True           False
# MC071-L14/M002           True           True         True           False
# MC071-L14/M003           True           True         True           False
# MC071-L15/M001           True           True         True           False
# MC071-L15/M002           True           True         True           False
# MC071-L15/M003           True           True         True           False
# MC071-L15/M004           True           True         True           False
# MC071-L15/M005           True           True         True           False
# MC071-L16/M001           True           True         True           False
# MC071-L16/M002           True           True        False           False
# MC071-L17/M001           True           True         True           False
# MC071-L17/M002           True           True         True           False
# MC071-L17/M003           True           True         True           False
#
#                 Tenant meter  Fiscal meter
# MC046-B01/A1            True          True
# MC046-B01/A101          True          True
# MC046-B01/A2            True          True
# MC046-B01/A3            True          True
# MC046-B01/C1            True          True
# MC046-B01/D10           True          True
# MC046-B01/D11           True          True
# MC046-B01/D12           True          True
# MC046-B01/D13           True          True
# MC046-B01/D14           True          True
# MC046-B01/D15           True          True
# MC046-B01/D16           True          True
# MC046-B01/D17           True          True
# MC046-B01/D18           True          True
# MC046-B01/D19           True          True
# MC046-B01/D20           True          True
# MC046-B01/D21           True          True
# MC046-B01/D22           True          True
# MC046-B01/D23           True          True
# MC046-B01/D24           True          True
# MC046-B01/D25           True          True
# MC046-B01/D26           True          True
# MC046-B01/D27           True          True
# MC046-B01/D28           True          True
# MC046-B01/D29           True          True
# MC046-B01/D30           True          True
# MC046-B01/D31           True          True
# MC046-B01/D6            True          True
# MC046-B01/D7            True          True
# MC046-B01/D8            True          True
# ...                      ...           ...
# MC071-L10/M008          True          True
# MC071-L11/M001          True          True
# MC071-L11/M002          True          True
# MC071-L11/M003          True          True
# MC071-L11/M004          True          True
# MC071-L11/M005          True          True
# MC071-L11/M006          True          True
# MC071-L11/M007          True          True
# MC071-L11/M008          True          True
# MC071-L12/M001          True          True
# MC071-L12/M002          True          True
# MC071-L12/M003          True          True
# MC071-L12/M004          True          True
# MC071-L12/M005          True          True
# MC071-L12/M006          True          True
# MC071-L12/M007          True          True
# MC071-L12/M008          True          True
# MC071-L14/M001          True          True
# MC071-L14/M002          True          True
# MC071-L14/M003          True          True
# MC071-L15/M001          True          True
# MC071-L15/M002          True          True
# MC071-L15/M003          True          True
# MC071-L15/M004          True          True
# MC071-L15/M005          True          True
# MC071-L16/M001          True          True
# MC071-L16/M002          True          True
# MC071-L17/M001          True          True
# MC071-L17/M002          True          True
# MC071-L17/M003          True          True
#
# [1346 rows x 6 columns]

# %%
np.all(planon_meterssensors_intersected==master_meterssensors_for_validation_intersected)
# Out:
# False

# %% [markdown]
# #### 2.1.3. Horizontal comparison

# %% [markdown]
# Number of cells matching

# %%
(planon_meterssensors_intersected==master_meterssensors_for_validation_intersected).sum()
# Out:
# Building Code     1346
# Building Name     1346
# Description       1309
# Logger Channel    1157
# Tenant meter      1346
# Fiscal meter      1346
# dtype: int64

# %% [markdown]
# Percentage matching

# %%
(planon_meterssensors_intersected==master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100
# Out:
# Building Code     100.000000
# Building Name     100.000000
# Description        97.251114
# Logger Channel     85.958395
# Tenant meter      100.000000
# Fiscal meter      100.000000
# dtype: float64

# %%
((planon_meterssensors_intersected==master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100).plot(kind='bar')

# %% [markdown]
# #### 2.1.4. Vertical comparison

# %%
df=pd.DataFrame((planon_meterssensors_intersected.T==master_meterssensors_for_validation_intersected.T).sum())
df
# Out:
#                 0
# MC046-B01/A1    6
# MC046-B01/A101  6
# MC046-B01/A2    6
# MC046-B01/A3    6
# MC046-B01/C1    6
# MC046-B01/D10   6
# MC046-B01/D11   6
# MC046-B01/D12   6
# MC046-B01/D13   6
# MC046-B01/D14   6
# MC046-B01/D15   6
# MC046-B01/D16   6
# MC046-B01/D17   6
# MC046-B01/D18   6
# MC046-B01/D19   6
# MC046-B01/D20   6
# MC046-B01/D21   6
# MC046-B01/D22   6
# MC046-B01/D23   6
# MC046-B01/D24   6
# MC046-B01/D25   6
# MC046-B01/D26   6
# MC046-B01/D27   6
# MC046-B01/D28   6
# MC046-B01/D29   6
# MC046-B01/D30   6
# MC046-B01/D31   6
# MC046-B01/D6    6
# MC046-B01/D7    6
# MC046-B01/D8    6
# ...            ..
# MC071-L10/M008  5
# MC071-L11/M001  5
# MC071-L11/M002  5
# MC071-L11/M003  5
# MC071-L11/M004  5
# MC071-L11/M005  5
# MC071-L11/M006  5
# MC071-L11/M007  5
# MC071-L11/M008  5
# MC071-L12/M001  5
# MC071-L12/M002  5
# MC071-L12/M003  5
# MC071-L12/M004  5
# MC071-L12/M005  5
# MC071-L12/M006  5
# MC071-L12/M007  5
# MC071-L12/M008  5
# MC071-L14/M001  5
# MC071-L14/M002  5
# MC071-L14/M003  5
# MC071-L15/M001  5
# MC071-L15/M002  5
# MC071-L15/M003  5
# MC071-L15/M004  5
# MC071-L15/M005  5
# MC071-L16/M001  5
# MC071-L16/M002  4
# MC071-L17/M001  5
# MC071-L17/M002  5
# MC071-L17/M003  5
#
# [1346 rows x 1 columns]

# %%
df=pd.DataFrame((planon_meterssensors_intersected.T==master_meterssensors_for_validation_intersected.T).sum()/\
len(planon_meterssensors_intersected.T)*100)
df[df[0]<100]
# Out:
#                         0
# MC046-B01/F48   83.333333
# MC046-B01/F49   83.333333
# MC046-B01/F50   83.333333
# MC046-B01/F51   83.333333
# MC046-B01/I1    83.333333
# MC046-B01/I2    83.333333
# MC046-B01/I25   83.333333
# MC046-B01/I29   83.333333
# MC046-B01/I3    83.333333
# MC046-B01/I4    83.333333
# MC046-B01/I49   83.333333
# MC046-B01/I5    83.333333
# MC046-B01/I55   83.333333
# MC046-B01/I6    83.333333
# MC046-B01/I7    83.333333
# MC046-B01/I8    83.333333
# MC046-B01/K37   83.333333
# MC046-B01/O1    83.333333
# MC046-B01/O2    83.333333
# MC046-B01/O3    83.333333
# MC046-B01/V1    83.333333
# MC046-L02/M001  83.333333
# MC046-L02/M002  83.333333
# MC046-L02/M003  83.333333
# MC046-L02/M004  83.333333
# MC046-L02/M005  83.333333
# MC046-L02/M006  83.333333
# MC046-L02/M007  83.333333
# MC046-L05/M001  83.333333
# MC046-L05/M002  83.333333
# ...                   ...
# MC071-L10/M008  83.333333
# MC071-L11/M001  83.333333
# MC071-L11/M002  83.333333
# MC071-L11/M003  83.333333
# MC071-L11/M004  83.333333
# MC071-L11/M005  83.333333
# MC071-L11/M006  83.333333
# MC071-L11/M007  83.333333
# MC071-L11/M008  83.333333
# MC071-L12/M001  83.333333
# MC071-L12/M002  83.333333
# MC071-L12/M003  83.333333
# MC071-L12/M004  83.333333
# MC071-L12/M005  83.333333
# MC071-L12/M006  83.333333
# MC071-L12/M007  83.333333
# MC071-L12/M008  83.333333
# MC071-L14/M001  83.333333
# MC071-L14/M002  83.333333
# MC071-L14/M003  83.333333
# MC071-L15/M001  83.333333
# MC071-L15/M002  83.333333
# MC071-L15/M003  83.333333
# MC071-L15/M004  83.333333
# MC071-L15/M005  83.333333
# MC071-L16/M001  83.333333
# MC071-L16/M002  66.666667
# MC071-L17/M001  83.333333
# MC071-L17/M002  83.333333
# MC071-L17/M003  83.333333
#
# [218 rows x 1 columns]

# %%
df[df[0]<100].plot(kind='bar')

# %% [markdown]
# #### 2.1.5. Smart(er) comparison

# %% [markdown]
# Not all of the dataframe matches. Let us do some basic string formatting, maybe that helps.

# %%
sum(planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description'])
# Out:
# 37

# %%
planon_meterssensors_intersected['Description']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in planon_meterssensors_intersected['Description'].values]
master_meterssensors_for_validation_intersected['Description']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in master_meterssensors_for_validation_intersected['Description'].values]

# %%
sum(planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description'])
# Out:
# 17

# %% [markdown]
# Some errors fixed, some left. Let's see which ones. These are either:
# - Wrong duplicate dropped
# - Input human erros in the description.
# - Actual erros somewhere in the indexing.

# %%
for i in planon_meterssensors_intersected[planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description']].index:
    print(i,'\t\tPlanon:',planon_meterssensors_intersected.loc[i]['Description'],'\t\tMaster:',master_meterssensors_for_validation_intersected.loc[i]['Description'])
# Out:
# MC046-B01/I4 		Planon: mod 4 - 8ui 		Master: p1 b fault
# MC046-B01/I7 		Planon: mod 7 - 4ui 		Master: cal 2  45kw
# MC046-B01/O1 		Planon: heating 		Master: alarm route 1
# MC046-B01/O2 		Planon: heating 		Master: alarm route 2
# MC046-B01/O3 		Planon: optimum start stop 3 		Master: alarm route 3
# MC063-B01/I3 		Planon: module 3 		Master: shower fans south fault
# MC063-B01/L2 		Planon: nan 		Master:
# MC063-B01/L3 		Planon: nan 		Master:
# MC063-B01/L4 		Planon: nan 		Master:
# MC071-B01/I1 		Planon: 16di_module 1 		Master: bar lossney hx03 fault
# MC071-B01/I2 		Planon: 8ui_module 2 		Master: bar lossney hx04 fault
# MC071-B01/I4 		Planon: toilet extract fan b013 fault 		Master: 4ao_module 4
# MC071-B01/I5 		Planon: 8do_module 1 		Master: toilet extract fan c068 fault
# MC071-B01/I6 		Planon: 4ui4ao_module 6 		Master: toilet extract fan c047 fault
# MC071-B01/I7 		Planon: toilet extract fan b070 fault 		Master: 8ui_module 7
# MC071-B01/I8 		Planon: 4ui4ao_module 8 		Master: eco hold off
# MC071-B01/O1 		Planon: alarm route 1 		Master: optimum start stop 1

# %% [markdown]
# Let us repeat the exercise for `Logger Channel`. Cross-validate, flag as highly likely error where both mismatch.

# %%
sum(planon_meterssensors_intersected['Logger Channel']!=master_meterssensors_for_validation_intersected['Logger Channel'])
# Out:
# 189

# %%
planon_meterssensors_intersected['Logger Channel']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in planon_meterssensors_intersected['Logger Channel'].values]
master_meterssensors_for_validation_intersected['Logger Channel']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in master_meterssensors_for_validation_intersected['Logger Channel'].values]

# %%
sum(planon_meterssensors_intersected['Logger Channel']!=master_meterssensors_for_validation_intersected['Logger Channel'])
# Out:
# 0

# %% [markdown]
# All errors fixed on logger channels.

# %%
for i in planon_meterssensors_intersected[planon_meterssensors_intersected['Logger Channel']!=master_meterssensors_for_validation_intersected['Logger Channel']].index:
    print(i,'\t\tPlanon:',planon_meterssensors_intersected.loc[i]['Logger Channel'],'\t\tMaster:',master_meterssensors_for_validation_intersected.loc[i]['Logger Channel'])

# %% [markdown]
# New error percentage:

# %%
(planon_meterssensors_intersected!=master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100
# Out:
# Building Code     0.000000
# Building Name     0.000000
# Description       1.263001
# Logger Channel    0.000000
# Tenant meter      0.000000
# Fiscal meter      0.000000
# dtype: float64

# %% [markdown]
# ### 2.2. Loggers

# %%
master_loggerscontrollers_for_validation = \
    pd.concat([master_loggerscontrollers.loc[master_loggerscontrollers['Building Code'] == building] \
           for building in buildings])
master_loggerscontrollers_for_validation.head(2)
# Out:
#           Building Code    Building Name       Space  \
# MC063-L01         MC063  Slaidburn House  Plant Room
# MC063-L02         MC063  Slaidburn House  Plant Room
#
#                             Description Classification Group     Make  \
# MC063-L01  Data logger: Slaidburn House          Data logger  Enercom
# MC063-L02  Data logger: Slaidburn House          Data logger  Enercom
#
#                  Model Logger Serial Number Logger Mac Address  \
# MC063-L01  Multilog G2         050198829500  00-50-C2-2C-3E-53
# MC063-L02  Multilog G2         0501E4369600                NaN
#
#           Logger Ip Address  Logger Modem Serial Number  Logger Sim  \
# MC063-L01      10.23.11.101                         NaN         NaN
# MC063-L02               NaN                         NaN         NaN
#
#            Network Point Id  Logger Upstream Comms Target  \
# MC063-L01               NaN                           NaN
# MC063-L02               NaN                           NaN
#
#           Additional Location Info
# MC063-L01               Plant Room
# MC063-L02               Plant Room

# %%
len(master_loggerscontrollers_for_validation)
# Out:
# 41

# %%
len(planon_loggerscontrollers)-len(planon_loggerscontrollers.index[planon_loggerscontrollers.index.duplicated()])
# Out:
# 36

# %%
master_loggerscontrollers_for_validation.sort_index(inplace=True)
planon_loggerscontrollers.sort_index(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
planon_loggerscontrollers.T
# Out:
#                                                          MC046-B01  \
# BuildingNo.                                                  MC046
# Building                                              Bowland Main
# Locations.Space.Space number                                   NaN
# Space Name                                                     NaN
# Additional Location Info                                       NaN
# Description                           BMS Controller: Bowland Main
# Classification Group                         EN.EN4 BMS Controller
# Record                                                         NaN
# HVAC Ref                                                       NaN
# Element Description                                            NaN
# Servicable Area                                                NaN
# Model                                                   IQ3xcite96
# Make                                                         Trend
# EIS ID                        8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2
# Logger Channel                                                   0
# Logger Upstream Comms Target                                   NaN
# Logger Modem Serial Number                                     NaN
# Logger IP Address                                              NaN
# Logger Serial Number                                           NaN
# Logger MAC Address                                             NaN
# Logger SIM                                                     NaN
# Meter Pulse Value                                              NaN
# Meter Units                                                    NaN
# Meter Capacity                                                 NaN
# Network Point ID                                               NaN
# Tenant Meter.Name                                              NaN
# Fiscal Meter.Name                                              NaN
# EIS Space.Space number                                         NaN
# Utility Type.Name                                              NaN
#
#                                               MC046-L02  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                         A0
# Space Name                               Whole Building
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     050200C7E200
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L05  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        Bt6
# Space Name                                   Plant Room
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                      50198895300
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L06  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        Bt6
# Space Name                                   Plant Room
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     050200C41100
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L07  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        D86
# Space Name                                        Lobby
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     0501E3889900
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L08  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        D86
# Space Name                                        Lobby
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     0501FD5E5F00
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L09  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        D64
# Space Name                                      Landing
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     050200BAC300
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L10  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        D64
# Space Name                                      Landing
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     050200DF6400
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L11  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        D17
# Space Name                                        Lobby
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     0501FD96E700
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                               MC046-L12  \
# BuildingNo.                                       MC046
# Building                                   Bowland Main
# Locations.Space.Space number                        D44
# Space Name                                        Lobby
# Additional Location Info                            NaN
# Description                   Data logger: Bowland Main
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                       Multilog G2
# Make                                            Enercom
# EIS ID                                     0501E3E79300
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
#
#                                                 ...                      \
# BuildingNo.                                     ...
# Building                                        ...
# Locations.Space.Space number                    ...
# Space Name                                      ...
# Additional Location Info                        ...
# Description                                     ...
# Classification Group                            ...
# Record                                          ...
# HVAC Ref                                        ...
# Element Description                             ...
# Servicable Area                                 ...
# Model                                           ...
# Make                                            ...
# EIS ID                                          ...
# Logger Channel                                  ...
# Logger Upstream Comms Target                    ...
# Logger Modem Serial Number                      ...
# Logger IP Address                               ...
# Logger Serial Number                            ...
# Logger MAC Address                              ...
# Logger SIM                                      ...
# Meter Pulse Value                               ...
# Meter Units                                     ...
# Meter Capacity                                  ...
# Network Point ID                                ...
# Tenant Meter.Name                               ...
# Fiscal Meter.Name                               ...
# EIS Space.Space number                          ...
# Utility Type.Name                               ...
#
#                                                  MC071-L08  \
# BuildingNo.                                          MC071
# Building                                   Furness College
# Locations.Space.Space number                            A0
# Space Name                                  Whole Building
# Additional Location Info                               NaN
# Description                   Data logger: Furness College
# Classification Group                    EN.EN1 Data Logger
# Record                                                 NaN
# HVAC Ref                                               NaN
# Element Description                                    NaN
# Servicable Area                                        NaN
# Model                                          Multilog G2
# Make                                               Enercom
# EIS ID                                        0502012BA000
# Logger Channel                                           0
# Logger Upstream Comms Target                           NaN
# Logger Modem Serial Number                             NaN
# Logger IP Address                                      NaN
# Logger Serial Number                                   NaN
# Logger MAC Address                                     NaN
# Logger SIM                                             NaN
# Meter Pulse Value                                      NaN
# Meter Units                                            NaN
# Meter Capacity                                         NaN
# Network Point ID                                       NaN
# Tenant Meter.Name                                      NaN
# Fiscal Meter.Name                                      NaN
# EIS Space.Space number                                 NaN
# Utility Type.Name                                      NaN
#
#                                                  MC071-L09  \
# BuildingNo.                                          MC071
# Building                                   Furness College
# Locations.Space.Space number                            A0
# Space Name                                  Whole Building
# Additional Location Info                               NaN
# Description                   Data logger: Furness College
# Classification Group                    EN.EN1 Data Logger
# Record                                                 NaN
# HVAC Ref                                               NaN
# Element Description                                    NaN
# Servicable Area                                        NaN
# Model                                          Multilog G2
# Make                                               Enercom
# EIS ID                                        0501F883F600
# Logger Channel                                           0
# Logger Upstream Comms Target                           NaN
# Logger Modem Serial Number                             NaN
# Logger IP Address                                      NaN
# Logger Serial Number                                   NaN
# Logger MAC Address                                     NaN
# Logger SIM                                             NaN
# Meter Pulse Value                                      NaN
# Meter Units                                            NaN
# Meter Capacity                                         NaN
# Network Point ID                                       NaN
# Tenant Meter.Name                                      NaN
# Fiscal Meter.Name                                      NaN
# EIS Space.Space number                                 NaN
# Utility Type.Name                                      NaN
#
#                                                  MC071-L10  \
# BuildingNo.                                          MC071
# Building                                   Furness College
# Locations.Space.Space number                            A0
# Space Name                                  Whole Building
# Additional Location Info                               NaN
# Description                   Data logger: Furness College
# Classification Group                    EN.EN1 Data Logger
# Record                                                 NaN
# HVAC Ref                                               NaN
# Element Description                                    NaN
# Servicable Area                                        NaN
# Model                                          Multilog G2
# Make                                               Enercom
# EIS ID                                        0501F9058600
# Logger Channel                                           0
# Logger Upstream Comms Target                           NaN
# Logger Modem Serial Number                             NaN
# Logger IP Address                                      NaN
# Logger Serial Number                                   NaN
# Logger MAC Address                                     NaN
# Logger SIM                                             NaN
# Meter Pulse Value                                      NaN
# Meter Units                                            NaN
# Meter Capacity                                         NaN
# Network Point ID                                       NaN
# Tenant Meter.Name                                      NaN
# Fiscal Meter.Name                                      NaN
# EIS Space.Space number                                 NaN
# Utility Type.Name                                      NaN
#
#                                                  MC071-L11  \
# BuildingNo.                                          MC071
# Building                                   Furness College
# Locations.Space.Space number                            A0
# Space Name                                  Whole Building
# Additional Location Info                               NaN
# Description                   Data logger: Furness College
# Classification Group                    EN.EN1 Data Logger
# Record                                                 NaN
# HVAC Ref                                               NaN
# Element Description                                    NaN
# Servicable Area                                        NaN
# Model                                          Multilog G2
# Make                                               Enercom
# EIS ID                                        0501F9076200
# Logger Channel                                           0
# Logger Upstream Comms Target                           NaN
# Logger Modem Serial Number                             NaN
# Logger IP Address                                      NaN
# Logger Serial Number                                   NaN
# Logger MAC Address                                     NaN
# Logger SIM                                             NaN
# Meter Pulse Value                                      NaN
# Meter Units                                            NaN
# Meter Capacity                                         NaN
# Network Point ID                                       NaN
# Tenant Meter.Name                                      NaN
# Fiscal Meter.Name                                      NaN
# EIS Space.Space number                                 NaN
# Utility Type.Name                                      NaN
#
#                                                  MC071-L12  \
# BuildingNo.                                          MC071
# Building                                   Furness College
# Locations.Space.Space number                          LG11
# Space Name                               Pizzetta Republic
# Additional Location Info                               NaN
# Description                   Data logger: Furness College
# Classification Group                    EN.EN1 Data Logger
# Record                                                 NaN
# HVAC Ref                                               NaN
# Element Description                                    NaN
# Servicable Area                                        NaN
# Model                                          Multilog G2
# Make                                               Enercom
# EIS ID                                        050157B41C00
# Logger Channel                                           0
# Logger Upstream Comms Target                           NaN
# Logger Modem Serial Number                             NaN
# Logger IP Address                                      NaN
# Logger Serial Number                                   NaN
# Logger MAC Address                                     NaN
# Logger SIM                                             NaN
# Meter Pulse Value                                      NaN
# Meter Units                                            NaN
# Meter Capacity                                         NaN
# Network Point ID                                       NaN
# Tenant Meter.Name                                      NaN
# Fiscal Meter.Name                                      NaN
# EIS Space.Space number                                 NaN
# Utility Type.Name                                      NaN
#
#                                                  MC071-L13  \
# BuildingNo.                                          MC071
# Building                                   Furness College
# Locations.Space.Space number                          LG11
# Space Name                               Pizzetta Republic
# Additional Location Info                               NaN
# Description                   Data logger: Furness College
# Classification Group                    EN.EN1 Data Logger
# Record                                                 NaN
# HVAC Ref                                               NaN
# Element Description                                    NaN
# Servicable Area                                        NaN
# Model                                          Multilog G2
# Make                                               Enercom
# EIS ID                                        05019891F000
# Logger Channel                                           0
# Logger Upstream Comms Target                           NaN
# Logger Modem Serial Number                             NaN
# Logger IP Address                                      NaN
# Logger Serial Number                                   NaN
# Logger MAC Address                                     NaN
# Logger SIM                                             NaN
# Meter Pulse Value                                      NaN
# Meter Units                                            NaN
# Meter Capacity                                         NaN
# Network Point ID                                       NaN
# Tenant Meter.Name                                      NaN
# Fiscal Meter.Name                                      NaN
# EIS Space.Space number                                 NaN
# Utility Type.Name                                      NaN
#
#                                                              MC071-L14  \
# BuildingNo.                                                      MC071
# Building                                               Furness College
# Locations.Space.Space number                                       NaN
# Space Name                                                         NaN
# Additional Location Info                                           NaN
# Description                   Data logger: Furness College - The Venue
# Classification Group                                EN.EN1 Data Logger
# Record                                                             NaN
# HVAC Ref                                                           NaN
# Element Description                                                NaN
# Servicable Area                                                    NaN
# Model                                                      Multilog G2
# Make                                                           Enercom
# EIS ID                                                    050157C16200
# Logger Channel                                                       0
# Logger Upstream Comms Target                                       NaN
# Logger Modem Serial Number                                         NaN
# Logger IP Address                                                  NaN
# Logger Serial Number                                               NaN
# Logger MAC Address                                                 NaN
# Logger SIM                                                         NaN
# Meter Pulse Value                                                  NaN
# Meter Units                                                        NaN
# Meter Capacity                                                     NaN
# Network Point ID                                                   NaN
# Tenant Meter.Name                                                  NaN
# Fiscal Meter.Name                                                  NaN
# EIS Space.Space number                                             NaN
# Utility Type.Name                                                  NaN
#
#                                                                     MC071-L15  \
# BuildingNo.                                                             MC071
# Building                                                      Furness College
# Locations.Space.Space number                                              PL2
# Space Name                                                    Substation No.4
# Additional Location Info                                                  NaN
# Description                   Data logger: Furness College - Sub Station No.4
# Classification Group                                       EN.EN1 Data Logger
# Record                                                                    NaN
# HVAC Ref                                                                  NaN
# Element Description                                                       NaN
# Servicable Area                                                           NaN
# Model                                                             Multilog G2
# Make                                                                  Enercom
# EIS ID                                                           050157AE6600
# Logger Channel                                                              0
# Logger Upstream Comms Target                                              NaN
# Logger Modem Serial Number                                                NaN
# Logger IP Address                                                         NaN
# Logger Serial Number                                                      NaN
# Logger MAC Address                                                        NaN
# Logger SIM                                                                NaN
# Meter Pulse Value                                                         NaN
# Meter Units                                                               NaN
# Meter Capacity                                                            NaN
# Network Point ID                                                          NaN
# Tenant Meter.Name                                                         NaN
# Fiscal Meter.Name                                                         NaN
# EIS Space.Space number                                                    NaN
# Utility Type.Name                                                         NaN
#
#                                                                MC071-L16  \
# BuildingNo.                                                        MC071
# Building                                                 Furness College
# Locations.Space.Space number                                        A048
# Space Name                                                   LUSU Living
# Additional Location Info                                             NaN
# Description                   Data logger: Furness College - LUVU Office
# Classification Group                                  EN.EN1 Data Logger
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                        Multilog G2
# Make                                                             Enercom
# EIS ID                                                       50198904000
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                                    NaN
# Logger Serial Number                                                 NaN
# Logger MAC Address                                                   NaN
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                          NaN
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                    NaN
# Fiscal Meter.Name                                                    NaN
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
#
#                                                               MC071-L17
# BuildingNo.                                                       MC071
# Building                                                Furness College
# Locations.Space.Space number                                        PL1
# Space Name                                                   Plant Room
# Additional Location Info                                            NaN
# Description                   Data logger: Furness College - Green Room
# Classification Group                                 EN.EN1 Data Logger
# Record                                                              NaN
# HVAC Ref                                                            NaN
# Element Description                                                 NaN
# Servicable Area                                                     NaN
# Model                                                       Multilog G2
# Make                                                            Enercom
# EIS ID                                                     050157AF8400
# Logger Channel                                                        0
# Logger Upstream Comms Target                                        NaN
# Logger Modem Serial Number                                          NaN
# Logger IP Address                                                   NaN
# Logger Serial Number                                                NaN
# Logger MAC Address                                                  NaN
# Logger SIM                                                          NaN
# Meter Pulse Value                                                   NaN
# Meter Units                                                         NaN
# Meter Capacity                                                      NaN
# Network Point ID                                                    NaN
# Tenant Meter.Name                                                   NaN
# Fiscal Meter.Name                                                   NaN
# EIS Space.Space number                                              NaN
# Utility Type.Name                                                   NaN
#
# [29 rows x 36 columns]

# %%
master_loggerscontrollers_for_validation.T
# Out:
#                                                            MC046-B01  \
# Building Code                                                  MC046
# Building Name                                           Bowland Main
# Space                                                            NaN
# Description                             BMS Controller: Bowland Main
# Classification Group                                  BMS controller
# Make                                                           Trend
# Model                                                     IQ3xcite96
# Logger Serial Number          {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}
# Logger Mac Address                                               NaN
# Logger Ip Address                            bo-bms01-bt6a.bms.local
# Logger Modem Serial Number                                       NaN
# Logger Sim                                                       NaN
# Network Point Id                                                 NaN
# Logger Upstream Comms Target                                     NaN
# Additional Location Info                                         NaN
#
#                                               MC046-L01  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               Bt6
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                                NaN
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                            NaN
#
#                                               MC046-L02  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                                A0
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                       050200C7E200
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                 Communal Areas
#
#                                               MC046-L03  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                                A0
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                                NaN
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info             Bowland Plant Room
#
#                                               MC046-L04  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               Bt6
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                                NaN
# Logger Mac Address                    00-50-C2-2C-3D-19
# Logger Ip Address                          10.23.13.103
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                     Mains Room
#
#                                               MC046-L05  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               Bt6
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                       050198895300
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info            Basement Plant Room
#
#                                               MC046-L06  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               Bt6
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                       050200C41100
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                    Switch Room
#
#                                               MC046-L07  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               D86
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                       0501E3889900
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                        Flat 16
#
#                                               MC046-L08  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               D86
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                       0501FD5E5F00
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                        Flat 16
#
#                                               MC046-L09  \
# Building Code                                     MC046
# Building Name                              Bowland Main
# Space                                               D64
# Description                   Data logger: Bowland Main
# Classification Group                        Data logger
# Make                                            Enercom
# Model                                       Multilog G2
# Logger Serial Number                       050200BAC300
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                        Flat 13
#
#                                                 ...                      \
# Building Code                                   ...
# Building Name                                   ...
# Space                                           ...
# Description                                     ...
# Classification Group                            ...
# Make                                            ...
# Model                                           ...
# Logger Serial Number                            ...
# Logger Mac Address                              ...
# Logger Ip Address                               ...
# Logger Modem Serial Number                      ...
# Logger Sim                                      ...
# Network Point Id                                ...
# Logger Upstream Comms Target                    ...
# Additional Location Info                        ...
#
#                                                  MC071-L08  \
# Building Code                                        MC071
# Building Name                              Furness College
# Space                                                   A0
# Description                   Data logger: Furness College
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                          0502012BA000
# Logger Mac Address                                     NaN
# Logger Ip Address                             10.23.10.207
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info                      Ground Floor
#
#                                                  MC071-L09  \
# Building Code                                        MC071
# Building Name                              Furness College
# Space                                                   A0
# Description                   Data logger: Furness College
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                          0501F883F600
# Logger Mac Address                                     NaN
# Logger Ip Address                             10.23.10.207
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info                      Ground Floor
#
#                                                  MC071-L10  \
# Building Code                                        MC071
# Building Name                              Furness College
# Space                                                   A0
# Description                   Data logger: Furness College
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                          0501F9058600
# Logger Mac Address                                     NaN
# Logger Ip Address                             10.23.10.207
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info                      Ground Floor
#
#                                                  MC071-L11  \
# Building Code                                        MC071
# Building Name                              Furness College
# Space                                                   A0
# Description                   Data logger: Furness College
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                          0501F9076200
# Logger Mac Address                                     NaN
# Logger Ip Address                              10.23.??.??
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info                              A017
#
#                                                  MC071-L12  \
# Building Code                                        MC071
# Building Name                              Furness College
# Space                                                 LG11
# Description                   Data logger: Furness College
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                          050157B41C00
# Logger Mac Address                                     NaN
# Logger Ip Address                                      NaN
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info                    Pizza Republic
#
#                                                  MC071-L13  \
# Building Code                                        MC071
# Building Name                              Furness College
# Space                                                 LG11
# Description                   Data logger: Furness College
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                          05019891F000
# Logger Mac Address                                     NaN
# Logger Ip Address                                      NaN
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info                    Pizza Republic
#
#                                                              MC071-L14  \
# Building Code                                                    MC071
# Building Name                                          Furness College
# Space                                                              NaN
# Description                   Data logger: Furness College - The Venue
# Classification Group                                       Data logger
# Make                                                           Enercom
# Model                                                      Multilog G2
# Logger Serial Number                                      050157C16200
# Logger Mac Address                                                 NaN
# Logger Ip Address                                                  NaN
# Logger Modem Serial Number                                         NaN
# Logger Sim                                                         NaN
# Network Point Id                                                   NaN
# Logger Upstream Comms Target                                       NaN
# Additional Location Info                                    Mains Room
#
#                                                                     MC071-L15  \
# Building Code                                                           MC071
# Building Name                                                 Furness College
# Space                                                                     PL2
# Description                   Data logger: Furness College - Sub Station No.4
# Classification Group                                              Data logger
# Make                                                                  Enercom
# Model                                                             Multilog G2
# Logger Serial Number                                             050157AE6600
# Logger Mac Address                                                        NaN
# Logger Ip Address                                                         NaN
# Logger Modem Serial Number                                                NaN
# Logger Sim                                                                NaN
# Network Point Id                                                          NaN
# Logger Upstream Comms Target                                              NaN
# Additional Location Info                                                  PR3
#
#                                                                MC071-L16  \
# Building Code                                                      MC071
# Building Name                                            Furness College
# Space                                                               A048
# Description                   Data logger: Furness College - LUVU Office
# Classification Group                                         Data logger
# Make                                                             Enercom
# Model                                                        Multilog G2
# Logger Serial Number                                        050198904000
# Logger Mac Address                                     00-50-C2-2C-3D-15
# Logger Ip Address                                             10.23.9.71
# Logger Modem Serial Number                                           NaN
# Logger Sim                                                           NaN
# Network Point Id                                                     NaN
# Logger Upstream Comms Target                                         NaN
# Additional Location Info                                     LUVU Office
#
#                                                               MC071-L17
# Building Code                                                     MC071
# Building Name                                           Furness College
# Space                                                               PL1
# Description                   Data logger: Furness College - Green Room
# Classification Group                                        Data logger
# Make                                                            Enercom
# Model                                                       Multilog G2
# Logger Serial Number                                       050157AF8400
# Logger Mac Address                                    00-50-C2-2C-3D-BF
# Logger Ip Address                                          10.23.10.202
# Logger Modem Serial Number                                          NaN
# Logger Sim                                                          NaN
# Network Point Id                                                    NaN
# Logger Upstream Comms Target                                        NaN
# Additional Location Info                                           A017
#
# [15 rows x 41 columns]

# %% [markdown]
# Create dictionary that maps Planon column names onto Master.
#
# From Nicola:
# - EIS ID (Serial Number)
# - Make
# - Model
# - Description
# - Code (Asset Code)
# - Building Code
#
# `Building code` and `Building name` are implicitly included. `Logger IP` or `MAC` would be essential to include, as well as `Make` and `Model`. `Additional Location Info` is not essnetial but would be useful to have. Locations (`Locations.Space.Space number` and `Space Name`) are included in the Planon export - but this is their only viable data source, therefore are not validated against.

# %%
#Planon:Master
loggers_match_dict={
      "BuildingNo.":"Building Code",
      "Building":"Building Name",
      "Description":"Description",
      "EIS ID":"Logger Serial Number",
      "Make":"Make",
      "Model":"Model"
      }

# %%
master_loggerscontrollers_for_validation_filtered=master_loggerscontrollers_for_validation[list(loggers_match_dict.values())]
planon_loggerscontrollers_filtered=planon_loggerscontrollers[list(loggers_match_dict.keys())]

# %%
master_loggerscontrollers_for_validation_filtered.head(2)
# Out:
#           Building Code Building Name                   Description  \
# MC046-B01         MC046  Bowland Main  BMS Controller: Bowland Main
# MC046-L01         MC046  Bowland Main     Data logger: Bowland Main
#
#                              Logger Serial Number     Make        Model
# MC046-B01  {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}    Trend   IQ3xcite96
# MC046-L01                                     NaN  Enercom  Multilog G2

# %%
planon_loggerscontrollers_filtered.head(2)
# Out:
#           BuildingNo.      Building                   Description  \
# MC046-B01       MC046  Bowland Main  BMS Controller: Bowland Main
# MC046-L02       MC046  Bowland Main     Data logger: Bowland Main
#
#                                          EIS ID     Make        Model
# MC046-B01  8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2    Trend   IQ3xcite96
# MC046-L02                          050200C7E200  Enercom  Multilog G2

# %%
planon_loggerscontrollers_filtered.columns=[loggers_match_dict[i] for i in planon_loggerscontrollers_filtered]

# %%
planon_loggerscontrollers_filtered.drop_duplicates(inplace=True)
master_loggerscontrollers_for_validation_filtered.drop_duplicates(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
planon_loggerscontrollers_filtered.head(2)
# Out:
#           Building Code Building Name                   Description  \
# MC046-B01         MC046  Bowland Main  BMS Controller: Bowland Main
# MC046-L02         MC046  Bowland Main     Data logger: Bowland Main
#
#                            Logger Serial Number     Make        Model
# MC046-B01  8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2    Trend   IQ3xcite96
# MC046-L02                          050200C7E200  Enercom  Multilog G2

# %%
master_loggerscontrollers_for_validation_filtered.head(2)
# Out:
#           Building Code Building Name                   Description  \
# MC046-B01         MC046  Bowland Main  BMS Controller: Bowland Main
# MC046-L01         MC046  Bowland Main     Data logger: Bowland Main
#
#                              Logger Serial Number     Make        Model
# MC046-B01  {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}    Trend   IQ3xcite96
# MC046-L01                                     NaN  Enercom  Multilog G2

# %%
a=np.sort(list(set(planon_loggerscontrollers_filtered.index)))
b=np.sort(list(set(master_loggerscontrollers_for_validation_filtered.index)))
loggerscontrollers_not_in_planon=[]
for i in b:
    if i not in a:
        print(i+',',end=" "),
        loggerscontrollers_not_in_planon.append(i)
print('\n\nMeters in Master, but not in Planon:',
      len(loggerscontrollers_not_in_planon),'/',len(b),':',
      round(len(loggerscontrollers_not_in_planon)/len(b)*100,3),'%')
# Out:
# MC046-L01, MC046-L19,
#
# Meters in Master, but not in Planon: 2 / 38 : 5.263 %

# %%
a=np.sort(list(set(planon_loggerscontrollers_filtered.index)))
b=np.sort(list(set(master_loggerscontrollers_for_validation_filtered.index)))
loggerscontrollers_not_in_master=[]
for i in a:
    if i not in b:
        print(i+',',end=" "),
        loggerscontrollers_not_in_master.append(i)
print('\n\nMeters in Planon, not in Master:',
      len(loggerscontrollers_not_in_master),'/',len(a),':',
      round(len(loggerscontrollers_not_in_master)/len(a)*100,3),'%')
# Out:
# Meters in Planon, not in Master: 0 / 36 : 0.0 %

# %%
print(len(planon_loggerscontrollers_filtered.index))
print(len(set(planon_loggerscontrollers_filtered.index)))
print(len(master_loggerscontrollers_for_validation_filtered.index))
print(len(set(master_loggerscontrollers_for_validation_filtered.index)))
# Out:
# 36
# 36
# 38
# 38

# %%
master_loggerscontrollers_for_validation_filtered[master_loggerscontrollers_for_validation_filtered.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Building Code, Building Name, Description, Logger Serial Number, Make, Model]
# Index: []

# %%
comon_index=list(set(master_loggerscontrollers_for_validation_filtered.index).intersection(set(planon_loggerscontrollers_filtered.index)))

# %%
master_loggerscontrollers_for_validation_intersected=master_loggerscontrollers_for_validation_filtered.loc[comon_index].sort_index()
planon_loggerscontrollers_intersected=planon_loggerscontrollers_filtered.loc[comon_index].sort_index()

# %%
master_loggerscontrollers_for_validation_intersected.head(2)
# Out:
#           Building Code Building Name                   Description  \
# MC046-B01         MC046  Bowland Main  BMS Controller: Bowland Main
# MC046-L02         MC046  Bowland Main     Data logger: Bowland Main
#
#                              Logger Serial Number     Make        Model
# MC046-B01  {8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2}    Trend   IQ3xcite96
# MC046-L02                            050200C7E200  Enercom  Multilog G2

# %%
planon_loggerscontrollers_intersected.head(2)
# Out:
#           Building Code Building Name                   Description  \
# MC046-B01         MC046  Bowland Main  BMS Controller: Bowland Main
# MC046-L02         MC046  Bowland Main     Data logger: Bowland Main
#
#                            Logger Serial Number     Make        Model
# MC046-B01  8AE84AB9-0098-468B-81FC-C5EDD0B0C0A2    Trend   IQ3xcite96
# MC046-L02                          050200C7E200  Enercom  Multilog G2

# %%
planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected
# Out:
#            Building Code  Building Name  Description  Logger Serial Number  \
# MC046-B01           True           True         True                 False
# MC046-L02           True           True         True                  True
# MC046-L05           True           True         True                 False
# MC046-L06           True           True         True                  True
# MC046-L07           True           True         True                  True
# MC046-L08           True           True         True                  True
# MC046-L09           True           True         True                  True
# MC046-L10           True           True         True                  True
# MC046-L11           True           True         True                  True
# MC046-L12           True           True         True                  True
# MC046-L13           True           True         True                  True
# MC046-L14           True           True         True                  True
# MC046-L15           True           True         True                  True
# MC046-L16           True           True         True                  True
# MC046-L17           True           True         True                  True
# MC063-B01           True           True         True                 False
# MC063-L01           True           True         True                 False
# MC063-L02           True           True         True                  True
# MC071-B01           True          False         True                 False
# MC071-L01           True           True         True                  True
# MC071-L02           True           True         True                 False
# MC071-L03           True           True         True                  True
# MC071-L04           True           True         True                  True
# MC071-L05           True           True         True                 False
# MC071-L06           True           True         True                  True
# MC071-L07           True           True         True                  True
# MC071-L08           True           True         True                  True
# MC071-L09           True           True         True                  True
# MC071-L10           True           True         True                  True
# MC071-L11           True           True         True                  True
# MC071-L12           True           True         True                  True
# MC071-L13           True           True         True                  True
# MC071-L14           True           True         True                  True
# MC071-L15           True           True         True                  True
# MC071-L16           True           True         True                 False
# MC071-L17           True           True         True                  True
#
#            Make  Model
# MC046-B01  True   True
# MC046-L02  True   True
# MC046-L05  True   True
# MC046-L06  True   True
# MC046-L07  True   True
# MC046-L08  True   True
# MC046-L09  True   True
# MC046-L10  True   True
# MC046-L11  True   True
# MC046-L12  True   True
# MC046-L13  True   True
# MC046-L14  True   True
# MC046-L15  True   True
# MC046-L16  True   True
# MC046-L17  True   True
# MC063-B01  True   True
# MC063-L01  True   True
# MC063-L02  True   True
# MC071-B01  True   True
# MC071-L01  True   True
# MC071-L02  True   True
# MC071-L03  True   True
# MC071-L04  True   True
# MC071-L05  True   True
# MC071-L06  True   True
# MC071-L07  True   True
# MC071-L08  True   True
# MC071-L09  True   True
# MC071-L10  True   True
# MC071-L11  True   True
# MC071-L12  True   True
# MC071-L13  True   True
# MC071-L14  True   True
# MC071-L15  True   True
# MC071-L16  True   True
# MC071-L17  True   True

# %% [markdown]
# Loggers matching

# %%
(planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected).sum()
# Out:
# Building Code           36
# Building Name           35
# Description             36
# Logger Serial Number    28
# Make                    36
# Model                   36
# dtype: int64

# %% [markdown]
# Percentage matching

# %%
(planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100
# Out:
# Building Code           100.000000
# Building Name            97.222222
# Description             100.000000
# Logger Serial Number     77.777778
# Make                    100.000000
# Model                   100.000000
# dtype: float64

# %%
((planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100).plot(kind='bar')

# %% [markdown]
# Loggers not matching on `Building Name`.

# %%
sum(planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name'])
# Out:
# 1

# %%
planon_loggerscontrollers_intersected['Building Name']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in planon_loggerscontrollers_intersected['Building Name'].values]
master_loggerscontrollers_for_validation_intersected['Building Name']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in master_loggerscontrollers_for_validation_intersected['Building Name'].values]

# %%
sum(planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name'])
# Out:
# 1

# %% [markdown]
# That didnt help.

# %%
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name']].index:
    print(i,'\t\tPlanon:',planon_loggerscontrollers_intersected.loc[i]['Building Name'],'\t\tMaster:',master_loggerscontrollers_for_validation_intersected.loc[i]['Building Name'])
# Out:
# MC071-B01 		Planon: furness college 		Master: furness

# %% [markdown]
# Follow up with lexical distance comparison. That would flag this as a match.

# %% [markdown]
# Loggers not matching on `Serial Number`.

# %%
sum(planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number'])
# Out:
# 8

# %%
planon_loggerscontrollers_intersected['Logger Serial Number']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ').replace('{','').replace('}','') for s in planon_loggerscontrollers_intersected['Logger Serial Number'].values]
master_loggerscontrollers_for_validation_intersected['Logger Serial Number']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ').replace('{','').replace('}','') for s in master_loggerscontrollers_for_validation_intersected['Logger Serial Number'].values]

# %%
sum(planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number'])
# Out:
# 5

# %%
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number']].index:
    print(i,'\t\tPlanon:',planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'],'\t\tMaster:',master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number'])
# Out:
# MC046-L05 		Planon: 50198895300 		Master: 050198895300
# MC063-L01 		Planon: 50198829500 		Master: 050198829500
# MC071-L02 		Planon: 50201286300 		Master: 050201286300
# MC071-L05 		Planon: 50201221 		Master: 050201221e00
# MC071-L16 		Planon: 50198904000 		Master: 050198904000

# %% [markdown]
# Technically the same, but there is a number format error. Compare based on float value, if they match, replace one of them. This needs to be amended, as it will throw `cannot onvert to float` exception if strings are left in from the previous step.

# %%
z1=[]
z2=[]    
for i in planon_loggerscontrollers_intersected.index:
    if planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number']:
        if float(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])==\
          float(master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number']):
                z1.append(str(int(float(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number']))))
                z2.append(str(int(float(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number']))))
        else:
            z1.append(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])
            z2.append(master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number'])
    else:
        z1.append(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])
        z2.append(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])
planon_loggerscontrollers_intersected['Logger Serial Number']=z1
master_loggerscontrollers_for_validation_intersected['Logger Serial Number']=z2

# %%
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number']].index:
    print(i,'\t\tPlanon:',planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'],'\t\tMaster:',master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number'])

# %% [markdown]
# New error percentage:

# %%
(planon_loggerscontrollers_intersected!=master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100
# Out:
# Building Code           0.000000
# Building Name           2.777778
# Description             0.000000
# Logger Serial Number    0.000000
# Make                    0.000000
# Model                   0.000000
# dtype: float64

# %% [markdown]
# (Bearing in my mind the above, this is technically 0)
