# %% [markdown]
# # EIS metadata validation script
# Used to validate Planon output with spreadsheet input

# %% [markdown]
# ## 1. Data import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Read data. There are two datasets: Planon and Master. The latter is the EIS data nomencalture that was created. Master is made up of two subsets: loggers and meters. Loggers are sometimes called controllers and meters are sometimes called sensors. In rare cases meters or sensors are also called channels.

# %%
planon=pd.read_excel('EIS Assets v2.xlsx',index_col = 'Code')
master_loggerscontrollers_old = pd.read_csv('LoggersControllers.csv', index_col = 'Asset Code')
master_meterssensors_old = pd.read_csv('MetersSensors.csv', encoding = 'macroman', index_col = 'Asset Code')
master_loggerscontrollers=pd.read_excel(master,sheetname='Loggers Controllers', index_col = 'Asset Code')
master_meterssensors=pd.read_excel(master,sheetname='Meters Sensors', index_col = 'Asset Code')
planon['Code']=planon.index
master_loggerscontrollers['Code']=master_loggerscontrollers.index
master_meterssensors['Code']=master_meterssensors.index

# %% [markdown]
# Unify index, caps everything and strip of trailing spaces.

# %%
planon.index=[str(i).upper().strip() for i in planon.index]
master_loggerscontrollers.index=[str(i).upper().strip() for i in master_loggerscontrollers.index]
master_meterssensors.index=[str(i).upper().strip() for i in master_meterssensors.index]

# %% [markdown]
# Drop duplicates (shouldn't be any)

# %%
planon.drop_duplicates(inplace=True)
master_loggerscontrollers.drop_duplicates(inplace=True)
master_meterssensors.drop_duplicates(inplace=True)

# %% [markdown]
# Split Planon import into loggers and meters
# Drop duplicates (shouldn't be any)

# %%
# Split the Planon file into 2, one for loggers & controllers, and one for meters & sensors.
planon_loggerscontrollers = planon.loc[(planon['Classification Group'] == 'EN.EN4 BMS Controller') | (planon['Classification Group'] == 'EN.EN1 Data Logger')]
planon_meterssensors = planon.loc[(planon['Classification Group'] == 'EN.EN2 Energy Meter') | (planon['Classification Group'] == 'EN.EN3 Energy Sensor')]
planon_loggerscontrollers.drop_duplicates(inplace=True)
planon_meterssensors.drop_duplicates(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\pandas\util\decorators.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return func(*args, **kwargs)

# %% [markdown]
# Index unique? show number of duplicates in index

# %%
len(planon_loggerscontrollers.index[planon_loggerscontrollers.index.duplicated()])
# Out:
# 0

# %%
len(planon_meterssensors.index[planon_meterssensors.index.duplicated()])
# Out:
# 3256

# %% [markdown]
# Meters are not unique. This is becasue of the spaces served. This is ok for now, we will deal with duplicates at the comparison stage. Same is true for loggers - in the unlikely event that there are duplicates in the future.

# %%
planon_meterssensors.head(3)
# Out:
#                BuildingNo.        Building Locations.Space.Space number  \
# AP000-L01/M001       AP000  Alexandra Park                          NaN
# AP000-L02/M001       AP000  Alexandra Park                          NaN
# AP000-L02/M002       AP000  Alexandra Park                          NaN
#
#                Space Name  Additional Location Info          Description  \
# AP000-L01/M001        NaN                       NaN                  NaN
# AP000-L02/M001        NaN                       NaN  Graduate House 1-11
# AP000-L02/M002        NaN                       NaN       Alex Park Main
#
#                Classification Group  Record  HVAC Ref  Element Description  \
# AP000-L01/M001  EN.EN2 Energy Meter     NaN       NaN                  NaN
# AP000-L02/M001  EN.EN2 Energy Meter     NaN       NaN                  NaN
# AP000-L02/M002  EN.EN2 Energy Meter     NaN       NaN                  NaN
#
#                      ...        Logger SIM Meter Pulse Value Meter Units  \
# AP000-L01/M001       ...               NaN               NaN         kWh
# AP000-L02/M001       ...               NaN               NaN         NaN
# AP000-L02/M002       ...               NaN               NaN         NaN
#
#                Meter Capacity  Network Point ID  Tenant Meter.Name  \
# AP000-L01/M001            NaN               NaN                 No
# AP000-L02/M001            NaN               NaN                 No
# AP000-L02/M002            NaN               NaN                 No
#
#                 Fiscal Meter.Name EIS Space.Space number  Utility Type.Name  \
# AP000-L01/M001                 No                    NaN                NaN
# AP000-L02/M001                 No                    NaN                NaN
# AP000-L02/M002                 No                    NaN                NaN
#
#                           Code
# AP000-L01/M001  AP000-L01/M001
# AP000-L02/M001  AP000-L02/M001
# AP000-L02/M002  AP000-L02/M002
#
# [3 rows x 30 columns]

# %% [markdown]
# ## 2. Validation

# %% [markdown]
# Create list of all buildings present in Planon export. These are buildings to check the data against from Master.

# %%
buildings=set(planon_meterssensors['BuildingNo.'])
buildings
# Out:
# {'AP000',
#  'AP001',
#  'AP009',
#  'AP010',
#  'AP011',
#  'AP057',
#  'AP080',
#  'AP081',
#  'EX001',
#  'MC000',
#  'MC001',
#  'MC003',
#  'MC007',
#  'MC008',
#  'MC010',
#  'MC011',
#  'MC013',
#  'MC014',
#  'MC029',
#  'MC030',
#  'MC031',
#  'MC032',
#  'MC033',
#  'MC043',
#  'MC044',
#  'MC045',
#  'MC046',
#  'MC047',
#  'MC048',
#  'MC050',
#  'MC051',
#  'MC053',
#  'MC055',
#  'MC061',
#  'MC062',
#  'MC063',
#  'MC064',
#  'MC065',
#  'MC066',
#  'MC067',
#  'MC068',
#  'MC069',
#  'MC070',
#  'MC071',
#  'MC072',
#  'MC075',
#  'MC076',
#  'MC077',
#  'MC078',
#  'MC083',
#  'MC095',
#  'MC099',
#  'MC102',
#  'MC103',
#  'MC125',
#  'MC126',
#  'MC128',
#  'MC129',
#  'MC131',
#  'MC134',
#  'MC138',
#  'MC139',
#  'MC140',
#  'MC141',
#  'MC171',
#  'MC181',
#  'MC197',
#  'MC198',
#  'MC199',
#  'MC200',
#  'MC202',
#  'MC203',
#  'MC204',
#  'MC207',
#  'MC208',
#  'MC210',
#  'MC211',
#  'OC004',
#  'OC005',
#  'OC006'}

# %%
len(buildings)
# Out:
# 80

# %% [markdown]
# ### 2.1. Meters

# %% [markdown]
# Create dataframe slice for validation from `master_meterssensors` where the only the buildings located in `buildings` are contained. Save this new slice into `master_meterssensors_for_validation`. This is done by creating sub-slices of the dataframe for each building, then concatenating them all together.

# %%
master_meterssensors_for_validation = \
    pd.concat([master_meterssensors.loc[master_meterssensors['Building Code'] == building] \
           for building in buildings])
master_meterssensors_for_validation.head(2)
# Out:
#              Logger Asset Code            Description Make Model Meter Units  \
# MC198-B01/A1         MC198-B01  Outside Air from OS13  NaN   NaN         NaN
# MC198-B01/C1         MC198-B01          Virtual CNC 1  NaN   NaN         NaN
#
#               Meter Pulse Value Classification Group Logger Channel  \
# MC198-B01/A1                NaN        Energy sensor             A1
# MC198-B01/C1                NaN        Energy sensor             C1
#
#              Utility Type  ??      ...       \
# MC198-B01/A1          NaN NaN      ...
# MC198-B01/C1          NaN NaN      ...
#
#                                                 Building Name Space  \
# MC198-B01/A1  Grizedale College - Offices, Bar & Social Space   NaN
# MC198-B01/C1  Grizedale College - Offices, Bar & Social Space   NaN
#
#              Additional Location Info Tenant meter Fiscal meter  Parent meter  \
# MC198-B01/A1                      NaN          0.0          0.0           NaN
# MC198-B01/C1                      NaN          0.0          0.0           NaN
#
#               Child meters Communications type  Electrical panel ID  \
# MC198-B01/A1           NaN                 NaN                  NaN
# MC198-B01/C1           NaN                 NaN                  NaN
#
#                       Code
# MC198-B01/A1  MC198-B01/A1
# MC198-B01/C1  MC198-B01/C1
#
# [2 rows x 22 columns]

# %%
#alternative method
master_meterssensors_for_validation2 = \
    master_meterssensors[master_meterssensors['Building Code'].isin(buildings)]
master_meterssensors_for_validation2.head(2)
# Out:
#                Logger Asset Code Description Make Model Meter Units  \
# MC046-L19/M001         MC046-L19     Meter 1  NaN   NaN         NaN
# MC046-L19/M002         MC046-L19     Meter 2  NaN   NaN         NaN
#
#                 Meter Pulse Value Classification Group Logger Channel  \
# MC046-L19/M001                NaN         Energy meter            DI1
# MC046-L19/M002                NaN         Energy meter            DI2
#
#                Utility Type  ??       ...        Building Name Space  \
# MC046-L19/M001          NaN NaN       ...         Bowland Main   NaN
# MC046-L19/M002          NaN NaN       ...         Bowland Main   NaN
#
#                Additional Location Info Tenant meter Fiscal meter  \
# MC046-L19/M001                      NaN          0.0          0.0
# MC046-L19/M002                      NaN          0.0          0.0
#
#                 Parent meter  Child meters Communications type  \
# MC046-L19/M001           NaN           NaN                 NaN
# MC046-L19/M002           NaN           NaN                 NaN
#
#                 Electrical panel ID            Code
# MC046-L19/M001                  NaN  MC046-L19/M001
# MC046-L19/M002                  NaN  MC046-L19/M002
#
# [2 rows x 22 columns]

# %% [markdown]
# Planon sensors are not unique because of the spaces served convention in the two data architectures. The Planon architecture devotes a new line for each space served - hence the not unique index. The Master architecture lists all the spaces only once, as a list, therefore it has a unique index. We will need to take this into account and create matching dataframe out of planon for comparison, with a unique index.

# %%
len(master_meterssensors_for_validation)
# Out:
# 30567

# %%
len(planon_meterssensors)-len(planon_meterssensors.index[planon_meterssensors.index.duplicated()])
# Out:
# 28824

# %% [markdown]
# Sort datasets after index for easier comparison.

# %%
master_meterssensors_for_validation.sort_index(inplace=True)
planon_meterssensors.sort_index(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %% [markdown]
# #### 2.1.1 Slicing of meters to  only certain columns of comparison

# %%
planon_meterssensors.T
# Out:
#                                    AP000-L01/M001       AP000-L02/M001  \
# BuildingNo.                                 AP000                AP000
# Building                           Alexandra Park       Alexandra Park
# Locations.Space.Space number                  NaN                  NaN
# Space Name                                    NaN                  NaN
# Additional Location Info                      NaN                  NaN
# Description                                   NaN  Graduate House 1-11
# Classification Group          EN.EN2 Energy Meter  EN.EN2 Energy Meter
# Record                                        NaN                  NaN
# HVAC Ref                                      NaN                  NaN
# Element Description                           NaN                  NaN
# Servicable Area                               NaN                  NaN
# Model                                         NaN                  NaN
# Make                                          NaN                  NaN
# EIS ID                                          1                    1
# Logger Channel                                  0                    0
# Logger Upstream Comms Target                  NaN                  NaN
# Logger Modem Serial Number                    NaN                  NaN
# Logger IP Address                             NaN                  NaN
# Logger Serial Number                          NaN                  NaN
# Logger MAC Address                            NaN                  NaN
# Logger SIM                                    NaN                  NaN
# Meter Pulse Value                             NaN                  NaN
# Meter Units                                   kWh                  NaN
# Meter Capacity                                NaN                  NaN
# Network Point ID                              NaN                  NaN
# Tenant Meter.Name                              No                   No
# Fiscal Meter.Name                              No                   No
# EIS Space.Space number                        NaN                  NaN
# Utility Type.Name                             NaN                  NaN
# Code                               AP000-L01/M001       AP000-L02/M001
#
#                                    AP000-L02/M002       AP000-L03/M001  \
# BuildingNo.                                 AP000                AP000
# Building                           Alexandra Park       Alexandra Park
# Locations.Space.Space number                  NaN                  NaN
# Space Name                                    NaN                  NaN
# Additional Location Info                      NaN                  NaN
# Description                        Alex Park Main                  NaN
# Classification Group          EN.EN2 Energy Meter  EN.EN2 Energy Meter
# Record                                        NaN                  NaN
# HVAC Ref                                      NaN                  NaN
# Element Description                           NaN                  NaN
# Servicable Area                               NaN                  NaN
# Model                                         NaN                  NaN
# Make                                          NaN                  NaN
# EIS ID                                          2                    1
# Logger Channel                                  0                    0
# Logger Upstream Comms Target                  NaN                  NaN
# Logger Modem Serial Number                    NaN                  NaN
# Logger IP Address                             NaN                  NaN
# Logger Serial Number                          NaN                  NaN
# Logger MAC Address                            NaN                  NaN
# Logger SIM                                    NaN                  NaN
# Meter Pulse Value                             NaN                  NaN
# Meter Units                                   NaN                  NaN
# Meter Capacity                                NaN                  NaN
# Network Point ID                              NaN                  NaN
# Tenant Meter.Name                              No                   No
# Fiscal Meter.Name                              No                   No
# EIS Space.Space number                        NaN                  NaN
# Utility Type.Name                             NaN                  NaN
# Code                               AP000-L02/M002       AP000-L03/M001
#
#                                    AP000-L03/M002  \
# BuildingNo.                                 AP000
# Building                           Alexandra Park
# Locations.Space.Space number                  NaN
# Space Name                                    NaN
# Additional Location Info                      NaN
# Description                                   NaN
# Classification Group          EN.EN2 Energy Meter
# Record                                        NaN
# HVAC Ref                                      NaN
# Element Description                           NaN
# Servicable Area                               NaN
# Model                                         NaN
# Make                                          NaN
# EIS ID                                          2
# Logger Channel                                  0
# Logger Upstream Comms Target                  NaN
# Logger Modem Serial Number                    NaN
# Logger IP Address                             NaN
# Logger Serial Number                          NaN
# Logger MAC Address                            NaN
# Logger SIM                                    NaN
# Meter Pulse Value                             NaN
# Meter Units                                   NaN
# Meter Capacity                                NaN
# Network Point ID                              NaN
# Tenant Meter.Name                              No
# Fiscal Meter.Name                              No
# EIS Space.Space number                        NaN
# Utility Type.Name                             NaN
# Code                               AP000-L03/M002
#
#                                                           AP001-L01/M001  \
# BuildingNo.                                                        AP001
# Building                      House 01 - Bassenthwaite, Graduate College
# Locations.Space.Space number                                         NaN
# Space Name                                                           NaN
# Additional Location Info                                             NaN
# Description                                                          NaN
# Classification Group                                 EN.EN2 Energy Meter
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                                NaN
# Make                                                                 NaN
# EIS ID                                                                 1
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                                    NaN
# Logger Serial Number                                                 NaN
# Logger MAC Address                                                   NaN
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                           m3
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                     No
# Fiscal Meter.Name                                                     No
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
# Code                                                      AP001-L01/M001
#
#                                                           AP001-L01/M002  \
# BuildingNo.                                                        AP001
# Building                      House 01 - Bassenthwaite, Graduate College
# Locations.Space.Space number                                         NaN
# Space Name                                                           NaN
# Additional Location Info                                             NaN
# Description                                                   Bar Cellar
# Classification Group                                 EN.EN2 Energy Meter
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                                NaN
# Make                                                                 NaN
# EIS ID                                                                 2
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                                    NaN
# Logger Serial Number                                                 NaN
# Logger MAC Address                                                   NaN
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                          kWh
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                     No
# Fiscal Meter.Name                                                     No
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
# Code                                                      AP001-L01/M002
#
#                                                           AP001-L01/M003  \
# BuildingNo.                                                        AP001
# Building                      House 01 - Bassenthwaite, Graduate College
# Locations.Space.Space number                                         NaN
# Space Name                                                           NaN
# Additional Location Info                                             NaN
# Description                                                   Bar Ground
# Classification Group                                 EN.EN2 Energy Meter
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                                NaN
# Make                                                                 NaN
# EIS ID                                                                 3
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                                    NaN
# Logger Serial Number                                                 NaN
# Logger MAC Address                                                   NaN
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                          kWh
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                     No
# Fiscal Meter.Name                                                     No
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
# Code                                                      AP001-L01/M003
#
#                                                           AP001-L01/M004  \
# BuildingNo.                                                        AP001
# Building                      House 01 - Bassenthwaite, Graduate College
# Locations.Space.Space number                                         NaN
# Space Name                                                           NaN
# Additional Location Info                                             NaN
# Description                                                Services Room
# Classification Group                                 EN.EN2 Energy Meter
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                                NaN
# Make                                                                 NaN
# EIS ID                                                                 4
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                                    NaN
# Logger Serial Number                                                 NaN
# Logger MAC Address                                                   NaN
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                          kWh
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                     No
# Fiscal Meter.Name                                                     No
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
# Code                                                      AP001-L01/M004
#
#                                                           AP001-L01/M005  \
# BuildingNo.                                                        AP001
# Building                      House 01 - Bassenthwaite, Graduate College
# Locations.Space.Space number                                         NaN
# Space Name                                                           NaN
# Additional Location Info                                             NaN
# Description                                                    Bar Water
# Classification Group                                 EN.EN2 Energy Meter
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                                NaN
# Make                                                                 NaN
# EIS ID                                                                 5
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                                    NaN
# Logger Serial Number                                                 NaN
# Logger MAC Address                                                   NaN
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                           m3
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                     No
# Fiscal Meter.Name                                                     No
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
# Code                                                      AP001-L01/M005
#
#                                            ...                \
# BuildingNo.                                ...
# Building                                   ...
# Locations.Space.Space number               ...
# Space Name                                 ...
# Additional Location Info                   ...
# Description                                ...
# Classification Group                       ...
# Record                                     ...
# HVAC Ref                                   ...
# Element Description                        ...
# Servicable Area                            ...
# Model                                      ...
# Make                                       ...
# EIS ID                                     ...
# Logger Channel                             ...
# Logger Upstream Comms Target               ...
# Logger Modem Serial Number                 ...
# Logger IP Address                          ...
# Logger Serial Number                       ...
# Logger MAC Address                         ...
# Logger SIM                                 ...
# Meter Pulse Value                          ...
# Meter Units                                ...
# Meter Capacity                             ...
# Network Point ID                           ...
# Tenant Meter.Name                          ...
# Fiscal Meter.Name                          ...
# EIS Space.Space number                     ...
# Utility Type.Name                          ...
# Code                                       ...
#
#                                                 OC006-B01/W4  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                  ShuntPumpRotate
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    W4
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/W4
#
#                                                 OC006-B01/W5  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                     Manual Shunt pump changeover
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    W5
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/W5
#
#                                                 OC006-B01/Y1  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                          Outside air temperature
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Y1
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                  Degrees Celsius
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Y1
#
#                                                 OC006-B01/Y2  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                 Immersion Sensor
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Y2
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Y2
#
#                                                 OC006-B01/Y3  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                  Thermistor TBTC
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Y3
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Y3
#
#                                                 OC006-B01/Y4  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                 Room temperature
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Y4
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                  Degrees Celsius
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Y4
#
#                                                 OC006-B01/Y5  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                  Thermistor TBTI
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Y5
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                  Degrees Celsius
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Y5
#
#                                                 OC006-B01/Y6  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                           4DIX V
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Y6
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Y6
#
#                                                 OC006-B01/Z1  \
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                  Heating Boilers
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Z1
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Z1
#
#                                                 OC006-B01/Z2
# BuildingNo.                                            OC006
# Building                      Chancellor's Wharf, Kent House
# Locations.Space.Space number                             NaN
# Space Name                                               NaN
# Additional Location Info                                 NaN
# Description                                   DHWS Immersion
# Classification Group                    EN.EN3 Energy Sensor
# Record                                                   NaN
# HVAC Ref                                                 NaN
# Element Description                                      NaN
# Servicable Area                                          NaN
# Model                                                    NaN
# Make                                                     NaN
# EIS ID                                                    Z2
# Logger Channel                                             0
# Logger Upstream Comms Target                             NaN
# Logger Modem Serial Number                               NaN
# Logger IP Address                                        NaN
# Logger Serial Number                                     NaN
# Logger MAC Address                                       NaN
# Logger SIM                                               NaN
# Meter Pulse Value                                        NaN
# Meter Units                                              NaN
# Meter Capacity                                           NaN
# Network Point ID                                         NaN
# Tenant Meter.Name                                         No
# Fiscal Meter.Name                                         No
# EIS Space.Space number                                   NaN
# Utility Type.Name                                        NaN
# Code                                            OC006-B01/Z2
#
# [30 rows x 32080 columns]

# %%
master_meterssensors_for_validation.T
# Out:
#                                     AP000-L01/M001  \
# Logger Asset Code                        AP000-L01
# Description                                    NaN
# Make                                 Carlo Gavazzi
# Model                                         EM24
# Meter Units                                    kWh
# Meter Pulse Value                                1
# Classification Group                  Energy meter
# Logger Channel                                   1
# Utility Type                           Electricity
# ??                                             NaN
# Meter Type                                     NaN
# Building Code                                AP000
# Building Name                       Alexandra Park
# Space                                          NaN
# Additional Location Info  Graduate 1-11 Plant Room
# Tenant meter                                     0
# Fiscal meter                                     0
# Parent meter                                   NaN
# Child meters                                   NaN
# Communications type                            NaN
# Electrical panel ID                            NaN
# Code                                AP000-L01/M001
#
#                                        AP000-L02/M001  \
# Logger Asset Code                           AP000-L02
# Description                       Graduate House 1-11
# Make                                          Actaris
# Model                                         Delta G
# Meter Units                                       NaN
# Meter Pulse Value                                 NaN
# Classification Group                     Energy meter
# Logger Channel                                      1
# Utility Type                              Natural Gas
# ??                                                NaN
# Meter Type                                        NaN
# Building Code                                   AP000
# Building Name                          Alexandra Park
# Space                                             NaN
# Additional Location Info  External Gas Meter Building
# Tenant meter                                        0
# Fiscal meter                                        0
# Parent meter                                      NaN
# Child meters                                      NaN
# Communications type                               NaN
# Electrical panel ID                               NaN
# Code                                   AP000-L02/M001
#
#                                        AP000-L02/M002  \
# Logger Asset Code                           AP000-L02
# Description                            Alex Park Main
# Make                                           Delta
# Model                                             D35
# Meter Units                                       NaN
# Meter Pulse Value                                 NaN
# Classification Group                     Energy meter
# Logger Channel                                      2
# Utility Type                              Natural Gas
# ??                                                NaN
# Meter Type                                        NaN
# Building Code                                   AP000
# Building Name                          Alexandra Park
# Space                                             NaN
# Additional Location Info  External Gas Meter Building
# Tenant meter                                        0
# Fiscal meter                                        0
# Parent meter                                      NaN
# Child meters                                      NaN
# Communications type                               NaN
# Electrical panel ID                               NaN
# Code                                   AP000-L02/M002
#
#                                         AP000-L03/M001  \
# Logger Asset Code                            AP000-L03
# Description                                        NaN
# Make
# Model
# Meter Units                                        NaN
# Meter Pulse Value                                  NaN
# Classification Group                      Energy meter
# Logger Channel                                       1
# Utility Type                                     Water
# ??                                                 NaN
# Meter Type                                         NaN
# Building Code                                    AP000
# Building Name                           Alexandra Park
# Space                                              NaN
# Additional Location Info  External Water Meter Chamber
# Tenant meter                                         0
# Fiscal meter                                         0
# Parent meter                                       NaN
# Child meters                                       NaN
# Communications type                                NaN
# Electrical panel ID                                NaN
# Code                                    AP000-L03/M001
#
#                                         AP000-L03/M002  \
# Logger Asset Code                            AP000-L03
# Description                                        NaN
# Make
# Model
# Meter Units                                        NaN
# Meter Pulse Value                                  NaN
# Classification Group                      Energy meter
# Logger Channel                                       2
# Utility Type                                     Water
# ??                                                 NaN
# Meter Type                                         NaN
# Building Code                                    AP000
# Building Name                           Alexandra Park
# Space                                              NaN
# Additional Location Info  External Water Meter Chamber
# Tenant meter                                         0
# Fiscal meter                                         0
# Parent meter                                       NaN
# Child meters                                       NaN
# Communications type                                NaN
# Electrical panel ID                                NaN
# Code                                    AP000-L03/M002
#
#                                                              AP000-L99/M303  \
# Logger Asset Code                                                 AP000-L99
# Description                                                    Alex Park LU
# Make                                                                    NaN
# Model                                                                   NaN
# Meter Units                                                             NaN
# Meter Pulse Value                                                       NaN
# Classification Group                                           Energy meter
# Logger Channel                                                          NaN
# Utility Type                                                    Natural Gas
# ??                                                                      NaN
# Meter Type                                                              NaN
# Building Code                                                         AP000
# Building Name                                                Alexandra Park
# Space                     AP001 A0, AP002 A0, AP003 A0, AP004 A0, Ap005 ...
# Additional Location Info                                                NaN
# Tenant meter                                                              0
# Fiscal meter                                                              1
# Parent meter                                                            NaN
# Child meters                                                            NaN
# Communications type                                                     NaN
# Electrical panel ID                                                     NaN
# Code                                                         AP000-L99/M303
#
#                                                              AP000-L99/M308  \
# Logger Asset Code                                                 AP000-L99
# Description                                                   Alex Park UPP
# Make                                                                    NaN
# Model                                                                   NaN
# Meter Units                                                             NaN
# Meter Pulse Value                                                       NaN
# Classification Group                                           Energy meter
# Logger Channel                                                          NaN
# Utility Type                                                    Natural Gas
# ??                                                                      NaN
# Meter Type                                                              NaN
# Building Code                                                         AP000
# Building Name                                                Alexandra Park
# Space                     AP012 A0, AP013 A0, AP014 A0, AP015 A0, AP016 ...
# Additional Location Info                                                NaN
# Tenant meter                                                              0
# Fiscal meter                                                              1
# Parent meter                                                            NaN
# Child meters                                                            NaN
# Communications type                                                     NaN
# Electrical panel ID                                                     NaN
# Code                                                         AP000-L99/M308
#
#                                     AP001-L01/M001            AP001-L01/M002  \
# Logger Asset Code                        AP001-L01                 AP001-L01
# Description                                    NaN              Bar Cellar
# Make                                                                  Elster
# Model                                                                  A1100
# Meter Units                                     m3                       kWh
# Meter Pulse Value                            0.001                     0.001
# Classification Group                  Energy meter              Energy meter
# Logger Channel                                   1                         2
# Utility Type                                 Water               Electricity
# ??                                             NaN                       NaN
# Meter Type                                     NaN                       NaN
# Building Code                                AP001                     AP001
# Building Name             House 01 - Bassenthwaite  House 01 - Bassenthwaite
# Space                                          NaN                       NaN
# Additional Location Info  Bassenthwaite Rm  No 104  Bassenthwaite Rm  No 104
# Tenant meter                                     0                         0
# Fiscal meter                                     0                         0
# Parent meter                                   NaN                       NaN
# Child meters                                   NaN                       NaN
# Communications type                            NaN                       NaN
# Electrical panel ID                            NaN                       NaN
# Code                                AP001-L01/M001            AP001-L01/M002
#
#                                     AP001-L01/M003  \
# Logger Asset Code                        AP001-L01
# Description                           Bar Ground
# Make                                        Landis
# Model                                        E1100
# Meter Units                                    kWh
# Meter Pulse Value                            0.001
# Classification Group                  Energy meter
# Logger Channel                                   3
# Utility Type                           Electricity
# ??                                             NaN
# Meter Type                                     NaN
# Building Code                                AP001
# Building Name             House 01 - Bassenthwaite
# Space                                          NaN
# Additional Location Info  Bassenthwaite Rm  No 104
# Tenant meter                                     0
# Fiscal meter                                     0
# Parent meter                                   NaN
# Child meters                                   NaN
# Communications type                            NaN
# Electrical panel ID                            NaN
# Code                                AP001-L01/M003
#
#                                        ...                \
# Logger Asset Code                      ...
# Description                            ...
# Make                                   ...
# Model                                  ...
# Meter Units                            ...
# Meter Pulse Value                      ...
# Classification Group                   ...
# Logger Channel                         ...
# Utility Type                           ...
# ??                                     ...
# Meter Type                             ...
# Building Code                          ...
# Building Name                          ...
# Space                                  ...
# Additional Location Info               ...
# Tenant meter                           ...
# Fiscal meter                           ...
# Parent meter                           ...
# Child meters                           ...
# Communications type                    ...
# Electrical panel ID                    ...
# Code                                   ...
#
#                                             OC006-B01/Y1  \
# Logger Asset Code                              OC006-B01
# Description                      Outside air temperature
# Make                                                 NaN
# Model                                                NaN
# Meter Units                              Degrees Celsius
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Y1
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Y1
#
#                                             OC006-B01/Y2  \
# Logger Asset Code                              OC006-B01
# Description                             Immersion Sensor
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          NaN
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Y2
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Y2
#
#                                             OC006-B01/Y3  \
# Logger Asset Code                              OC006-B01
# Description                              Thermistor TBTC
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          NaN
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Y3
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Y3
#
#                                             OC006-B01/Y4  \
# Logger Asset Code                              OC006-B01
# Description                             Room temperature
# Make                                                 NaN
# Model                                                NaN
# Meter Units                              Degrees Celsius
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Y4
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Y4
#
#                                             OC006-B01/Y5  \
# Logger Asset Code                              OC006-B01
# Description                              Thermistor TBTI
# Make                                                 NaN
# Model                                                NaN
# Meter Units                              Degrees Celsius
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Y5
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Y5
#
#                                             OC006-B01/Y6  \
# Logger Asset Code                              OC006-B01
# Description                                       4DIX V
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          NaN
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Y6
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Y6
#
#                                             OC006-B01/Z1  \
# Logger Asset Code                              OC006-B01
# Description                              Heating Boilers
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          NaN
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Z1
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Z1
#
#                                             OC006-B01/Z2  \
# Logger Asset Code                              OC006-B01
# Description                               DHWS Immersion
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          NaN
# Meter Pulse Value                                    NaN
# Classification Group                       Energy sensor
# Logger Channel                                        Z2
# Utility Type                                         NaN
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                                NaN
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           0
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                        OC006-B01/Z2
#
#                                           OC006-L99/M200  \
# Logger Asset Code                              OC006-L99
# Description                                   Kent House
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          kWh
# Meter Pulse Value                                    NaN
# Classification Group                        Energy meter
# Logger Channel                                       NaN
# Utility Type                                 Electricity
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                           OC006 A0
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           1
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                      OC006-L99/M200
#
#                                           OC006-L99/M503
# Logger Asset Code                              OC006-L99
# Description                                   Kent House
# Make                                                 NaN
# Model                                                NaN
# Meter Units                                          NaN
# Meter Pulse Value                                    NaN
# Classification Group                        Energy meter
# Logger Channel                                       NaN
# Utility Type                                       Water
# ??                                                   NaN
# Meter Type                                           NaN
# Building Code                                      OC006
# Building Name             Chancellor's Wharf, Kent House
# Space                                           OC006 A0
# Additional Location Info                             NaN
# Tenant meter                                           0
# Fiscal meter                                           1
# Parent meter                                         NaN
# Child meters                                         NaN
# Communications type                                  NaN
# Electrical panel ID                                  NaN
# Code                                      OC006-L99/M503
#
# [22 rows x 30567 columns]

# %% [markdown]
# Create dictionary that maps Planon column names onto Master.
#
# From Nicola:
# - Code (Asset Code)
# - Description
# - EIS ID (Channel)
# - Utility Type
# - Fiscal Meter
# - Tenant Meter
#
# `Building code` and `Building name` are implicitly included. `Logger Serial Number`, `IP` or `MAC` would be essential to include, as well as `Make` and `Model`. `Additional Location Info` is not essnetial but would be useful to have. Locations (`Locations.Space.Space number` and `Space Name`) are included in the Planon export - but this is their only viable data source, therefore are not validated against.

# %%
#Planon:Master
meters_match_dict={
      "BuildingNo.":"Building Code",
      "Building":"Building Name",
      "Description":"Description",
      "EIS ID":"Logger Channel",
      "Tenant Meter.Name":"Tenant meter",
      "Fiscal Meter.Name":"Fiscal meter",
      "Code":"Code"
      }

# %% [markdown]
# Filter both dataframes based on these new columns. Then remove duplicates. Currently, this leads to loss of information of spaces served, but also a unique index for the Planon dataframe, therefore bringing the dataframes closer to each other. When including spaces explicitly in the comparison (if we want to - or just trust the  Planon space mapping), this needs to be modified.

# %%
master_meterssensors_for_validation_filtered=master_meterssensors_for_validation[list(meters_match_dict.values())]
planon_meterssensors_filtered=planon_meterssensors[list(meters_match_dict.keys())]

# %%
master_meterssensors_for_validation_filtered.head(2)
# Out:
#                  Building Name  Tenant meter Logger Channel Building Code  \
# AP000-L01/M001  Alexandra Park           0.0              1         AP000
# AP000-L02/M001  Alexandra Park           0.0              1         AP000
#
#                 Fiscal meter          Description            Code
# AP000-L01/M001           0.0                  NaN  AP000-L01/M001
# AP000-L02/M001           0.0  Graduate House 1-11  AP000-L02/M001

# %%
planon_meterssensors_filtered.head(2)
# Out:
#                       Building Tenant Meter.Name EIS ID BuildingNo.  \
# AP000-L01/M001  Alexandra Park                No      1       AP000
# AP000-L02/M001  Alexandra Park                No      1       AP000
#
#                Fiscal Meter.Name          Description            Code
# AP000-L01/M001                No                  NaN  AP000-L01/M001
# AP000-L02/M001                No  Graduate House 1-11  AP000-L02/M001

# %% [markdown]
# Unify headers, drop duplicates (bear the mind the spaces argument, this where it needs to be brought back in in the future!).

# %%
planon_meterssensors_filtered.columns=[meters_match_dict[i] for i in planon_meterssensors_filtered]

# %%
planon_meterssensors_filtered.drop_duplicates(inplace=True)
master_meterssensors_for_validation_filtered.drop_duplicates(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\pandas\util\decorators.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return func(*args, **kwargs)

# %%
planon_meterssensors_filtered.head(2)
# Out:
#                  Building Name Tenant meter Logger Channel Building Code  \
# AP000-L01/M001  Alexandra Park           No              1         AP000
# AP000-L02/M001  Alexandra Park           No              1         AP000
#
#                Fiscal meter          Description            Code
# AP000-L01/M001           No                  NaN  AP000-L01/M001
# AP000-L02/M001           No  Graduate House 1-11  AP000-L02/M001

# %% [markdown]
# Fiscal/Tenant meter name needs fixing from Yes/No and 1/0.

# %%
planon_meterssensors_filtered['Fiscal meter']=planon_meterssensors_filtered['Fiscal meter'].isin(['Yes'])
planon_meterssensors_filtered['Tenant meter']=planon_meterssensors_filtered['Tenant meter'].isin(['Yes'])
master_meterssensors_for_validation_filtered['Fiscal meter']=master_meterssensors_for_validation_filtered['Fiscal meter'].isin([1])
master_meterssensors_for_validation_filtered['Tenant meter']=master_meterssensors_for_validation_filtered['Tenant meter'].isin([1])
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
master_meterssensors_for_validation_filtered.head(2)
# Out:
#                  Building Name Tenant meter Logger Channel Building Code  \
# AP000-L01/M001  Alexandra Park        False              1         AP000
# AP000-L02/M001  Alexandra Park        False              1         AP000
#
#                Fiscal meter          Description            Code
# AP000-L01/M001        False                  NaN  AP000-L01/M001
# AP000-L02/M001        False  Graduate House 1-11  AP000-L02/M001

# %%
planon_meterssensors_filtered.head(2)
# Out:
#                  Building Name Tenant meter Logger Channel Building Code  \
# AP000-L01/M001  Alexandra Park        False              1         AP000
# AP000-L02/M001  Alexandra Park        False              1         AP000
#
#                Fiscal meter          Description            Code
# AP000-L01/M001        False                  NaN  AP000-L01/M001
# AP000-L02/M001        False  Graduate House 1-11  AP000-L02/M001

# %% [markdown]
# Cross-check missing meters

# %%
a=np.sort(list(set(planon_meterssensors_filtered.index)))
b=np.sort(list(set(master_meterssensors_for_validation_filtered.index)))
meterssensors_not_in_planon=[]
for i in b:
    if i not in a:
        print(i+',',end=" "),
        meterssensors_not_in_planon.append(i)
print('\n\nMeters in Master, but not in Planon:',
      len(meterssensors_not_in_planon),'/',len(b),':',
      round(len(meterssensors_not_in_planon)/len(b)*100,3),'%')
# Out:
# AP000-L99/M303, AP000-L99/M308, AP080-L79/M001, AP080-L80/M001, AP080-L81/M001, EX001-B01/N1, EX001-B01/O1, EX001-B01/O2, EX001-B01/O3, MC000-L99/M201, MC000-L99/M202, MC000-L99/M203, MC000-L99/M506, MC001-B01/N1, MC001-L82-M972, MC001-L82-M973, MC001-L82-M974, MC001-L82-M975, MC001-L82-M976, MC001-L99/M100, MC001-L99/M222, MC001-L99/M224, MC001-L99/M306, MC001-L99/M508, MC003-B01/N1, MC003-L99/M207, MC003-L99/M304, MC003-L99/M509, MC007-L99/M211, MC007-L99/M511, MC008-L82-M916, MC008-L99/M302, MC010-L82-M745, MC010-L82-M746, MC010-L82-M747, MC010-L82-M748, MC010-L82-M749, MC010-L82-M750, MC010-L82-M751, MC010-L82-M752, MC010-L82-M753, MC010-L82-M754, MC010-L82-M755, MC010-L82-M756, MC010-L82-M757, MC010-L82-M758, MC010-L82-M759, MC010-L82-M760, MC010-L82-M761, MC010-L82-M762, MC010-L82-M763, MC010-L82-M764, MC010-L82-M765, MC010-L82-M766, MC010-L82-M767, MC010-L82-M768, MC010-L82-M769, MC010-L82-M770, MC010-L82-M771, MC010-L82-M772, MC011-B01/N1, MC011-B01/O2, MC011-L82-M953, MC011-L82-M954, MC014-B01/N1, MC014-B01/O2, MC014-B01/O3, MC014-B02/N1, MC014-B02/O2, MC014-B02/O3, MC014-B03/N1, MC014-B03/O2, MC014-B03/O3, MC014-B04/N1, MC014-B04/O2, MC014-B04/O3, MC014-B05/N1, MC014-B05/O2, MC014-B05/O3, MC014-B06/N1, MC014-B06/O2, MC014-B06/O3, MC014-B07/N1, MC014-B07/O2, MC014-B07/O3, MC014-B08/N1, MC014-B08/O2, MC014-B08/O3, MC014-B09/N1, MC014-B09/O2, MC014-B09/O3, MC014-B10/N1, MC014-B10/O2, MC014-B10/O3, MC014-B11/N1, MC014-B11/O2, MC014-B11/O3, MC014-B12/N1, MC014-B12/O2, MC014-B12/O3, MC014-B13/N1, MC014-B13/O2, MC014-B13/O3, MC014-B14/N1, MC014-B14/O2, MC014-B14/O3, MC029-B01/N1, MC030-B01/N1, MC030-B01/O1, MC030-B01/O2, MC030-B01/O3, MC031-B01/N1, MC031-B02/N1, MC031-B02/O1, MC031-B02/O2, MC031-B02/O3, MC032-B01/N1, MC032-B01/N10, MC032-B01/N11, MC032-B01/N2, MC032-B01/N3, MC032-B01/N6, MC032-B01/O1, MC032-B02/N1, MC032-B02/O2, MC032-B02/O3, MC032-B03/N1, MC032-B03/O1, MC032-B04/N1, MC032-B04/O1, MC032-B05/N1, MC032-B06/N1, MC032-B06/N2, MC032-B07/N1, MC032-B07/O1, MC032-B07/O2, MC032-B07/O3, MC032-L82-M773, MC032-L82-M774, MC033-B01/N1, MC033-L82-M898, MC033-L82-M899, MC043-B01/N1, MC043-B01/N10, MC043-B01/N11, MC043-B01/N3, MC043-B01/N6, MC044-B01/N1, MC044-B01/N2, MC044-B01/N6, MC044-B01/O1, MC044-B01/O2, MC044-B01/O3, MC044-B02/N1, MC044-B02/N2, MC044-B02/N3, MC044-B02/N6, MC044-B02/O1, MC044-B02/O3, MC044-B03/N1, MC044-B03/N3, MC044-B03/N6, MC044-B03/O1, MC044-B03/O2, MC044-B03/O3, MC044-B04/N1, MC044-B04/N10, MC044-B04/N11, MC044-B04/N12, MC044-B04/N13, MC044-B04/N14, MC044-B04/N3, MC044-B04/N6, MC044-B04/N9, MC044-B05/N1, MC044-B05/N2, MC044-B05/N3, MC044-B05/N6, MC044-B05/O1, MC044-B05/O2, MC044-B05/O3, MC044-B06/N1, MC044-B06/N3, MC044-B06/N4, MC044-B06/N6, MC044-B06/O1, MC044-B06/O2, MC044-B06/O3, MC044-B07/N1, MC044-B07/N2, MC044-B07/N3, MC044-B07/N4, MC044-B07/N5, MC044-B07/N6, MC044-B07/N7, MC044-B08/N1, MC044-B08/N2, MC044-B08/N3, MC044-B08/N6, MC044-B08/O2, MC044-B08/O3, MC044-B09/I1, MC044-B09/I2, MC044-B09/I3, MC044-B09/I4, MC044-B09/N1, MC044-B09/N10, MC044-B09/N11, MC044-B09/N2, MC044-B09/N3, MC044-B09/N4, MC044-B09/N5, MC044-B09/N6, MC044-B09/N7, MC044-B09/N8, MC044-B09/N9, MC044-B10/N1, MC044-B10/N10, MC044-B10/N100, MC044-B10/N101, MC044-B10/N102, MC044-B10/N103, MC044-B10/N104, MC044-B10/N105, MC044-B10/N106, MC044-B10/N107, MC044-B10/N108, MC044-B10/N109, MC044-B10/N11, MC044-B10/N110, MC044-B10/N111, MC044-B10/N112, MC044-B10/N113, MC044-B10/N114, MC044-B10/N115, MC044-B10/N116, MC044-B10/N117, MC044-B10/N118, MC044-B10/N119, MC044-B10/N12, MC044-B10/N120, MC044-B10/N121, MC044-B10/N122, MC044-B10/N123, MC044-B10/N124, MC044-B10/N125, MC044-B10/N126, MC044-B10/N127, MC044-B10/N128, MC044-B10/N129, MC044-B10/N13, MC044-B10/N130, MC044-B10/N131, MC044-B10/N132, MC044-B10/N133, MC044-B10/N134, MC044-B10/N135, MC044-B10/N136, MC044-B10/N137, MC044-B10/N138, MC044-B10/N139, MC044-B10/N14, MC044-B10/N140, MC044-B10/N141, MC044-B10/N142, MC044-B10/N143, MC044-B10/N144, MC044-B10/N145, MC044-B10/N146, MC04 ...
#
# Meters in Master, but not in Planon: 1311 / 30135 : 4.35 %

# %%
#without MC210
len(set([i for i in meterssensors_not_in_planon if i[:5]!='MC210']))
# Out:
# 1202

# %%
set([i for i in meterssensors_not_in_planon if i[:5]!='MC210'])
# Out:
# {'MC044-B08/N3',
#  'MC044-B10/N168',
#  'MC044-B10/N115',
#  'MC044-B10/N45',
#  'MC065-B05/N1',
#  'MC070-L82-M932',
#  'MC204-B06/N1',
#  'MC044-B10/N13',
#  'MC044-B10/N128',
#  'MC044-B11/N21',
#  'MC065-B08/N4',
#  'MC044-B04/N1',
#  'MC103-B01/N6',
#  'MC044-B11/N137',
#  'MC204-B01/N4',
#  'MC070-B02/N1',
#  'MC014-B10/N1',
#  'MC044-B10/N160',
#  'MC200-L82-M939',
#  'MC204-B01/O4',
#  'MC044-B10/N126',
#  'MC197-L82-M889',
#  'MC071-L82-M917',
#  'MC202-B10/O1',
#  'MC072-B02/N9',
#  'MC044-L82-M812',
#  'MC044-B10/N216',
#  'MC044-B11/N15',
#  'MC044-B04/N9',
#  'MC044-B11/N24',
#  'MC044-B10/N21',
#  'MC044-B11/N74',
#  'MC065-B02/O3',
#  'MC065-B06/N7',
#  'MC044-B10/N208',
#  'MC204-B03/O2',
#  'MC071-B01/N3',
#  'MC065-L82-M905',
#  'MC044-L82-M831',
#  'MC044-B11/N17',
#  'MC031-B02/O1',
#  'MC044-B11/N8',
#  'MC046-L82-M742',
#  'MC044-B10/N11',
#  'MC065-L82-M912',
#  'MC044-B10/N196',
#  'MC044-B10/N212',
#  'MC044-B11/N94',
#  'MC044-L82-M811',
#  'MC061-L99/M310',
#  'MC044-B11/N88',
#  'MC102-L82-M718',
#  'MC207-L82-M856',
#  'MC065-L82-M901',
#  'MC044-B11/N3',
#  'MC044-B10/N93',
#  'MC044-B11/N71',
#  'MC014-B12/O2',
#  'MC202-B04/N1',
#  'MC044-B10/N150',
#  'MC044-B10/N30',
#  'MC044-B10/N92',
#  'MC046-B01/O4',
#  'MC044-B11/N168',
#  'MC044-B11/N150',
#  'MC044-B11/N42',
#  'MC044-L82-M805',
#  'MC045-L82-M787',
#  'MC061-L99/M305',
#  'MC078-B01/N3',
#  'MC014-B01/O3',
#  'MC061-B01/O4',
#  'MC065-B09/N4',
#  'MC033-L82-M899',
#  'MC001-L99/M222',
#  'MC072-B02/N3',
#  'MC075-L82-M944',
#  'MC103-L99/M300',
#  'MC211-B01/N1',
#  'MC102-L82-M704',
#  'MC065-B07/N2',
#  'MC102-L82-M878',
#  'MC044-B10/N1',
#  'MC044-B07/N6',
#  'MC061-B03/N7',
#  'MC044-B10/N153',
#  'MC211-L82-M858',
#  'MC070-B03/O1',
#  'MC010-L82-M770',
#  'MC044-B10/N29',
#  'MC044-B11/N146',
#  'MC131-L82-M925',
#  'MC044-B09/I4',
#  'MC072-B04/I7',
#  'MC198-B02/O1',
#  'MC044-B11/N78',
#  'MC044-B10/N108',
#  'MC044-B11/N141',
#  'MC014-B10/O3',
#  'MC044-B10/N52',
#  'MC044-B10/N209',
#  'MC032-B01/N10',
#  'MC065-L82-M914',
#  'MC128-L82-M926',
#  'MC045-L82-M775',
#  'MC044-B10/N178',
#  'MC044-B09/I1',
#  'MC044-B10/N17',
#  'MC003-L99/M509',
#  'MC000-L99/M506',
#  'MC063-B01/O1',
#  'MC014-B06/N1',
#  'MC044-B11/N44',
#  'MC061-B02/N4',
#  'MC065-B09/N10',
#  'MC044-B10/N109',
#  'MC102-L82-M713',
#  'MC032-B02/O2',
#  'MC044-B10/N187',
#  'MC044-B10/N144',
#  'MC047-B02/N1',
#  'MC010-L82-M771',
#  'MC044-B11/N11',
#  'MC030-B01/O3',
#  'MC014-B08/O3',
#  'MC065-B03/O3',
#  'MC044-B10/N184',
#  'MC102-L82-M701',
#  'MC044-B10/N172',
#  'MC044-B11/N182',
#  'MC044-B11/N65',
#  'MC061-B03/N4',
#  'MC051-B01/N1',
#  'MC061-B02/N1',
#  'MC003-L99/M304',
#  'MC044-B10/N155',
#  'MC044-L82-M794',
#  'MC044-L82-M830',
#  'MC065-B03/N1',
#  'MC102-L82-M867',
#  'MC011-L82-M953',
#  'MC044-L82-M835',
#  'MC044-B11/N69',
#  'MC078-B01/N2',
#  'MC044-B06/N1',
#  'MC044-B10/N116',
#  'MC000-L99/M203',
#  'MC103-B01/N11',
#  'MC046-L82-M736',
#  'MC202-B08/O1',
#  'MC065-B03/O1',
#  'MC044-B10/N43',
#  'MC045-L82-M777',
#  'MC010-L82-M772',
#  'MC045-L82-M779',
#  'MC044-B10/N202',
#  'MC045-B01/O1',
#  'MC065-B01/O3',
#  'MC070-L82-M969',
#  'MC204-B02/N4',
#  'MC044-B10/N3',
#  'MC207-B01/O2',
#  'MC102-L82-M712',
#  'MC044-B11/N180',
#  'MC065-B07/N7',
#  'MC044-L82-M820',
#  'MC102-L82-M881',
#  'MC044-B02/N3',
#  'MC044-B11/N151',
#  'MC102-L82-M715',
#  'MC044-B11/N6',
#  'MC126-L82-M931',
#  'MC071-L82-M919',
#  'MC044-B10/N44',
#  'MC065-L82-M935',
#  'MC065-B09/N8',
#  'MC078-B03/N8',
#  'MC044-B10/N104',
#  'MC044-B10/N49',
#  'MC046-L82-M737',
#  'MC078-B03/N5',
#  'MC014-B10/O2',
#  'MC204-B02/N1',
#  'MC044-B10/N120',
#  'MC044-B06/O1',
#  'MC078-B03/N6',
#  'MC044-B09/N6',
#  'MC044-L82-M834',
#  'OC006-B01/N1',
#  'MC070-B01/O1',
#  'MC065-B07/N10',
#  'MC010-L82-M768',
#  'MC032-L82-M773',
#  'MC044-B10/N33',
#  'MC044-B10/N156',
#  'MC044-B10/N74',
#  'MC044-L82-M817',
#  'MC044-L82-M844',
#  'MC045-L82-M786',
#  'MC061-B02/N5',
#  'MC065-B10/N1',
#  'MC032-B06/N2',
#  'MC211-L82-M865',
#  'MC044-B02/N1',
#  'MC044-B11/N115',
#  'MC044-L82-M836',
#  'MC072-B05/O2',
#  'MC044-B04/N14',
#  'MC070-L82-M965',
#  'MC200-B01/O1',
#  'MC044-B10/N7',
#  'MC044-B10/N105',
#  'MC032-B04/O1',
#  'MC044-B11/N49',
#  'MC065-B01/N8',
#  'MC202-B12/O1',
#  'MC044-L82-M824',
#  'MC044-B10/N39',
#  'MC065-B01/N5',
#  'MC044-B11/N83',
#  'MC044-B11/N103',
#  'MC044-B11/N58',
#  'MC065-B09/N7',
#  'MC044-B02/N6',
#  'MC070-L82-M934',
#  'MC072-B02/N17',
#  'MC207-L82-M845',
#  'MC044-B11/N131',
#  'MC044-B10/N106',
#  'MC207-L82-M852',
#  'MC047-L02/M888',
#  'MC044-L82-M797',
#  'MC061-B03/N16',
#  'MC204-B02/N8',
#  'MC044-B05/N6',
#  'MC014-B02/N1',
#  'MC032-B07/O2',
#  'MC044-B11/N28',
#  'MC065-B01/N4',
#  'MC065-B05/O3',
#  'MC014-B07/O2',
#  'MC207-L82-M849',
#  'MC044-L82-M823',
#  'MC072-B02/N6',
#  'MC044-B10/N87',
#  'MC044-B11/N25',
#  'MC070-B01/N1',
#  'MC197-L82-M890',
#  'MC198-B02/N1',
#  'MC070-L82-M966',
#  'MC072-B03/O1',
#  'MC202-B13/O1',
#  'MC044-B09/N11',
#  'MC075-B02/N1',
#  'MC044-B11/N128',
#  'MC044-B11/N7',
#  'MC044-B11/N16',
#  'MC001-L82-M973',
#  'MC044-B10/N118',
#  'MC044-B10/N76',
#  'MC044-B10/N96',
#  'MC071-B01/N1',
#  'MC044-B11/N154',
#  'MC044-B11/N107',
#  'MC044-B10/N201',
#  'MC045-L82-M947',
#  'MC044-B11/N75',
#  'MC044-B10/N107',
#  'MC044-B10/N31',
#  'MC072-B04/N3',
#  'MC010-L82-M759',
#  'MC044-B11/N89',
#  'MC044-B10/N27',
#  'MC065-L82-M937',
#  'MC078-B02/O1',
#  'MC044-B10/N69',
#  'MC078-B02/O2',
#  'MC010-L82-M766',
#  'MC044-B11/N99',
#  'MC044-B10/N62',
#  'MC044-B11/N54',
#  'MC044-B10/N54',
#  'MC044-L82-M806',
#  'MC014-B13/O2',
#  'MC044-B10/N15',
#  'MC046-B01/N1',
#  'MC065-B08/N8',
#  'MC010-L82-M749',
#  'MC061-B02/N3',
#  'MC001-L99/M306',
#  'MC070-B03/N1',
#  'MC207-B01/N1',
#  'MC014-B03/O3',
#  'MC044-B10/N152',
#  'MC072-B02/N16',
#  'MC065-B08/N3',
#  'MC200-L82-M940',
#  'MC007-L99/M211',
#  'MC011-B01/N1',
#  'MC072-B02/N14',
#  'MC065-B03/N2',
#  'MC001-L82-M972',
#  'MC044-L82-M827',
#  'MC044-B10/N28',
#  'MC044-L82-M825',
#  'MC063-L82-M955',
#  'MC032-B04/N1',
#  'MC014-B12/N1',
#  'MC044-B10/N193',
#  'MC044-L82-M809',
#  'MC044-B09/N10',
#  'MC045-L82-M951',
#  'MC044-B10/N59',
#  'MC102-L82-M717',
#  'MC045-L82-M785',
#  'MC204-B04/N1',
#  'MC197-L82-M893',
#  'MC044-B10/N132',
#  'MC044-B11/N50',
#  'MC078-B02/N1',
#  'MC072-B04/I5',
#  'MC065-B01/N3',
#  'MC202-B03/N1',
#  'MC044-B11/N91',
#  'MC044-B11/N105',
#  'MC044-B11/N76',
#  'MC204-B03/O1',
#  'MC067-B01/N1',
#  'MC044-B11/N127',
#  'MC207-L82-M847',
#  'MC207-L82-M850',
#  'MC065-L82-M902',
#  'MC032-B01/N2',
#  'MC065-B09/N11',
#  'MC033-L82-M898',
#  'MC044-B01/O1',
#  'MC044-B11/N32',
#  'MC044-B11/N68',
#  'MC061-B01/N3',
#  'MC065-B07/N8',
#  'MC044-B07/N4',
#  'MC044-B10/N167',
#  'MC044-B11/N135',
#  'MC044-B11/N35',
#  'MC044-L82-M799',
#  'MC071-L82-M918',
#  'MC076-B04/N1',
#  'MC044-B11/N187',
#  'MC102-L82-M884',
#  'MC204-B05/N1',
#  'MC207-L82-M854',
#  'MC065-B05/O1',
#  'MC204-B04/O1',
#  'MC044-B11/N134',
#  'MC044-B11/N45',
#  'MC061-B01/N5',
#  'MC202-B11/O1',
#  'MC204-B04/O5',
#  'MC044-B10/N183',
#  'MC044-B11/N163',
#  'MC102-L82-M719',
#  'MC044-B10/N8',
#  'MC102-L82-M877',
#  'MC204-L82-M957',
#  'MC102-L82-M883',
#  'MC044-B10/N194',
#  'MC044-L82-M815',
#  'MC001-L82-M974',
#  'MC014-B14/O3',
#  'MC032-B02/O3',
#  'MC044-L82-M842',
#  'MC044-B04/N10',
#  'MC044-B10/N77',
#  'MC075-L82-M946',
#  'MC102-L82-M875',
#  'MC043-B01/N10',
#  'MC014-B02/O2',
#  'MC044-B10/N207',
#  'MC044-B10/N110',
#  'MC061-B01/O3',
#  'MC207-L82-M851',
#  'MC198-B01/O2',
#  'MC061-B03/N5',
#  'MC044-B11/N112',
#  'MC044-B11/N33',
#  'MC061-B02/O2',
#  'MC055-B01/N1',
#  'MC065-L82-M906',
#  'MC202-B16/N2',
#  'MC063-B01/N1',
#  'MC197-L82-M895',
#  'MC044-B10/N180',
#  'MC044-L82-M796',
#  'MC044-B10/N217',
#  'MC003-B01/N1',
#  'MC046-L82-M744',
#  'MC044-B11/N122',
#  'MC044-B11/N62',
#  'MC044-B09/N4',
#  'MC063-B01/O2',
#  'MC014-B05/O2',
#  'MC044-B10/N141',
#  'MC044-B10/N18',
#  'MC202-B02/N1',
#  'MC065-B01/N2',
#  'MC044-B06/N3',
#  'MC061-B01/N2',
#  'MC014-B01/N1',
#  'MC044-B10/N140',
#  'MC065-L82-M910',
#  'MC207-L82-M855',
#  'MC065-B08/N7',
#  'MC065-B09/N5',
#  'MC044-B10/N151',
#  'MC044-B11/N110',
#  'MC032-B07/N1',
#  'MC103-B01/N10',
#  'MC204-B02/O6',
#  'MC044-L82-M808',
#  'MC044-L82-M841',
#  'MC204-B02/N2',
#  'MC078-B03/O1',
#  'MC072-B03/O3',
#  'MC070-B03/N2',
#  'MC010-L82-M753',
#  'MC044-B10/N211',
#  'MC202-B03/O1',
#  'MC044-B10/N84',
#  'MC044-B11/N22',
#  'MC044-B11/N116',
#  'MC202-B05/N1',
#  'MC044-B10/N40',
#  'MC065-L82-M913',
#  'MC010-L82-M745',
#  'OC004-L99/M512',
#  'MC044-B10/N185',
#  'MC044-B10/N57',
#  'MC044-B10/N91',
#  'MC044-B11/N1',
#  'MC044-B10/N35',
#  'MC044-B11/N139',
#  'MC044-B11/N130',
#  'MC072-B03/O2',
#  'MC202-B10/N1',
#  'MC044-B06/N6',
#  'MC044-B10/N34',
#  'MC044-B10/N111',
#  'MC033-B01/N1',
#  'EX001-B01/O3',
#  'MC044-B10/O2',
#  'MC010-L82-M761',
#  'MC045-L82-M949',
#  'MC204-B02/O2',
#  'MC044-B10/N89',
#  'MC065-B07/N9',
#  'MC202-B09/O1',
#  'MC010-L82-M748',
#  'MC044-B10/N171',
#  'MC065-B02/N1',
#  'MC044-B10/N181',
#  'MC044-B11/N34',
#  'MC061-B01/N6',
#  'MC044-B11/N117',
#  'MC072-B04/I3',
#  'MC044-B10/N186',
#  'MC044-B10/N135',
#  'MC044-B11/N140',
#  'MC045-L82-M793',
#  'MC202-B05/O1',
#  'MC072-B04/O1',
#  'MC061-B03/N2',
#  'MC001-B01/N1',
#  'MC044-B04/N3',
#  'MC014-B04/N1',
#  'MC032-B01/N6',
#  'MC044-B10/N37',
#  'MC065-B02/O2',
#  'MC065-B09/N9',
#  'MC102-L82-M866',
#  'MC055-B01/O5',
#  'EX001-B01/N1',
#  'MC048-B01/O1',
#  'MC044-B04/N11',
#  'MC044-B10/N55',
#  'MC065-B02/N2',
#  'MC044-B08/O2',
#  'MC072-B02/N21',
#  'MC202-B02/O1',
#  'MC207-L82-M846',
#  'MC065-L82-M909',
#  'MC045-B01/N1',
#  'MC207-L82-M857',
#  'MC211-L82-M863',
#  'MC044-B10/N215',
#  'MC044-B11/N12',
#  'MC045-B01/N6',
#  'MC014-B08/N1',
#  'MC044-B10/N112',
#  'MC065-B04/N1',
#  'MC202-B06/O1',
#  'MC045-L82-M792',
#  'MC202-B13/N2',
#  'MC204-B05/O6',
#  'MC202-B07/O1',
#  'MC044-B11/N63',
#  'OC005-L99/M505',
#  'MC044-L82-M810',
#  'MC065-B04/O1',
#  'MC103-B01/N3',
#  'MC061-B03/N12',
#  'MC200-L82-M941',
#  'MC202-B09/N1',
#  'MC044-B11/N43',
#  'MC044-B11/N80',
#  'MC010-L82-M769',
#  'MC001-L99/M100',
#  'MC010-L82-M760',
#  'MC044-B10/N85',
#  'MC044-L82-M814',
#  'MC014-B03/O2',
#  'MC044-B10/N137',
#  'MC044-B10/N117',
#  'MC044-B10/N58',
#  'MC044-B11/N31',
#  'MC065-B06/N8',
#  'MC045-L82-M776',
#  'MC065-B09/N2',
#  'MC045-L82-M950',
#  'EX001-B01/O1',
#  'OC004-B01/N1',
#  'MC044-B08/N6',
#  'MC044-B11/N66',
#  'MC061-B01/N4',
#  'MC204-B02/N3',
#  'MC044-B11/N108',
#  'MC043-B01/N6',
#  'MC102-L82-M882',
#  'MC046-B01/N4',
#  'MC044-B11/N148',
#  'MC065-B06/N5',
#  'MC044-B10/N82',
#  'MC044-B11/N160',
#  'MC078-B01/N1',
#  'MC044-B10/N36',
#  'MC102-L99/M309',
#  'MC044-B01/N6',
#  'MC070-L82-M971',
#  'MC010-L82-M746',
#  'MC071-L82-M920',
#  'MC204-B02/N7',
#  'MC007-L99/M511',
#  'MC044-B10/N90',
#  'MC044-B10/N47',
#  'MC065-B07/N3',
#  'MC044-B11/N46',
#  'MC044-B11/N92',
#  'MC044-B11/N97',
#  'MC072-B02/N7',
#  'MC102-L82-M708',
#  'MC044-B10/N123',
#  'MC197-L82-M892',
#  'OC006-L99/M200',
#  'MC044-B10/N4',
#  'MC011-B01/O2',
#  'MC014-B06/O2',
#  'AP000-L99/M303',
#  'MC044-B11/N172',
#  'MC045-B01/N3',
#  'MC065-B09/N1',
#  'MC072-B04/N4',
#  'MC044-B10/N12',
#  'MC011-L82-M954',
#  'MC061-B01/N1',
#  'MC204-B01/O1',
#  'MC044-B10/N50',
#  'MC075-B01/N1',
#  'MC072-B04/I6',
#  'MC044-B10/N79',
#  'MC044-B11/N184',
#  'MC065-B08/N5',
#  'MC044-L82-M840',
#  'MC061-B01/O2',
#  'MC044-B11/N124',
#  'MC202-B14/N1',
#  'MC044-B10/N142',
#  'MC197-L82-M891',
#  'MC044-B11/N27',
#  'MC044-B06/N4',
#  'MC204-B01/O6',
#  'MC070-L82-M968',
#  'MC044-B11/N169',
#  'MC102-L82-M869',
#  'MC001-L82-M976',
#  'MC078-B03/N3',
#  'MC044-B10/N81',
#  'MC044-L82-M813',
#  'MC102-L82-M700',
#  'MC044-B11/N159',
#  'MC044-B10/N6',
#  'MC044-B11/N2',
#  'MC197-L82-M897',
#  'MC014-B11/N1',
#  'MC044-B11/O2',
#  'MC204-B04/N2',
#  'MC044-B10/N127',
#  'MC044-B10/N218',
#  'MC204-B04/O3',
#  'MC204-B03/O3',
#  'MC014-B09/N1',
#  'MC044-B05/O2',
#  'MC044-B10/N98',
#  'MC044-B11/N47',
#  'MC010-L82-M756',
#  'MC044-B11/N143',
#  'MC065-B01/N6',
#  'MC072-B02/N22',
#  'MC202-B13/N1',
#  'MC204-B06/N3',
#  'MC204-B02/N9',
#  'MC044-B10/N102',
#  'MC200-B01/N2',
#  'MC044-B10/N164',
#  'MC044-L82-M838',
#  'AP000-L99/M308',
#  'MC044-B10/N65',
#  'MC044-B11/N10',
#  'MC065-L82-M915',
#  'MC044-B10/N56',
#  'MC044-B11/N77',
#  'MC078-B01/N7',
#  'MC204-B02/O4',
#  'MC044-B11/N121',
#  'MC044-B10/N124',
#  'MC010-L82-M765',
#  'MC044-B11/N158',
#  'MC070-B03/O2',
#  'MC078-B03/N1',
#  'MC046-L82-M741',
#  'MC197-L82-M896',
#  'MC044-B10/N75',
#  'MC010-L82-M762',
#  'MC032-B01/O1',
#  'MC044-B11/N5',
#  'MC044-B09/I3',
#  'MC055-B01/O6',
#  'MC044-B10/N101',
#  'MC044-B10/N97',
#  'MC044-B10/N149',
#  'MC061-B02/O3',
#  'MC014-B05/O3',
#  'MC070-B05/O1',
#  'MC044-B11/N123',
#  'MC204-B02/N5',
#  'MC044-B10/N205',
#  'MC078-B03/N4',
#  'MC044-B10/N41',
#  'MC076-B01/N1',
#  'MC010-L82-M751',
#  'MC044-B10/N176',
#  'MC072-B02/N10',
#  'MC014-B09/O2',
#  'MC044-B10/N139',
#  'MC044-B11/N70',
#  'MC065-B07/N1',
#  'MC044-B11/N36',
#  'MC071-B01/N2',
#  'MC200-L82-M938',
#  'MC044-B07/N7',
#  'MC077-B01/N1',
#  'MC044-L82-M807',
#  'MC204-B01/N2',
#  'MC043-B01/N11',
#  'MC070-L82-M962',
#  'MC061-B02/N2',
#  'MC063-B01/O3',
#  'MC044-B02/O3',
#  'MC044-B11/N4',
#  'MC078-B01/N4',
#  'MC207-L82-M853',
#  'MC044-B11/N37',
#  'MC102-L82-M887',
#  'MC014-B13/N1',
#  'MC044-B10/N157',
#  'MC003-L99/M207',
#  'MC044-B10/N32',
#  'MC044-L82-M801',
#  'MC046-L82-M743',
#  'MC065-L82-M936',
#  'MC070-L82-M970',
#  'MC044-B11/N174',
#  'MC045-L82-M781',
#  'MC065-B09/N12',
#  'MC044-B11/N126',
#  'MC044-B10/N154',
#  'MC044-B10/N136',
#  'MC044-B10/N48',
#  'MC044-B11/N55',
#  'MC061-B03/N6',
#  'MC044-B10/N72',
#  'MC065-B09/N15',
#  'MC204-B02/N11',
#  'MC065-B09/N14',
#  'MC075-L82-M943',
#  'MC044-B10/N158',
#  'MC102-L82-M706',
#  'MC014-B05/N1',
#  'MC202-B06/N1',
#  'MC014-B09/O3',
#  'MC045-L82-M784',
#  'MC102-L82-M716',
#  'MC204-B03/N1',
#  'MC207-B01/O3',
#  'OC004-L99/M206',
#  'MC078-B01/O2',
#  'EX001-B01/O2',
#  'MC044-B10/N192',
#  'MC044-B10/N2',
#  'MC044-B11/N67',
#  'MC044-B11/N93',
#  'MC044-B09/N3',
#  'MC072-B01/N1',
#  'MC078-B03/O2',
#  'MC072-B02/N1',
#  'MC008-L82-M916',
#  'MC044-B03/O3',
#  'MC044-B04/N12',
#  'MC044-B11/N14',
#  'MC044-B11/N153',
#  'MC044-B11/N40',
#  'MC044-B02/O1',
#  'MC032-B02/N1',
#  'MC065-L82-M900',
#  'MC202-B08/N1',
#  'MC044-B11/N73',
#  'MC044-B10/N99',
#  'MC044-B10/N42',
#  'OC006-L99/M503',
#  'MC044-B07/N2',
#  'MC102-L82-M868',
#  'MC044-B11/N144',
#  'MC044-B11/N60',
#  'MC044-B10/N174',
#  'MC065-B08/N1',
#  'MC044-B10/N191',
#  'MC072-B04/I4',
#  'MC202-B01/N1',
#  'MC061-B02/O1',
#  'MC044-B09/N9',
#  'MC014-B07/N1',
#  'MC044-B10/N197',
#  'MC044-B10/N113',
#  'MC031-B02/O2',
#  'MC044-L82-M819',
#  'MC202-B07/N1',
#  'MC014-B03/N1',
#  'MC044-L82-M843',
#  'MC078-B01/O1',
#  'MC044-B10/N80',
#  'MC044-L82-M839',
#  'MC045-L82-M782',
#  'MC000-L99/M202',
#  'MC204-B01/N3',
#  'MC204-B01/O3',
#  'MC044-B11/N171',
#  'MC044-B11/N48',
#  'MC044-B10/N51',
#  'MC044-B11/N18',
#  'MC065-B05/N2',
#  'MC044-B10/N175',
#  'MC044-B11/N129',
#  'MC061-B03/N1',
#  'MC010-L82-M767',
#  'MC044-B10/N10',
#  'MC204-B06/O2',
#  'MC061-B03/N8',
#  'MC044-L82-M816',
#  'MC044-B07/N3',
#  'MC204-B02/O1',
#  'MC044-B10/N9',
#  'MC044-B10/N143',
#  'MC044-B10/N219',
#  'MC044-B01/O2',
#  'MC044-B10/N66',
#  'MC044-B11/N59',
#  'MC200-B01/N1',
#  'MC044-L82-M803',
#  'MC044-B11/N165',
#  'MC044-B11/N61',
#  'MC001-L99/M224',
#  'MC072-B02/N5',
#  'MC044-B11/N95',
#  'MC044-B11/O1',
#  'MC065-B09/N3',
#  'MC044-B11/N125',
#  'MC044-B11/N167',
#  'MC103-L99/M216',
#  'MC044-L82-M795',
#  'MC044-B10/N134',
#  'AP080-L79/M001',
#  'MC065-B06/N1',
#  'AP080-L81/M001',
#  'MC014-B04/O2',
#  'MC065-L82-M903',
#  'MC044-B05/N2',
#  'MC078-B03/N7',
#  'MC044-B10/N173',
#  'MC207-L82-M848',
#  'MC044-B10/N188',
#  'MC043-B01/N3',
#  'MC044-B11/N96',
#  'MC061-B02/N9',
#  'MC032-B01/N3',
#  'MC065-L82-M911',
#  'MC044-B03/N6',
#  'MC044-B10/N63',
#  'MC103-B01/N1',
#  'MC202-B16/N1',
#  'MC044-L82-M818',
#  'MC044-B10/N138',
#  'MC044-B11/N57',
#  'MC065-B08/N2',
#  'MC129-L82-M922',
#  'MC044-B10/O3',
#  'MC044-B11/N179',
#  'MC044-B11/N72',
#  'MC044-B07/N5',
#  'MC044-B10/N68',
#  'MC044-B11/N162',
#  'MC065-B04/O3',
#  'MC078-B03/N9',
#  'MC044-B12/N1',
#  'MC044-B10/N198',
#  'MC044-B10/N46',
#  'MC061-B03/N14',
#  'MC014-B13/O3',
#  'MC014-B04/O3',
#  'MC044-B11/N161',
#  'MC010-L82-M750',
#  'MC065-B04/O2',
#  'MC202-B15/O1',
#  'MC045-L82-M791',
#  'MC044-B11/N164',
#  'MC102-L82-M871',
#  'MC044-B11/N119',
#  'MC055-B01/O7',
#  'MC001-L99/M508',
#  'MC065-B01/O1',
#  'MC044-B10/N169',
#  'MC204-B04/O4',
#  'MC044-B10/N159',
#  'MC044-B11/N64',
#  'MC044-B10/N67',
#  'MC204-L99/M312',
#  'MC078-B01/N5',
#  'MC032-L82-M774',
#  'MC044-B10/N88',
#  'MC044-B10/N71',
#  'MC044-B10/N170',
#  'MC044-B04/N13',
#  'MC202-B11/N1',
#  'MC204-B01/O5',
#  'MC044-L82-M821',
#  'MC048-B01/N1',
#  'MC044-B10/N179',
#  'MC061-B03/N10',
#  'MC044-B03/N1',
#  'MC044-B10/N73',
#  'MC044-B10/N133',
#  'MC044-B11/N87',
#  'MC102-L82-M709',
#  'MC044-L82-M837',
#  'MC202-B12/N1',
#  'MC044-B11/N29',
#  'MC044-B10/N131',
#  'MC044-L82-M798',
#  'MC044-B12/O1',
#  'MC044-B08/N1',
#  'MC014-B06/O3',
#  'MC044-B11/N39',
#  'MC065-B01/N7',
#  'MC126-L82-M930',
#  'MC044-B10/N214',
#  'MC204-B02/N6',
#  'MC072-B02/N15',
#  'MC044-B11/N20',
#  'MC044-L82-M833',
#  'MC031-B02/N1',
#  'MC044-B11/N176',
#  'MC072-B05/O3',
#  'MC044-B10/N14',
#  'MC211-L82-M862',
#  'MC000-L99/M201',
#  'MC044-B11/N132',
#  'MC044-B10/N125',
#  'MC070-B02/O2',
#  'MC044-B11/N38',
#  'MC045-B01/I8',
#  'OC005-L99/M204',
#  'MC044-B11/N86',
#  'MC044-B11/N114',
#  'MC044-B11/N177',
#  'MC065-B06/N2',
#  'MC014-B02/O3',
#  'MC044-B10/N103',
#  'MC044-B10/N146',
#  'MC044-B11/N19',
#  'MC044-B11/N156',
#  'MC070-L82-M960',
#  'MC044-B11/N79',
#  'MC044-B10/N162',
#  'MC010-L82-M764',
#  'MC045-L82-M952',
#  'MC044-B10/N86',
#  'MC044-B10/N25',
#  'MC061-B02/N8',
#  'MC204-B06/O1',
#  'MC065-B06/N6',
#  'MC044-B10/N177',
#  'MC061-B03/N15',
#  'MC010-L82-M747',
#  'MC044-B10/N121',
#  'MC044-B10/N163',
#  'MC044-B11/N183',
#  'MC044-B10/N204',
#  'MC044-B05/N1',
#  'MC044-B11/N120',
#  'MC008-L99/M302',
#  'MC202-B01/O1',
#  'MC131-L82-M924',
#  'OC005-B01/N1',
#  'MC046-L82-M740',
#  'MC044-B10/N203',
#  'MC045-L82-M783',
#  'MC065-B01/N1',
#  'MC065-B06/N3',
#  'MC065-B06/N4',
#  'MC065-B08/N6',
#  'MC044-B10/N100',
#  'MC045-L82-M790',
#  'MC044-B11/N173',
#  'MC044-B10/N95',
#  'MC070-B06/N1',
#  'MC044-B11/O3',
#  'MC070-L82-M963',
#  'MC070-L82-M964',
#  'MC204-B05/N2',
#  'MC072-B02/N19',
#  'MC197-L82-M888',
#  'MC044-B01/N2',
#  'MC001-L82-M975',
#  'MC102-L82-M870',
#  'MC202-B14/N2',
#  'MC044-B10/N114',
#  'MC044-B10/N165',
#  'MC044-B11/N138',
#  'MC211-L82-M861',
#  'MC044-B10/N145',
#  'MC044-B11/N101',
#  'MC044-B11/N90',
#  'MC032-B03/O1',
#  'MC044-B11/N157',
#  'MC044-B11/N142',
#  'AP080-L80/M001',
#  'MC044-B10/N119',
#  'MC204-B02/O3',
#  'MC044-B11/N149',
#  'MC014-B07/O3',
#  'MC061-B03/N11',
#  'MC078-B03/N2',
#  'MC204-B04/O6',
#  'MC044-B10/N161',
#  'MC044-B03/O2',
#  'MC044-B11/N9',
#  'MC211-L82-M864',
#  'MC044-B10/N147',
#  'MC102-L82-M885',
#  'MC044-B02/N2',
#  'MC014-B11/O3',
#  'MC010-L82-M755',
#  'MC045-L82-M948',
#  'MC044-B10/N200',
#  'MC061-B03/N3',
#  'MC066-B01/N1',
#  'MC044-B10/N182',
#  'MC014-B08/O2',
#  'MC044-B11/N109',
#  'MC010-L82-M757',
#  'MC044-B11/N113',
#  'MC044-B11/N166',
#  'MC044-B10/N16',
#  'MC044-B11/N104',
#  'MC044-B11/N186',
#  'MC045-L82-M780',
#  'MC078-B02/N2',
#  'MC044-B09/N8',
#  'MC078-B03/N11',
#  'MC102-L82-M707',
#  'MC204-B06/O5',
#  'MC102-L82-M703',
#  'MC204-L82-M956',
#  ...}

# %%
(set([i[:5] for i in meterssensors_not_in_planon]))
# Out:
# {'AP000',
#  'AP080',
#  'EX001',
#  'MC000',
#  'MC001',
#  'MC003',
#  'MC007',
#  'MC008',
#  'MC010',
#  'MC011',
#  'MC014',
#  'MC029',
#  'MC030',
#  'MC031',
#  'MC032',
#  'MC033',
#  'MC043',
#  'MC044',
#  'MC045',
#  'MC046',
#  'MC047',
#  'MC048',
#  'MC051',
#  'MC055',
#  'MC061',
#  'MC063',
#  'MC065',
#  'MC066',
#  'MC067',
#  'MC070',
#  'MC071',
#  'MC072',
#  'MC075',
#  'MC076',
#  'MC077',
#  'MC078',
#  'MC083',
#  'MC102',
#  'MC103',
#  'MC125',
#  'MC126',
#  'MC128',
#  'MC129',
#  'MC131',
#  'MC197',
#  'MC198',
#  'MC200',
#  'MC202',
#  'MC204',
#  'MC207',
#  'MC210',
#  'MC211',
#  'OC004',
#  'OC005',
#  'OC006'}

# %%
a=np.sort(list(set(planon_meterssensors_filtered.index)))
b=np.sort(list(set(master_meterssensors_for_validation_filtered.index)))
meterssensors_not_in_master=[]
for i in a:
    if i not in b:
        print(i+',',end=" "),
        meterssensors_not_in_master.append(i)
print('\n\nMeters in Planon, not in Master:',
      len(meterssensors_not_in_master),'/',len(a),':',
      round(len(meterssensors_not_in_master)/len(a)*100,3),'%')
# Out:
# Meters in Planon, not in Master: 0 / 28824 : 0.0 %

# %%
len(set([i for i in meterssensors_not_in_master]))
# Out:
# 0

# %%
set([i[:9] for i in meterssensors_not_in_master])
# Out:
# set()

# %%
set([i[:5] for i in meterssensors_not_in_master])
# Out:
# set()

# %% [markdown]
# Check for duplicates in index, but not duplicates over the entire row

# %%
print(len(planon_meterssensors_filtered.index))
print(len(set(planon_meterssensors_filtered.index)))
print(len(master_meterssensors_for_validation_filtered.index))
print(len(set(master_meterssensors_for_validation_filtered.index)))
# Out:
# 28824
# 28824
# 30567
# 30135

# %%
master_meterssensors_for_validation_filtered[master_meterssensors_for_validation_filtered.index.duplicated()]
# Out:
#                                           Building Name Tenant meter  \
# MC011-B01/I1                             The Roundhouse        False
# MC011-B01/I2                             The Roundhouse        False
# MC011-B01/O1                             The Roundhouse        False
# MC014-B01/O1                               Bowland Hall        False
# MC014-B02/O1                               Bowland Hall        False
# MC014-B03/O1                               Bowland Hall        False
# MC014-B04/O1                               Bowland Hall        False
# MC014-B05/O1                               Bowland Hall        False
# MC014-B06/O1                               Bowland Hall        False
# MC014-B07/O1                               Bowland Hall        False
# MC014-B08/O1                               Bowland Hall        False
# MC014-B09/O1                               Bowland Hall        False
# MC014-B10/O1                               Bowland Hall        False
# MC014-B11/O1                               Bowland Hall        False
# MC014-B12/O1                               Bowland Hall        False
# MC014-B13/O1                               Bowland Hall        False
# MC014-B14/O1                               Bowland Hall        False
# MC031-B01/I1                                 Great Hall        False
# MC031-B01/I2                                 Great Hall        False
# MC031-B01/I3                                 Great Hall        False
# MC031-B01/I4                                 Great Hall        False
# MC031-B02/I1                                 Great Hall        False
# MC031-B02/I2                                 Great Hall        False
# MC032-B01/I1                               County South        False
# MC032-B01/I2                               County South        False
# MC032-B01/I3                               County South        False
# MC032-B01/I4                               County South        False
# MC032-B01/I5                               County South        False
# MC032-B02/I1                               County South        False
# MC032-B02/I2                               County South        False
# ...                                                 ...          ...
# MC210-B01/I5                       Engineering Building        False
# MC210-B01/I6                       Engineering Building        False
# MC210-B01/I7                       Engineering Building        False
# MC210-B01/I8                       Engineering Building        False
# MC210-B01/I9                       Engineering Building        False
# MC210-B01/N1                       Engineering Building        False
# MC210-B02/I1                       Engineering Building        False
# MC210-B02/I2                       Engineering Building        False
# MC210-B02/I3                       Engineering Building        False
# MC210-B02/N1                       Engineering Building        False
# MC210-B03/I1                       Engineering Building        False
# MC210-B03/I10                      Engineering Building        False
# MC210-B03/I11                      Engineering Building        False
# MC210-B03/I12                      Engineering Building        False
# MC210-B03/I13                      Engineering Building        False
# MC210-B03/I14                      Engineering Building        False
# MC210-B03/I2                       Engineering Building        False
# MC210-B03/I3                       Engineering Building        False
# MC210-B03/I4                       Engineering Building        False
# MC210-B03/I5                       Engineering Building        False
# MC210-B03/I6                       Engineering Building        False
# MC210-B03/I7                       Engineering Building        False
# MC210-B03/I8                       Engineering Building        False
# MC210-B03/I9                       Engineering Building        False
# MC210-B03/N1                       Engineering Building        False
# MC211-B01/I1   Life Sciences & Environment Laboratories        False
# MC211-B01/I2   Life Sciences & Environment Laboratories        False
# MC211-B01/I3   Life Sciences & Environment Laboratories        False
# MC211-B01/I4   Life Sciences & Environment Laboratories        False
# MC211-B01/O1   Life Sciences & Environment Laboratories        False
#
#               Logger Channel Building Code Fiscal meter  \
# MC011-B01/I1              I1         MC011        False
# MC011-B01/I2              i2         MC011        False
# MC011-B01/O1              o1         MC011        False
# MC014-B01/O1              o1         MC014        False
# MC014-B02/O1              O1         MC014        False
# MC014-B03/O1              O1         MC014        False
# MC014-B04/O1              o1         MC014        False
# MC014-B05/O1              o1         MC014        False
# MC014-B06/O1              o1         MC014        False
# MC014-B07/O1              o1         MC014        False
# MC014-B08/O1              O1         MC014        False
# MC014-B09/O1              o1         MC014        False
# MC014-B10/O1              O1         MC014        False
# MC014-B11/O1              o1         MC014        False
# MC014-B12/O1              o1         MC014        False
# MC014-B13/O1              o1         MC014        False
# MC014-B14/O1              O1         MC014        False
# MC031-B01/I1              i1         MC031        False
# MC031-B01/I2              I2         MC031        False
# MC031-B01/I3              i3         MC031        False
# MC031-B01/I4              i4         MC031        False
# MC031-B02/I1              i1         MC031        False
# MC031-B02/I2              i2         MC031        False
# MC032-B01/I1              I1         MC032        False
# MC032-B01/I2              i2         MC032        False
# MC032-B01/I3              i3         MC032        False
# MC032-B01/I4              i4         MC032        False
# MC032-B01/I5              i5         MC032        False
# MC032-B02/I1              i1         MC032        False
# MC032-B02/I2              i2         MC032        False
# ...                      ...           ...          ...
# MC210-B01/I5              i5         MC210        False
# MC210-B01/I6              I6         MC210        False
# MC210-B01/I7              I7         MC210        False
# MC210-B01/I8              I8         MC210        False
# MC210-B01/I9              I9         MC210        False
# MC210-B01/N1              N1         MC210        False
# MC210-B02/I1              I1         MC210        False
# MC210-B02/I2              i2         MC210        False
# MC210-B02/I3              I3         MC210        False
# MC210-B02/N1              n1         MC210        False
# MC210-B03/I1              i1         MC210        False
# MC210-B03/I10            I10         MC210        False
# MC210-B03/I11            i11         MC210        False
# MC210-B03/I12            i12         MC210        False
# MC210-B03/I13            I13         MC210        False
# MC210-B03/I14            I14         MC210        False
# MC210-B03/I2              i2         MC210        False
# MC210-B03/I3              I3         MC210        False
# MC210-B03/I4              i4         MC210        False
# MC210-B03/I5              I5         MC210        False
# MC210-B03/I6              I6         MC210        False
# MC210-B03/I7              I7         MC210        False
# MC210-B03/I8              i8         MC210        False
# MC210-B03/I9              i9         MC210        False
# MC210-B03/N1              n1         MC210        False
# MC211-B01/I1              I1         MC211        False
# MC211-B01/I2              I2         MC211        False
# MC211-B01/I3              I3         MC211        False
# MC211-B01/I4              i4         MC211        False
# MC211-B01/O1              O1         MC211        False
#
#                                 Description           Code
# MC011-B01/I1              Fire alarm active   MC011-B01/I1
# MC011-B01/I2                   xcite/IO/8DO   MC011-B01/i2
# MC011-B01/O1                  Alarm Route 1   MC011-B01/o1
# MC014-B01/O1                  Alarm Route 1   MC014-B01/o1
# MC014-B02/O1                  Heating times   MC014-B02/O1
# MC014-B03/O1                  Heating times   MC014-B03/O1
# MC014-B04/O1                  Alarm Route 1   MC014-B04/o1
# MC014-B05/O1                  Alarm Route 1   MC014-B05/o1
# MC014-B06/O1                  Alarm Route 1   MC014-B06/o1
# MC014-B07/O1                  Alarm Route 1   MC014-B07/o1
# MC014-B08/O1                  Heating times   MC014-B08/O1
# MC014-B09/O1                  Alarm Route 1   MC014-B09/o1
# MC014-B10/O1                  Heating times   MC014-B10/O1
# MC014-B11/O1                  Alarm Route 1   MC014-B11/o1
# MC014-B12/O1                  Alarm Route 1   MC014-B12/o1
# MC014-B13/O1                  Alarm Route 1   MC014-B13/o1
# MC014-B14/O1                  Heating times   MC014-B14/O1
# MC031-B01/I1                   xcite/IO/4UI   MC031-B01/i1
# MC031-B01/I2            Heating Pump Status   MC031-B01/I2
# MC031-B01/I3                   xcite/IO/4DO   MC031-B01/i3
# MC031-B01/I4                   xcite/IO/8DI   MC031-B01/i4
# MC031-B02/I1                       Module 1   MC031-B02/i1
# MC031-B02/I2                       Module 2   MC031-B02/i2
# MC032-B01/I1           Fire Alarm Activated   MC032-B01/I1
# MC032-B01/I2                     IQ4/IO/8UI   MC032-B01/i2
# MC032-B01/I3                     IQ4/IO/8DI   MC032-B01/i3
# MC032-B01/I4                     IQ4/IO/4DO   MC032-B01/i4
# MC032-B01/I5                     IQ4/IO/8DO   MC032-B01/i5
# MC032-B02/I1                       Module 1   MC032-B02/i1
# MC032-B02/I2                       Module 2   MC032-B02/i2
# ...                                     ...            ...
# MC210-B01/I5                   xcite/IO/8DO   MC210-B01/i5
# MC210-B01/I6        Lift Status - Car Alarm   MC210-B01/I6
# MC210-B01/I7     Lift Status - Common Fault   MC210-B01/I7
# MC210-B01/I8    Lift Status - Maint Control   MC210-B01/I8
# MC210-B01/I9    PHE Sec Pump P1a Flow Prove   MC210-B01/I9
# MC210-B01/N1                     IC Comms 1   MC210-B01/N1
# MC210-B02/I1           Winter Switch Active   MC210-B02/I1
# MC210-B02/I2                   xcite/IO/8UI   MC210-B02/i2
# MC210-B02/I3          Holiday Switch Active   MC210-B02/I3
# MC210-B02/N1                         MCP01b   MC210-B02/n1
# MC210-B03/I1                   xcite/IO/8UI   MC210-B03/i1
# MC210-B03/I10                  B30 Override  MC210-B03/I10
# MC210-B03/I11                  xcite/IO/8DO  MC210-B03/i11
# MC210-B03/I12                  xcite/IO/8AO  MC210-B03/i12
# MC210-B03/I13                  B31 Override  MC210-B03/I13
# MC210-B03/I14                  B04 Override  MC210-B03/I14
# MC210-B03/I2                   xcite/IO/8UI   MC210-B03/i2
# MC210-B03/I3      Nitrogen Generation Alarm   MC210-B03/I3
# MC210-B03/I4                   xcite/IO/8UI   MC210-B03/i4
# MC210-B03/I5   A04a&amp;b Extract Fan Fault   MC210-B03/I5
# MC210-B03/I6     ChemEngLab Condenser Fault   MC210-B03/I6
# MC210-B03/I7     NuclearLab Condenser Fault   MC210-B03/I7
# MC210-B03/I8                   xcite/IO/8AO   MC210-B03/i8
# MC210-B03/I9                   xcite/IO/8DO   MC210-B03/i9
# MC210-B03/N1                         MCP01c   MC210-B03/n1
# MC211-B01/I1         Heating Press. Unit LP   MC211-B01/I1
# MC211-B01/I2           Boundary Water Meter   MC211-B01/I2
# MC211-B01/I3           Incoming Water Meter   MC211-B01/I3
# MC211-B01/I4                   xcite/IO/4AO   MC211-B01/i4
# MC211-B01/O1           Optimum Start Stop 1   MC211-B01/O1
#
# [432 rows x 7 columns]

# %% [markdown]
# The duplicates are the `nan`s. Remove these for now. Could revisit later to do an index-less comparison, only over row contents.

# %%
good_index=[i for i in master_meterssensors_for_validation_filtered.index if str(i).lower().strip()!='nan']
master_meterssensors_for_validation_filtered=master_meterssensors_for_validation_filtered.loc[good_index]
master_meterssensors_for_validation_filtered.drop_duplicates(inplace=True)

# %%
len(planon_meterssensors_filtered)
# Out:
# 28824

# %%
len(master_meterssensors_for_validation_filtered)
# Out:
# 30567

# %% [markdown]
# Do comparison only on common indices. Need to revisit and identify the cause missing meters, both ways (5 Planon->Meters and 30 Meters->Planon in this example).

# %%
comon_index=list(set(master_meterssensors_for_validation_filtered.index).intersection(set(planon_meterssensors_filtered.index)))

# %%
len(comon_index)
# Out:
# 28824

# %%
master_meterssensors_for_validation_intersected=master_meterssensors_for_validation_filtered.loc[comon_index].sort_index()
planon_meterssensors_intersected=planon_meterssensors_filtered.loc[comon_index].sort_index()

# %%
len(master_meterssensors_for_validation_intersected)
# Out:
# 29180

# %%
len(planon_meterssensors_intersected)
# Out:
# 28824

# %% [markdown]
# Still have duplicate indices. For now we just drop and keep the first.

# %%
master_meterssensors_for_validation_intersected = master_meterssensors_for_validation_intersected[~master_meterssensors_for_validation_intersected.index.duplicated(keep='first')]

# %%
master_meterssensors_for_validation_intersected.head(2)
# Out:
#                  Building Name Tenant meter Logger Channel Building Code  \
# AP000-L01/M001  Alexandra Park        False              1         AP000
# AP000-L02/M001  Alexandra Park        False              1         AP000
#
#                Fiscal meter          Description            Code
# AP000-L01/M001        False                  NaN  AP000-L01/M001
# AP000-L02/M001        False  Graduate House 1-11  AP000-L02/M001

# %%
planon_meterssensors_intersected.head(2)
# Out:
#                  Building Name Tenant meter Logger Channel Building Code  \
# AP000-L01/M001  Alexandra Park        False              1         AP000
# AP000-L02/M001  Alexandra Park        False              1         AP000
#
#                Fiscal meter          Description            Code
# AP000-L01/M001        False                  NaN  AP000-L01/M001
# AP000-L02/M001        False  Graduate House 1-11  AP000-L02/M001

# %% [markdown]
# #### 2.1.2. Primitive comparison

# %%
planon_meterssensors_intersected==master_meterssensors_for_validation_intersected
# Out:
#                Building Name Tenant meter Logger Channel Building Code  \
# AP000-L01/M001          True         True           True          True
# AP000-L02/M001          True         True           True          True
# AP000-L02/M002          True         True           True          True
# AP000-L03/M001          True         True           True          True
# AP000-L03/M002          True         True           True          True
# AP001-L01/M001         False         True           True          True
# AP001-L01/M002         False         True           True          True
# AP001-L01/M003         False         True           True          True
# AP001-L01/M004         False         True           True          True
# AP001-L01/M005         False         True           True          True
# AP001-L01/M006         False         True           True          True
# AP009-L01/M001         False         True           True          True
# AP009-L01/M002         False         True           True          True
# AP009-L01/M003         False         True           True          True
# AP010-L01/M001         False         True           True          True
# AP010-L01/M002         False         True           True          True
# AP010-L01/M003         False         True           True          True
# AP010-L01/M004         False         True           True          True
# AP010-L01/M005         False         True           True          True
# AP011-L01/M001         False         True           True          True
# AP011-L01/M002         False         True           True          True
# AP011-L01/M003         False         True           True          True
# AP011-L01/M004         False         True           True          True
# AP057-L01/M001          True         True           True          True
# AP057-L01/M002          True         True           True          True
# AP057-L01/M003          True         True           True          True
# AP080-L01/M001          True         True           True          True
# AP080-L01/M002          True         True           True          True
# AP080-L01/M003          True         True           True          True
# AP081-L01/M001          True         True           True          True
# ...                      ...          ...            ...           ...
# OC006-B01/S21           True         True           True          True
# OC006-B01/S22           True         True           True          True
# OC006-B01/S23           True         True           True          True
# OC006-B01/S24           True         True           True          True
# OC006-B01/S25           True         True           True          True
# OC006-B01/S26           True         True           True          True
# OC006-B01/S27           True         True           True          True
# OC006-B01/S28           True         True           True          True
# OC006-B01/S29           True         True           True          True
# OC006-B01/S3            True         True           True          True
# OC006-B01/S4            True         True           True          True
# OC006-B01/S5            True         True           True          True
# OC006-B01/S6            True         True           True          True
# OC006-B01/S8            True         True           True          True
# OC006-B01/S9            True         True           True          True
# OC006-B01/V1            True         True           True          True
# OC006-B01/W1            True         True           True          True
# OC006-B01/W10           True         True           True          True
# OC006-B01/W2            True         True           True          True
# OC006-B01/W3            True         True           True          True
# OC006-B01/W4            True         True           True          True
# OC006-B01/W5            True         True           True          True
# OC006-B01/Y1            True         True           True          True
# OC006-B01/Y2            True         True           True          True
# OC006-B01/Y3            True         True           True          True
# OC006-B01/Y4            True         True           True          True
# OC006-B01/Y5            True         True           True          True
# OC006-B01/Y6            True         True           True          True
# OC006-B01/Z1            True         True           True          True
# OC006-B01/Z2            True         True           True          True
#
#                Fiscal meter Description  Code
# AP000-L01/M001         True       False  True
# AP000-L02/M001         True        True  True
# AP000-L02/M002         True        True  True
# AP000-L03/M001         True       False  True
# AP000-L03/M002         True       False  True
# AP001-L01/M001         True       False  True
# AP001-L01/M002         True       False  True
# AP001-L01/M003         True       False  True
# AP001-L01/M004         True       False  True
# AP001-L01/M005         True        True  True
# AP001-L01/M006         True        True  True
# AP009-L01/M001         True        True  True
# AP009-L01/M002         True        True  True
# AP009-L01/M003         True       False  True
# AP010-L01/M001         True        True  True
# AP010-L01/M002         True        True  True
# AP010-L01/M003         True        True  True
# AP010-L01/M004         True        True  True
# AP010-L01/M005         True        True  True
# AP011-L01/M001         True        True  True
# AP011-L01/M002         True        True  True
# AP011-L01/M003         True        True  True
# AP011-L01/M004         True        True  True
# AP057-L01/M001         True       False  True
# AP057-L01/M002         True        True  True
# AP057-L01/M003         True        True  True
# AP080-L01/M001         True       False  True
# AP080-L01/M002         True        True  True
# AP080-L01/M003         True        True  True
# AP081-L01/M001         True       False  True
# ...                     ...         ...   ...
# OC006-B01/S21          True        True  True
# OC006-B01/S22          True        True  True
# OC006-B01/S23          True        True  True
# OC006-B01/S24          True        True  True
# OC006-B01/S25          True        True  True
# OC006-B01/S26          True        True  True
# OC006-B01/S27          True        True  True
# OC006-B01/S28          True        True  True
# OC006-B01/S29          True        True  True
# OC006-B01/S3           True        True  True
# OC006-B01/S4           True        True  True
# OC006-B01/S5           True        True  True
# OC006-B01/S6           True        True  True
# OC006-B01/S8           True        True  True
# OC006-B01/S9           True        True  True
# OC006-B01/V1           True       False  True
# OC006-B01/W1           True        True  True
# OC006-B01/W10          True        True  True
# OC006-B01/W2           True        True  True
# OC006-B01/W3           True        True  True
# OC006-B01/W4           True        True  True
# OC006-B01/W5           True        True  True
# OC006-B01/Y1           True        True  True
# OC006-B01/Y2           True        True  True
# OC006-B01/Y3           True        True  True
# OC006-B01/Y4           True        True  True
# OC006-B01/Y5           True        True  True
# OC006-B01/Y6           True        True  True
# OC006-B01/Z1           True        True  True
# OC006-B01/Z2           True        True  True
#
# [28824 rows x 7 columns]

# %%
np.all(planon_meterssensors_intersected==master_meterssensors_for_validation_intersected)
# Out:
# False

# %% [markdown]
# #### 2.1.3. Horizontal comparison

# %% [markdown]
# Number of cells matching

# %%
(planon_meterssensors_intersected==master_meterssensors_for_validation_intersected).sum()
# Out:
# Building Name     28295
# Tenant meter      28824
# Logger Channel    28663
# Building Code     28824
# Fiscal meter      28824
# Description       27275
# Code              28663
# dtype: int64

# %% [markdown]
# Percentage matching

# %%
(planon_meterssensors_intersected==master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100
# Out:
# Building Name      98.164724
# Tenant meter      100.000000
# Logger Channel     99.441438
# Building Code     100.000000
# Fiscal meter      100.000000
# Description        94.626006
# Code               99.441438
# dtype: float64

# %%
((planon_meterssensors_intersected==master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100).plot(kind='bar')

# %% [markdown]
# #### 2.1.4. Vertical comparison

# %%
df=pd.DataFrame((planon_meterssensors_intersected.T==master_meterssensors_for_validation_intersected.T).sum())
df
# Out:
#                 0
# AP000-L01/M001  6
# AP000-L02/M001  7
# AP000-L02/M002  7
# AP000-L03/M001  6
# AP000-L03/M002  6
# AP001-L01/M001  5
# AP001-L01/M002  5
# AP001-L01/M003  5
# AP001-L01/M004  5
# AP001-L01/M005  6
# AP001-L01/M006  6
# AP009-L01/M001  6
# AP009-L01/M002  6
# AP009-L01/M003  5
# AP010-L01/M001  6
# AP010-L01/M002  6
# AP010-L01/M003  6
# AP010-L01/M004  6
# AP010-L01/M005  6
# AP011-L01/M001  6
# AP011-L01/M002  6
# AP011-L01/M003  6
# AP011-L01/M004  6
# AP057-L01/M001  6
# AP057-L01/M002  7
# AP057-L01/M003  7
# AP080-L01/M001  6
# AP080-L01/M002  7
# AP080-L01/M003  7
# AP081-L01/M001  6
# ...            ..
# OC006-B01/S21   7
# OC006-B01/S22   7
# OC006-B01/S23   7
# OC006-B01/S24   7
# OC006-B01/S25   7
# OC006-B01/S26   7
# OC006-B01/S27   7
# OC006-B01/S28   7
# OC006-B01/S29   7
# OC006-B01/S3    7
# OC006-B01/S4    7
# OC006-B01/S5    7
# OC006-B01/S6    7
# OC006-B01/S8    7
# OC006-B01/S9    7
# OC006-B01/V1    6
# OC006-B01/W1    7
# OC006-B01/W10   7
# OC006-B01/W2    7
# OC006-B01/W3    7
# OC006-B01/W4    7
# OC006-B01/W5    7
# OC006-B01/Y1    7
# OC006-B01/Y2    7
# OC006-B01/Y3    7
# OC006-B01/Y4    7
# OC006-B01/Y5    7
# OC006-B01/Y6    7
# OC006-B01/Z1    7
# OC006-B01/Z2    7
#
# [28824 rows x 1 columns]

# %%
df=pd.DataFrame((planon_meterssensors_intersected.T==master_meterssensors_for_validation_intersected.T).sum()/\
len(planon_meterssensors_intersected.T)*100)
df[df[0]<100]
# Out:
#                         0
# AP000-L01/M001  85.714286
# AP000-L03/M001  85.714286
# AP000-L03/M002  85.714286
# AP001-L01/M001  71.428571
# AP001-L01/M002  71.428571
# AP001-L01/M003  71.428571
# AP001-L01/M004  71.428571
# AP001-L01/M005  85.714286
# AP001-L01/M006  85.714286
# AP009-L01/M001  85.714286
# AP009-L01/M002  85.714286
# AP009-L01/M003  71.428571
# AP010-L01/M001  85.714286
# AP010-L01/M002  85.714286
# AP010-L01/M003  85.714286
# AP010-L01/M004  85.714286
# AP010-L01/M005  85.714286
# AP011-L01/M001  85.714286
# AP011-L01/M002  85.714286
# AP011-L01/M003  85.714286
# AP011-L01/M004  85.714286
# AP057-L01/M001  85.714286
# AP080-L01/M001  85.714286
# AP081-L01/M001  85.714286
# EX001-B01/V1    85.714286
# MC001-B01/V1    85.714286
# MC001-L02/M001  85.714286
# MC003-B01/I4    85.714286
# MC003-B01/V1    85.714286
# MC003-B01/V2    85.714286
# ...                   ...
# MC210-B03/I5    57.142857
# MC210-B03/I6    57.142857
# MC210-B03/I9    57.142857
# MC210-B03/U1    85.714286
# MC210-B03/U2    85.714286
# MC210-B03/V1    85.714286
# MC211-B01/I2    57.142857
# MC211-B01/I3    57.142857
# MC211-B01/O1    57.142857
# MC211-B01/P23   85.714286
# MC211-B01/P24   85.714286
# MC211-B01/S24   85.714286
# MC211-B01/S25   85.714286
# MC211-B01/V1    85.714286
# OC004-B01/G50   85.714286
# OC004-B01/L1    85.714286
# OC004-B01/L2    85.714286
# OC004-B01/L3    85.714286
# OC004-B01/L4    85.714286
# OC004-B01/V1    85.714286
# OC005-B01/G50   85.714286
# OC005-B01/L1    85.714286
# OC005-B01/L2    85.714286
# OC005-B01/L3    85.714286
# OC005-B01/V1    85.714286
# OC006-B01/G50   85.714286
# OC006-B01/L1    85.714286
# OC006-B01/L2    85.714286
# OC006-B01/L3    85.714286
# OC006-B01/V1    85.714286
#
# [2064 rows x 1 columns]

# %% [markdown]
# #### 2.1.5. Smart(er) comparison

# %% [markdown]
# Not all of the dataframe matches. Let us do some basic string formatting, maybe that helps.

# %%
sum(planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description'])
# Out:
# 1549

# %%
planon_meterssensors_intersected['Description']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in planon_meterssensors_intersected['Description'].values]
master_meterssensors_for_validation_intersected['Description']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in master_meterssensors_for_validation_intersected['Description'].values]

# %%
sum(planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description'])
# Out:
# 269

# %% [markdown]
# Some errors fixed, some left. Let's see which ones. These are either:
# - Wrong duplicate dropped
# - Input human erros in the description.
# - Actual erros somewhere in the indexing.

# %%
for i in planon_meterssensors_intersected[planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description']].index:
    print(i,'\t\tPlanon:',planon_meterssensors_intersected.loc[i]['Description'],'\t\tMaster:',master_meterssensors_for_validation_intersected.loc[i]['Description'])
# Out:
# MC011-B01/I1 		Planon: fire alarm active 		Master: xcite/io/16di
# MC011-B01/I2 		Planon: lthw pri pmp flow 		Master: xcite/io/8do
# MC014-B01/L4 		Planon: nan 		Master:
# MC014-B01/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B02/L4 		Planon: nan 		Master:
# MC014-B02/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B03/L4 		Planon: nan 		Master:
# MC014-B04/L4 		Planon: nan 		Master:
# MC014-B05/L4 		Planon: nan 		Master:
# MC014-B05/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B06/L4 		Planon: nan 		Master:
# MC014-B06/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B07/L4 		Planon: nan 		Master:
# MC014-B08/L4 		Planon: nan 		Master:
# MC014-B08/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B09/L4 		Planon: nan 		Master:
# MC014-B09/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B10/L4 		Planon: nan 		Master:
# MC014-B11/L4 		Planon: nan 		Master:
# MC014-B11/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B12/L4 		Planon: nan 		Master:
# MC014-B12/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B13/L4 		Planon: nan 		Master:
# MC014-B13/O1 		Planon: heating times 		Master: alarm route 1
# MC014-B14/L4 		Planon: nan 		Master:
# MC014-B14/O1 		Planon: heating times 		Master: alarm route 1
# MC029-B01/L4 		Planon: nan 		Master:
# MC031-B01/I2 		Planon: heating pump status 		Master: xcite/io/2ui/2ao
# MC031-B01/I3 		Planon: greathall ahu on-off 		Master: xcite/io/4do
# MC031-B02/I2 		Planon: sump no1 pump 1 trip 		Master: module 2
# MC032-B01/I1 		Planon: fire alarm activated 		Master: iq4/io/16di
# MC032-B01/I5 		Planon: ct pump flow prove 		Master: iq4/io/8do
# MC032-B01/L1 		Planon: nan 		Master:
# MC032-B01/L2 		Planon: nan 		Master:
# MC032-B02/L1 		Planon: nan 		Master:
# MC032-B02/L2 		Planon: nan 		Master:
# MC032-B02/L3 		Planon: nan 		Master:
# MC032-B02/L4 		Planon: nan 		Master:
# MC032-B02/L5 		Planon: nan 		Master:
# MC032-B02/L6 		Planon: nan 		Master:
# MC032-B02/L8 		Planon: nan 		Master:
# MC032-B03/I2 		Planon: emergency stop 		Master: xcite/io/16di
# MC032-B03/I4 		Planon: kitchen hws pump trip 		Master: xcite/io/2ui/2ao
# MC032-B04/I1 		Planon: thermal wheel fault 		Master: xcite/io/8di
# MC032-B07/I3 		Planon: sump no4 pump 2 trip 		Master: module 3
# MC033-B01/I1 		Planon: water booster alarm 		Master: 8ui
# MC043-B01/I1 		Planon: fire alarm 		Master: mod 1
# MC043-B01/I4 		Planon: heat ex pump 2 trip 		Master: mod 4
# MC043-B01/I5 		Planon: ct htg pump 1 trip 		Master: mod 5
# MC043-B01/I6 		Planon: ct htg pump 2 trip 		Master: mod 6
# MC043-B01/L1 		Planon: nan 		Master:
# MC043-B01/L2 		Planon: nan 		Master:
# MC043-B01/L3 		Planon: nan 		Master:
# MC043-B01/L4 		Planon: nan 		Master:
# MC043-B01/L5 		Planon: nan 		Master:
# MC043-B01/L6 		Planon: nan 		Master:
# MC043-B01/L7 		Planon: nan 		Master:
# MC043-B01/O1 		Planon: nan 		Master:
# MC044-B01/I10 		Planon: ahu01 extr dmpr open 		Master: module 10
# MC044-B01/I11 		Planon: ahu01 extr fan flow 		Master: module 11
# MC044-B01/I3 		Planon: ahu01 sply dmpr open 		Master: module 3
# MC044-B01/I4 		Planon: ahu01 sply fan flow 		Master: module 4
# MC044-B01/I5 		Planon: ahu01 frost trip 		Master: module 5
# MC044-B01/I6 		Planon: ahu01 panel fltr dirty 		Master: module 6
# MC044-B01/I8 		Planon: ahu01 th wheel fault 		Master: module 8
# MC044-B01/L10 		Planon: nan 		Master:
# MC044-B01/L12 		Planon: nan 		Master:
# MC044-B01/L13 		Planon: nan 		Master:
# MC044-B01/L14 		Planon: nan 		Master:
# MC044-B01/L15 		Planon: nan 		Master:
# MC044-B01/L2 		Planon: nan 		Master:
# MC044-B01/L3 		Planon: nan 		Master:
# MC044-B01/L4 		Planon: nan 		Master:
# MC044-B01/L5 		Planon: nan 		Master:
# MC044-B01/L7 		Planon: nan 		Master:
# MC044-B01/L8 		Planon: nan 		Master:
# MC044-B01/L9 		Planon: nan 		Master:
# MC044-B02/I2 		Planon: fire alarm active 		Master: module 2
# MC044-B02/I3 		Planon: emergency stop 		Master: module 3
# MC044-B02/I7 		Planon: lthw pu hi press 		Master: module 7
# MC044-B02/I8 		Planon: lthw pu lo press 		Master: module 8
# MC044-B02/O2 		Planon: vt system 102 		Master: alarm route 2
# MC044-B03/I1 		Planon: ups low battery 		Master: module 1
# MC044-B04/I1 		Planon: phe1 high temp alarm 		Master: module 1
# MC044-B04/I2 		Planon: emergency stop 		Master: module 2
# MC044-B04/I3 		Planon: mains failure 		Master: module 3
# MC044-B04/I4 		Planon: gas detect fault 		Master: module 4
# MC044-B04/I7 		Planon: phe2 high temp alarm 		Master: module 7
# MC044-B04/I8 		Planon: hws high temp alarm 		Master: module 8
# MC044-B04/O1 		Planon: foyer vt heating 		Master: alarm route 1
# MC044-B04/O3 		Planon: lecture vt heating 		Master: alarm route 3
# MC044-B06/I1 		Planon: door interlock shut 		Master: module 1
# MC044-B06/I2 		Planon: fire alarm active 		Master: module 2
# MC044-B06/I4 		Planon: mains failure 		Master: module 4
# MC044-B06/I8 		Planon: ahu 2 fa dmpr open 		Master: module 8
# MC044-B06/L12 		Planon: nan 		Master:
# MC044-B06/L13 		Planon: nan 		Master:
# MC044-B08/I2 		Planon: emergency stop 		Master: module 2
# MC044-B08/I7 		Planon: ahu 5 fa dmpr open 		Master: module 7
# MC044-B08/I8 		Planon: large room 3 ndrman status 		Master: module 8
# MC044-B08/I9 		Planon: ahu 5 sply fan auto 		Master: module 9
# MC044-B08/L3 		Planon: nan 		Master:
# MC044-B08/L4 		Planon: nan 		Master:
# MC044-B08/O1 		Planon: ahu 5 physics store vent 		Master: alarm route 1
# MC045-B01/I4 		Planon: chiller failed 		Master: module4 16di
# MC045-B01/I7 		Planon: chw pump2fail 		Master: xcite/io/8ao
# MC046-B01/I1 		Planon: fire alarm 		Master: mod 1 - 8ao
# MC046-B01/I3 		Planon: p1 a fault 		Master: mod 3 - 8ao
# MC046-B01/I6 		Planon: cal 1 18kw on 		Master: mod 6 - 8ui
# MC051-B01/L4 		Planon: nan 		Master:
# MC051-B01/L5 		Planon: nan 		Master:
# MC051-B01/O1 		Planon: optimum start stop 1 		Master: alarm route 1
# MC061-B01/I4 		Planon: boiler no.1 running 		Master: xcite/io/16di
# MC061-B01/I7 		Planon: boiler no.2 gas booster switch 		Master: xcite/io/8do
# MC061-B01/I8 		Planon: boiler no.2 gas booster fault 		Master: xcite/io/8ao
# MC061-B02/I1 		Planon: fire alarm 		Master: io module 1
# MC061-B02/I2 		Planon: pump p3 flow dps 		Master: io module 2
# MC061-B02/I3 		Planon: biomass gas safety circuit 		Master: module 3
# MC061-B03/I2 		Planon: pm-a-01 pump run 		Master: spare
# MC063-B01/I1 		Planon: fire alarm active 		Master: module 1
# MC063-B01/I2 		Planon: shower fans north fault 		Master: module 2
# MC063-B01/I3 		Planon: shower fans south fault 		Master: module 3
# MC063-B01/L2 		Planon: nan 		Master:
# MC063-B01/L3 		Planon: nan 		Master:
# MC063-B01/L4 		Planon: nan 		Master:
# MC065-B01/I1 		Planon: phex no.1highlimitstatus 		Master: xcite/io/8ui
# MC065-B01/I2 		Planon: phex no.2highlimitstatus 		Master: xcite/io/8di/8ti
# MC065-B01/L3 		Planon: nan 		Master:
# MC065-B01/L4 		Planon: nan 		Master:
# MC065-B01/L6 		Planon: nan 		Master:
# MC065-B01/L7 		Planon: nan 		Master:
# MC065-B03/I1 		Planon: fire alarm active 		Master: module 1
# MC065-B03/I3 		Planon: for off 		Master: module 3
# MC065-B04/I2 		Planon: for auto 		Master: module 2
# MC065-B04/I4 		Planon: for extr only 		Master: module 4
# MC065-B06/I5 		Planon: ahu-nwsupplypanelfiltersts 		Master: xcite/io/8ao
# MC065-B06/L3 		Planon: nan 		Master:
# MC065-B06/L4 		Planon: nan 		Master:
# MC065-B06/O1 		Planon: nw zone 1 floor a oss 		Master: alarm route 1
# MC065-B06/O2 		Planon: nw zone 1 floor b oss 		Master: alarm route 1
# MC065-B07/I1 		Planon: ahu-ne supply vsd fault 		Master: xcite/io/8ui
# MC065-B07/I3 		Planon: ahu-ne extract vsd fault 		Master: xcite/io/8ao
# MC065-B07/L3 		Planon: nan 		Master:
# MC065-B07/L4 		Planon: nan 		Master:
# MC065-B08/I2 		Planon: ahu-se supply vsd fault 		Master: xcite/io/8ui
# MC065-B08/I4 		Planon: ahu-se extract vsd fault 		Master: xcite/io/8ui
# MC065-B08/I7 		Planon: ahu-se bagpanelfiltersts 		Master: xcite/io/8ao
# MC065-B08/I9 		Planon: ahu-se frost stat 		Master: xcite/io/8ao
# MC065-B08/L3 		Planon: nan 		Master:
# MC065-B08/L4 		Planon: nan 		Master:
# MC065-B08/O2 		Planon: se zone 4 floor b oss 		Master: alarm route 1
# MC065-B09/I1 		Planon: ahu-sw supply vsd fault 		Master: xcite/io/8ui
# MC065-B09/I2 		Planon: ahu-sw supply flow sts 		Master: xcite/io/8ui
# MC065-B09/I5 		Planon: tef1 toilet extrct fault 		Master: xcite/io/8ao
# MC065-B09/L3 		Planon: nan 		Master:
# MC065-B09/L4 		Planon: nan 		Master:
# MC065-B09/O1 		Planon: sw zone 3 floor a oss 		Master: alarm route 1
# MC065-B09/O2 		Planon: sw zone 3 floor b oss 		Master: alarm route 1
# MC066-B01/I1 		Planon: vt pump flow proven 		Master: xcite/io/8ui
# MC066-B01/I2 		Planon: ct pump flow proven 		Master: xcite/io/8ui
# MC066-B01/I3 		Planon: ahu no2 air flow proven 		Master: xcite/io/8ui
# MC066-B01/I4 		Planon: fire alarm 		Master: xcite/io/16di
# MC066-B01/L10 		Planon: nan 		Master:
# MC066-B01/L13 		Planon: nan 		Master:
# MC066-B01/L14 		Planon: nan 		Master:
# MC066-B01/L5 		Planon: nan 		Master:
# MC066-B01/L6 		Planon: nan 		Master:
# MC066-B01/L9 		Planon: nan 		Master:
# MC070-B01/L1 		Planon: nan 		Master:
# MC070-B01/L2 		Planon: nan 		Master:
# MC070-B01/L3 		Planon: nan 		Master:
# MC070-B01/L4 		Planon: nan 		Master:
# MC070-B01/L5 		Planon: nan 		Master:
# MC070-B03/I2 		Planon: ahu supply fan run 		Master: io module 2
# MC070-B05/I2 		Planon: dhw cyl 2 high limit ok 		Master: xcite/io/8ao
# MC070-B05/I3 		Planon: compressor fault 		Master: 4ui
# MC071-B01/I1 		Planon: bar lossney hx03 fault 		Master: 16di_module 1
# MC071-B01/I2 		Planon: bar lossney hx04 fault 		Master: 8ui_module 2
# MC071-B01/I3 		Planon: toilet extract fan a030 fault 		Master: 8ao_module 3
# MC071-B01/I4 		Planon: toilet extract fan b013 fault 		Master: 4ao_module 4
# MC071-B01/I7 		Planon: toilet extract fan b070 fault 		Master: 8ui_module 7
# MC072-B01/I2 		Planon: ct pump 2 fault 		Master: 1 8do
# MC072-B01/I3 		Planon: tower pump 1 fault 		Master: io module 3
# MC072-B02/I2 		Planon: presurisation unit hp fault 		Master: xcite/io/16di no2
# MC072-B02/I4 		Planon: mthw shunt pump p1a fault 		Master: xcite/io/4do no1
# MC072-B02/I7 		Planon: lthw shunt pump p2a fault 		Master: xcite/io/8ui no3
# MC072-B03/I1 		Planon: alarm mute pb 		Master: module 1
# MC072-B03/I2 		Planon: sump so5 pump 1 trip 		Master: module 2
# MC075-B01/I2 		Planon: heating pump 2 fault 		Master: xcite/io/4ao/4u
# MC076-B02/I3 		Planon: ahu 1 flow proving 1=flow 		Master: xcite/io/8ao
# MC076-B02/I4 		Planon: ac unit 01_2 fault =1 		Master: xcite/io/4ao
# MC077-B01/O1 		Planon: heating 		Master: alarm route 1
# MC078-B01/I2 		Planon: f39 frost 		Master: xcite/io/16di
# MC078-B01/I3 		Planon: fan 1 frost 		Master: xcite/io/16di
# MC078-B01/I5 		Planon: f40 frost 		Master: xcite/io/8ao
# MC078-B01/I6 		Planon: ground floor toilet extract 		Master: xcite/io/8ao
# MC078-B01/I7 		Planon: f40 supply 		Master: xcite/io/8ao
# MC078-B01/I9 		Planon: f40 filter 		Master: xcite/io/2ui/2ao
# MC078-B02/I6 		Planon: main supply filter dirty 		Master: xcite/io/16di
# MC078-B02/I8 		Planon: main extract filter dirty 		Master: xcite/io/16di
# MC078-B03/I1 		Planon: 2 flr hws cal 1 valve 		Master: xcite/io/16di
# MC078-B03/I2 		Planon: 2 flr hws cal 2 valve 		Master: io module 2
# MC078-B03/I3 		Planon: 2-3 flr htg pump 1 		Master: io module 3
# MC078-B03/L3 		Planon: nan 		Master:
# MC103-B01/I2 		Planon: hws failed 		Master: iq4/io/8do
# MC103-B01/L1 		Planon: nan 		Master:
# MC103-B01/O1 		Planon: nan 		Master:
# MC200-B01/I1 		Planon: ahu2 extract fan flow status 		Master: module 1 - 8ui
# MC204-B01/I2 		Planon: emergency stop 		Master: module 2
# MC204-B01/I3 		Planon: gas detected 		Master: module 3
# MC204-B02/I1 		Planon: fire alarm active 		Master: module 1
# MC204-B02/I2 		Planon: for normal 		Master: module 2
# MC204-B02/I4 		Planon: ahu3 frost trip 		Master: module 4
# MC204-B02/I5 		Planon: ahu3 fa dmpr open 		Master: module 5
# MC204-B02/L10 		Planon: nan 		Master:
# MC204-B02/L11 		Planon: nan 		Master:
# MC204-B02/L12 		Planon: nan 		Master:
# MC204-B02/L13 		Planon: nan 		Master:
# MC204-B02/L14 		Planon: nan 		Master:
# MC204-B02/L6 		Planon: nan 		Master:
# MC204-B02/L7 		Planon: nan 		Master:
# MC204-B02/L8 		Planon: nan 		Master:
# MC204-B02/L9 		Planon: nan 		Master:
# MC204-B04/L1 		Planon: nan 		Master:
# MC204-B04/L2 		Planon: nan 		Master:
# MC204-B04/L3 		Planon: nan 		Master:
# MC204-B04/O2 		Planon: climbing wall 		Master: alarm route 2
# MC204-B05/I2 		Planon: vt pump 3b fault 		Master: module 2
# MC204-B05/I3 		Planon: vt pumps flow 		Master: module 3
# MC204-B05/I5 		Planon: ufhm1 pump flow 		Master: module 5
# MC204-B05/I6 		Planon: ufhm1 htco 		Master: module 6
# MC204-B05/O1 		Planon: vt heating 		Master: alarm route 1
# MC204-B05/O5 		Planon: ufhm4-pool change 		Master: alarm route 5
# MC204-B06/I2 		Planon: ahu4 fa dmpr open 		Master: module 2
# MC204-B06/I3 		Planon: ahu4 sply fan fault 		Master: module 3
# MC204-B06/L2 		Planon: nan 		Master:
# MC204-B06/L3 		Planon: nan 		Master:
# MC204-B06/L4 		Planon: nan 		Master:
# MC204-B06/L5 		Planon: nan 		Master:
# MC204-B06/L6 		Planon: nan 		Master:
# MC204-B06/L7 		Planon: nan 		Master:
# MC204-B06/L8 		Planon: nan 		Master:
# MC207-B01/I2 		Planon: press unit fault 		Master: io module 2
# MC207-B01/I3 		Planon: sec hr pumps flow 		Master: io module 3
# MC207-B01/I6 		Planon: lodge pumps flow 		Master: io module 6
# MC207-B01/I7 		Planon: training ahu1 run 		Master: io module 7
# MC210-B01/I2 		Planon: gas safety cct trip 		Master: xcite/io/8ao
# MC210-B01/I4 		Planon: iss hub condenser1 fault 		Master: xcite/io/8do
# MC210-B02/I2 		Planon: summer switch active 		Master: xcite/io/8ui
# MC210-B03/I14 		Planon: b04 override 		Master: xcite/io/8do
# MC210-B03/I2 		Planon: compressedairunit2 fault 		Master: xcite/io/8ui
# MC210-B03/I3 		Planon: nitrogen generation alarm 		Master: xcite/io/8ui
# MC210-B03/I4 		Planon: cef03 extract fan fault 		Master: xcite/io/8ui
# MC210-B03/I5 		Planon: a04a&amp;b extract fan fault 		Master: xcite/io/8di
# MC210-B03/I6 		Planon: chemenglab condenser fault 		Master: xcite/io/8ui
# MC210-B03/I9 		Planon: a17 override 		Master: xcite/io/8do
# MC211-B01/I2 		Planon: boundary water meter 		Master: xcite/io/8ui
# MC211-B01/I3 		Planon: incoming water meter 		Master: xcite/io/8ao
# MC211-B01/O1 		Planon: optimum start stop 1 		Master: alarm route 1
# OC004-B01/L1 		Planon: nan 		Master:
# OC004-B01/L2 		Planon: nan 		Master:
# OC004-B01/L3 		Planon: nan 		Master:
# OC004-B01/L4 		Planon: nan 		Master:
# OC005-B01/L1 		Planon: nan 		Master:
# OC005-B01/L2 		Planon: nan 		Master:
# OC005-B01/L3 		Planon: nan 		Master:
# OC006-B01/L1 		Planon: nan 		Master:
# OC006-B01/L2 		Planon: nan 		Master:
# OC006-B01/L3 		Planon: nan 		Master:

# %% [markdown]
# Let us repeat the exercise for `Logger Channel`. Cross-validate, flag as highly likely error where both mismatch.

# %%
sum(planon_meterssensors_intersected['Logger Channel']!=master_meterssensors_for_validation_intersected['Logger Channel'])
# Out:
# 161

# %%
planon_meterssensors_intersected['Logger Channel']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in planon_meterssensors_intersected['Logger Channel'].values]
master_meterssensors_for_validation_intersected['Logger Channel']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in master_meterssensors_for_validation_intersected['Logger Channel'].values]

# %%
sum(planon_meterssensors_intersected['Logger Channel']!=master_meterssensors_for_validation_intersected['Logger Channel'])
# Out:
# 0

# %% [markdown]
# All errors fixed on logger channels.

# %%
for i in planon_meterssensors_intersected[planon_meterssensors_intersected['Logger Channel']!=master_meterssensors_for_validation_intersected['Logger Channel']].index:
    print(i,'\t\tPlanon:',planon_meterssensors_intersected.loc[i]['Logger Channel'],'\t\tMaster:',master_meterssensors_for_validation_intersected.loc[i]['Logger Channel'])

# %% [markdown]
# New error percentage:

# %%
(planon_meterssensors_intersected!=master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100
# Out:
# Building Name     1.835276
# Tenant meter      0.000000
# Logger Channel    0.000000
# Building Code     0.000000
# Fiscal meter      0.000000
# Description       0.933250
# Code              0.558562
# dtype: float64

# %% [markdown]
# ### 2.2. Loggers

# %%
buildings=set(planon_loggerscontrollers['BuildingNo.'])
buildings
# Out:
# {'AP000',
#  'AP001',
#  'AP009',
#  'AP010',
#  'AP011',
#  'AP057',
#  'AP080',
#  'AP081',
#  'EX000',
#  'EX001',
#  'EX005',
#  'FH000',
#  'FH002',
#  'FH003',
#  'FH008',
#  'FH012',
#  'MC000',
#  'MC001',
#  'MC002',
#  'MC003',
#  'MC007',
#  'MC008',
#  'MC010',
#  'MC011',
#  'MC013',
#  'MC014',
#  'MC029',
#  'MC030',
#  'MC031',
#  'MC032',
#  'MC033',
#  'MC042',
#  'MC043',
#  'MC044',
#  'MC045',
#  'MC046',
#  'MC047',
#  'MC048',
#  'MC050',
#  'MC051',
#  'MC053',
#  'MC055',
#  'MC060',
#  'MC061',
#  'MC062',
#  'MC063',
#  'MC064',
#  'MC065',
#  'MC066',
#  'MC067',
#  'MC068',
#  'MC069',
#  'MC070',
#  'MC071',
#  'MC072',
#  'MC075',
#  'MC076',
#  'MC077',
#  'MC078',
#  'MC083',
#  'MC095',
#  'MC099',
#  'MC102',
#  'MC103',
#  'MC125',
#  'MC126',
#  'MC128',
#  'MC129',
#  'MC131',
#  'MC134',
#  'MC138',
#  'MC139',
#  'MC140',
#  'MC141',
#  'MC171',
#  'MC181',
#  'MC197',
#  'MC198',
#  'MC199',
#  'MC200',
#  'MC202',
#  'MC203',
#  'MC204',
#  'MC207',
#  'MC210',
#  'MC211',
#  'OC001',
#  'OC003',
#  'OC004',
#  'OC005',
#  'OC006',
#  'OC007',
#  'OC008',
#  'OC011',
#  'OC012'}

# %%
master_loggerscontrollers_for_validation = \
    pd.concat([master_loggerscontrollers.loc[master_loggerscontrollers['Building Code'] == building] \
           for building in buildings])
master_loggerscontrollers_for_validation.head(2)
# Out:
#           Building Code  Building Name Space                 Description  \
# MC204-L01         MC204  Sports Centre   A43  Data logger: Sports Centre
# MC204-L02         MC204  Sports Centre   B08  Data logger: Sports Centre
#
#           Classification Group     Make        Model Logger Serial Number  \
# MC204-L01          Data logger  Enercom  Multilog G2         050157B3B000
# MC204-L02          Data logger  Enercom  Multilog G2        0501988894C00
#
#           Logger Mac Address Logger Ip Address  Logger Modem Serial Number  \
# MC204-L01  00-50-C2-2C-3D-13       10.23.11.71                         NaN
# MC204-L02  00-50-C2-2C-3E-25       10.23.11.72                         NaN
#
#            Logger Sim  Network Point Id  Logger Upstream Comms Target  \
# MC204-L01         NaN               NaN                           NaN
# MC204-L02         NaN               NaN                           NaN
#
#           Additional Location Info       Code
# MC204-L01          Pool Plant Room  MC204-L01
# MC204-L02        Cleaners Cupboard  MC204-L02

# %%
master_loggerscontrollers[master_loggerscontrollers['Building Code']=='MC060']
# Out:
#           Building Code                Building Name Space  \
# MC060-L01         MC060  Furness Residences, Bardsea   PL1
#
#                                Description Classification Group     Make  \
# MC060-L01  Data logger: Furness Residences          Data logger  Enercom
#
#                  Model Logger Serial Number Logger Mac Address  \
# MC060-L01  Multilog G2         0501988FCB00  00-50-C2-2C-3E-32
#
#           Logger Ip Address  Logger Modem Serial Number  Logger Sim  \
# MC060-L01       10.23.12.13                         NaN         NaN
#
#            Network Point Id  Logger Upstream Comms Target  \
# MC060-L01               NaN                           NaN
#
#           Additional Location Info       Code
# MC060-L01                      NaN  MC060-L01

# %%
planon_loggerscontrollers[planon_loggerscontrollers['BuildingNo.']=='MC060']
# Out:
#           BuildingNo.                     Building  \
# MC060-L01       MC060  Furness Residences, Bardsea
#
#           Locations.Space.Space number  Space Name  Additional Location Info  \
# MC060-L01                          PL1  Plant Room                       NaN
#
#                                Description Classification Group  Record  \
# MC060-L01  Data logger: Furness Residences   EN.EN1 Data Logger     NaN
#
#            HVAC Ref  Element Description    ...      Logger SIM  \
# MC060-L01       NaN                  NaN    ...             NaN
#
#           Meter Pulse Value Meter Units Meter Capacity  Network Point ID  \
# MC060-L01               NaN         NaN            NaN               NaN
#
#            Tenant Meter.Name  Fiscal Meter.Name EIS Space.Space number  \
# MC060-L01                NaN                NaN                    NaN
#
#            Utility Type.Name       Code
# MC060-L01                NaN  MC060-L01
#
# [1 rows x 30 columns]

# %%
master_loggerscontrollers.loc['MC060-L01']
# Out:
# Building Code                                             MC060
# Building Name                       Furness Residences, Bardsea
# Space                                                       PL1
# Description                     Data logger: Furness Residences
# Classification Group                                Data logger
# Make                                                    Enercom
# Model                                               Multilog G2
# Logger Serial Number                               0501988FCB00
# Logger Mac Address                            00-50-C2-2C-3E-32
# Logger Ip Address                                   10.23.12.13
# Logger Modem Serial Number                                  NaN
# Logger Sim                                                  NaN
# Network Point Id                                            NaN
# Logger Upstream Comms Target                                NaN
# Additional Location Info                                    NaN
# Code                                                  MC060-L01
# Name: MC060-L01, dtype: object

# %%
len(master_loggerscontrollers_for_validation)
# Out:
# 378

# %%
len(planon_loggerscontrollers)-len(planon_loggerscontrollers.index[planon_loggerscontrollers.index.duplicated()])
# Out:
# 359

# %%
master_loggerscontrollers_for_validation.sort_index(inplace=True)
planon_loggerscontrollers.sort_index(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
master_loggerscontrollers_for_validation.loc['MC060-L01']
# Out:
# Building Code                                             MC060
# Building Name                       Furness Residences, Bardsea
# Space                                                       PL1
# Description                     Data logger: Furness Residences
# Classification Group                                Data logger
# Make                                                    Enercom
# Model                                               Multilog G2
# Logger Serial Number                               0501988FCB00
# Logger Mac Address                            00-50-C2-2C-3E-32
# Logger Ip Address                                   10.23.12.13
# Logger Modem Serial Number                                  NaN
# Logger Sim                                                  NaN
# Network Point Id                                            NaN
# Logger Upstream Comms Target                                NaN
# Additional Location Info                                    NaN
# Code                                                  MC060-L01
# Name: MC060-L01, dtype: object

# %%
planon_loggerscontrollers.T
# Out:
#                                                 AP000-L01  \
# BuildingNo.                                         AP000
# Building                                   Alexandra Park
# Locations.Space.Space number                           A0
# Space Name                                     Whole Site
# Additional Location Info                              NaN
# Description                   Data logger: Alexandra Park
# Classification Group                   EN.EN1 Data Logger
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                         Multilog G2
# Make                                              Enercom
# EIS ID                                       050157C7ED00
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                              10.23.9.39
# Logger Serial Number                                  NaN
# Logger MAC Address                      00-50-C2-2C-3E-43
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                     NaN
# Fiscal Meter.Name                                     NaN
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
# Code                                            AP000-L01
#
#                                                 AP000-L02  \
# BuildingNo.                                         AP000
# Building                                   Alexandra Park
# Locations.Space.Space number                           A0
# Space Name                                     Whole Site
# Additional Location Info                              NaN
# Description                   Data logger: Alexandra Park
# Classification Group                   EN.EN1 Data Logger
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                         Multilog G2
# Make                                              Enercom
# EIS ID                                           37475126
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                                     NaN
# Logger Serial Number                                  NaN
# Logger MAC Address                                    NaN
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                     NaN
# Fiscal Meter.Name                                     NaN
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
# Code                                            AP000-L02
#
#                                                 AP000-L03  \
# BuildingNo.                                         AP000
# Building                                   Alexandra Park
# Locations.Space.Space number                           A0
# Space Name                                     Whole Site
# Additional Location Info                              NaN
# Description                   Data logger: Alexandra Park
# Classification Group                   EN.EN1 Data Logger
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                         Multilog G2
# Make                                              Enercom
# EIS ID                                           48015355
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                                     NaN
# Logger Serial Number                                  NaN
# Logger MAC Address                                    NaN
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                     NaN
# Fiscal Meter.Name                                     NaN
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
# Code                                            AP000-L03
#
#                                                 AP000-L99  \
# BuildingNo.                                         AP000
# Building                                   Alexandra Park
# Locations.Space.Space number                          NaN
# Space Name                                            NaN
# Additional Location Info                              NaN
# Description                   Data logger: Alexandra Park
# Classification Group                   EN.EN1 Data Logger
# Record                                                NaN
# HVAC Ref                                              NaN
# Element Description                                   NaN
# Servicable Area                                       NaN
# Model                                                 NaN
# Make                                                  NaN
# EIS ID                                                NaN
# Logger Channel                                          0
# Logger Upstream Comms Target                          NaN
# Logger Modem Serial Number                            NaN
# Logger IP Address                                     NaN
# Logger Serial Number                                  NaN
# Logger MAC Address                                    NaN
# Logger SIM                                            NaN
# Meter Pulse Value                                     NaN
# Meter Units                                           NaN
# Meter Capacity                                        NaN
# Network Point ID                                      NaN
# Tenant Meter.Name                                     NaN
# Fiscal Meter.Name                                     NaN
# EIS Space.Space number                                NaN
# Utility Type.Name                                     NaN
# Code                                            AP000-L99
#
#                                                                AP001-L01  \
# BuildingNo.                                                        AP001
# Building                      House 01 - Bassenthwaite, Graduate College
# Locations.Space.Space number                                        A104
# Space Name                                              Electrical Riser
# Additional Location Info                                             NaN
# Description                      Data logger: Graduate College - House 1
# Classification Group                                  EN.EN1 Data Logger
# Record                                                               NaN
# HVAC Ref                                                             NaN
# Element Description                                                  NaN
# Servicable Area                                                      NaN
# Model                                                        Multilog G2
# Make                                                             Enercom
# EIS ID                                                      0501E3E97100
# Logger Channel                                                         0
# Logger Upstream Comms Target                                         NaN
# Logger Modem Serial Number                                           NaN
# Logger IP Address                                            10.23.12.36
# Logger Serial Number                                                 NaN
# Logger MAC Address                                     00-50-C2-2C-3D-DE
# Logger SIM                                                           NaN
# Meter Pulse Value                                                    NaN
# Meter Units                                                          NaN
# Meter Capacity                                                       NaN
# Network Point ID                                                     NaN
# Tenant Meter.Name                                                    NaN
# Fiscal Meter.Name                                                    NaN
# EIS Space.Space number                                               NaN
# Utility Type.Name                                                    NaN
# Code                                                           AP001-L01
#
#                                                             AP009-L01  \
# BuildingNo.                                                     AP009
# Building                          House 09 - Devoke, Graduate College
# Locations.Space.Space number                                     A124
# Space Name                                  Electrical Riser/Cupboard
# Additional Location Info                                          NaN
# Description                   Data logger: Graduate College - House 9
# Classification Group                               EN.EN1 Data Logger
# Record                                                            NaN
# HVAC Ref                                                          NaN
# Element Description                                               NaN
# Servicable Area                                                   NaN
# Model                                                     Multilog G2
# Make                                                          Enercom
# EIS ID                                                   0501E38A6300
# Logger Channel                                                      0
# Logger Upstream Comms Target                                      NaN
# Logger Modem Serial Number                                        NaN
# Logger IP Address                                                 NaN
# Logger Serial Number                                              NaN
# Logger MAC Address                                  00-50-C2-2C-3D-CB
# Logger SIM                                                        NaN
# Meter Pulse Value                                                 NaN
# Meter Units                                                       NaN
# Meter Capacity                                                    NaN
# Network Point ID                                                  NaN
# Tenant Meter.Name                                                 NaN
# Fiscal Meter.Name                                                 NaN
# EIS Space.Space number                                            NaN
# Utility Type.Name                                                 NaN
# Code                                                        AP009-L01
#
#                                                              AP010-L01  \
# BuildingNo.                                                      AP010
# Building                       House 10 - Elterwater, Graduate College
# Locations.Space.Space number                                      A109
# Space Name                                            Electrical Riser
# Additional Location Info                                           NaN
# Description                   Data logger: Graduate College - House 10
# Classification Group                                EN.EN1 Data Logger
# Record                                                             NaN
# HVAC Ref                                                           NaN
# Element Description                                                NaN
# Servicable Area                                                    NaN
# Model                                                      Multilog G2
# Make                                                           Enercom
# EIS ID                                                    0501E3D07500
# Logger Channel                                                       0
# Logger Upstream Comms Target                                       NaN
# Logger Modem Serial Number                                         NaN
# Logger IP Address                                          10.23.12.37
# Logger Serial Number                                               NaN
# Logger MAC Address                                   00-50-C2-2C-3D-D1
# Logger SIM                                                         NaN
# Meter Pulse Value                                                  NaN
# Meter Units                                                        NaN
# Meter Capacity                                                     NaN
# Network Point ID                                                   NaN
# Tenant Meter.Name                                                  NaN
# Fiscal Meter.Name                                                  NaN
# EIS Space.Space number                                             NaN
# Utility Type.Name                                                  NaN
# Code                                                         AP010-L01
#
#                                                              AP011-L01  \
# BuildingNo.                                                      AP011
# Building                        House 11 - Ennerdale, Graduate College
# Locations.Space.Space number                                      A102
# Space Name                                            Electrical Riser
# Additional Location Info                                           NaN
# Description                   Data logger: Graduate College - House 11
# Classification Group                                EN.EN1 Data Logger
# Record                                                             NaN
# HVAC Ref                                                           NaN
# Element Description                                                NaN
# Servicable Area                                                    NaN
# Model                                                      Multilog G2
# Make                                                           Enercom
# EIS ID                                                    0501E3839500
# Logger Channel                                                       0
# Logger Upstream Comms Target                                       NaN
# Logger Modem Serial Number                                         NaN
# Logger IP Address                                          10.23.12.38
# Logger Serial Number                                               NaN
# Logger MAC Address                                   00-50-C2-2C-3D-A7
# Logger SIM                                                         NaN
# Meter Pulse Value                                                  NaN
# Meter Units                                                        NaN
# Meter Capacity                                                     NaN
# Network Point ID                                                   NaN
# Tenant Meter.Name                                                  NaN
# Fiscal Meter.Name                                                  NaN
# EIS Space.Space number                                             NaN
# Utility Type.Name                                                  NaN
# Code                                                         AP011-L01
#
#                                                            AP057-L01  \
# BuildingNo.                                                    AP057
# Building                                   Alexandra Park Laundrette
# Locations.Space.Space number                                      A0
# Space Name                                            Whole Building
# Additional Location Info                                         NaN
# Description                   Data logger: Alexandra Park Laundrette
# Classification Group                              EN.EN1 Data Logger
# Record                                                           NaN
# HVAC Ref                                                         NaN
# Element Description                                              NaN
# Servicable Area                                                  NaN
# Model                                                    Multilog G2
# Make                                                         Enercom
# EIS ID                                                  050157C16100
# Logger Channel                                                     0
# Logger Upstream Comms Target                                     NaN
# Logger Modem Serial Number                                       NaN
# Logger IP Address                                 80.93.175.91:40455
# Logger Serial Number                                             NaN
# Logger MAC Address                                               NaN
# Logger SIM                                                       NaN
# Meter Pulse Value                                                NaN
# Meter Units                                                      NaN
# Meter Capacity                                                   NaN
# Network Point ID                                                 NaN
# Tenant Meter.Name                                                NaN
# Fiscal Meter.Name                                                NaN
# EIS Space.Space number                                           NaN
# Utility Type.Name                                                NaN
# Code                                                       AP057-L01
#
#                                                              AP080-L01  \
# BuildingNo.                                                      AP080
# Building                                     Lonsdale House (Block 12)
# Locations.Space.Space number                                       A13
# Space Name                                                  Laundrette
# Additional Location Info                                           NaN
# Description                   Data logger: Lonsdale House - Laundrette
# Classification Group                                EN.EN1 Data Logger
# Record                                                             NaN
# HVAC Ref                                                           NaN
# Element Description                                                NaN
# Servicable Area                                                    NaN
# Model                                                      Multilog G2
# Make                                                           Enercom
# EIS ID                                                    050157AB6700
# Logger Channel                                                       0
# Logger Upstream Comms Target                                       NaN
# Logger Modem Serial Number                                         NaN
# Logger IP Address                                           10.23.9.40
# Logger Serial Number                                               NaN
# Logger MAC Address                                   00-50-C2-2C-3D-1B
# Logger SIM                                                         NaN
# Meter Pulse Value                                                  NaN
# Meter Units                                                        NaN
# Meter Capacity                                                     NaN
# Network Point ID                                                   NaN
# Tenant Meter.Name                                                  NaN
# Fiscal Meter.Name                                                  NaN
# EIS Space.Space number                                             NaN
# Utility Type.Name                                                  NaN
# Code                                                         AP080-L01
#
#                                             ...                 \
# BuildingNo.                                 ...
# Building                                    ...
# Locations.Space.Space number                ...
# Space Name                                  ...
# Additional Location Info                    ...
# Description                                 ...
# Classification Group                        ...
# Record                                      ...
# HVAC Ref                                    ...
# Element Description                         ...
# Servicable Area                             ...
# Model                                       ...
# Make                                        ...
# EIS ID                                      ...
# Logger Channel                              ...
# Logger Upstream Comms Target                ...
# Logger Modem Serial Number                  ...
# Logger IP Address                           ...
# Logger Serial Number                        ...
# Logger MAC Address                          ...
# Logger SIM                                  ...
# Meter Pulse Value                           ...
# Meter Units                                 ...
# Meter Capacity                              ...
# Network Point ID                            ...
# Tenant Meter.Name                           ...
# Fiscal Meter.Name                           ...
# EIS Space.Space number                      ...
# Utility Type.Name                           ...
# Code                                        ...
#
#                                                            OC004-B01  \
# BuildingNo.                                                    OC004
# Building                              Chancellor's Wharf, Wyre House
# Locations.Space.Space number                                     NaN
# Space Name                                                       NaN
# Additional Location Info                                         NaN
# Description                        BMS Controller: Chancellors Wharf
# Classification Group                           EN.EN4 BMS Controller
# Record                                                           NaN
# HVAC Ref                                                         NaN
# Element Description                                              NaN
# Servicable Area                                                  NaN
# Model                                                      IQ3xact12
# Make                                                           Trend
# EIS ID                        {48352BB4-4B1B-4013-AB9F-14E143E83948}
# Logger Channel                                                     0
# Logger Upstream Comms Target                                     NaN
# Logger Modem Serial Number                                       NaN
# Logger IP Address                                                NaN
# Logger Serial Number                                             NaN
# Logger MAC Address                                               NaN
# Logger SIM                                                       NaN
# Meter Pulse Value                                                NaN
# Meter Units                                                      NaN
# Meter Capacity                                                   NaN
# Network Point ID                                                 NaN
# Tenant Meter.Name                                                NaN
# Fiscal Meter.Name                                                NaN
# EIS Space.Space number                                           NaN
# Utility Type.Name                                                NaN
# Code                                                       OC004-B01
#
#                                                                 OC004-L99  \
# BuildingNo.                                                         OC004
# Building                                   Chancellor's Wharf, Wyre House
# Locations.Space.Space number                                          NaN
# Space Name                                                            NaN
# Additional Location Info                                              NaN
# Description                   Data logger: Chancellor's Wharf, Wyre House
# Classification Group                                   EN.EN1 Data Logger
# Record                                                                NaN
# HVAC Ref                                                              NaN
# Element Description                                                   NaN
# Servicable Area                                                       NaN
# Model                                                                 NaN
# Make                                                                  NaN
# EIS ID                                                                NaN
# Logger Channel                                                          0
# Logger Upstream Comms Target                                          NaN
# Logger Modem Serial Number                                            NaN
# Logger IP Address                                                     NaN
# Logger Serial Number                                                  NaN
# Logger MAC Address                                                    NaN
# Logger SIM                                                            NaN
# Meter Pulse Value                                                     NaN
# Meter Units                                                           NaN
# Meter Capacity                                                        NaN
# Network Point ID                                                      NaN
# Tenant Meter.Name                                                     NaN
# Fiscal Meter.Name                                                     NaN
# EIS Space.Space number                                                NaN
# Utility Type.Name                                                     NaN
# Code                                                            OC004-L99
#
#                                                            OC005-B01  \
# BuildingNo.                                                    OC005
# Building                              Chancellor's Wharf, Lune House
# Locations.Space.Space number                                     NaN
# Space Name                                                       NaN
# Additional Location Info                                         NaN
# Description                        BMS Controller: Chancellors Wharf
# Classification Group                           EN.EN4 BMS Controller
# Record                                                           NaN
# HVAC Ref                                                         NaN
# Element Description                                              NaN
# Servicable Area                                                  NaN
# Model                                                      IQ3xact12
# Make                                                           Trend
# EIS ID                        {281682DC-5479-4064-8290-E873933872B0}
# Logger Channel                                                     0
# Logger Upstream Comms Target                                     NaN
# Logger Modem Serial Number                                       NaN
# Logger IP Address                                                NaN
# Logger Serial Number                                             NaN
# Logger MAC Address                                               NaN
# Logger SIM                                                       NaN
# Meter Pulse Value                                                NaN
# Meter Units                                                      NaN
# Meter Capacity                                                   NaN
# Network Point ID                                                 NaN
# Tenant Meter.Name                                                NaN
# Fiscal Meter.Name                                                NaN
# EIS Space.Space number                                           NaN
# Utility Type.Name                                                NaN
# Code                                                       OC005-B01
#
#                                                                 OC005-L99  \
# BuildingNo.                                                         OC005
# Building                                   Chancellor's Wharf, Lune House
# Locations.Space.Space number                                          NaN
# Space Name                                                            NaN
# Additional Location Info                                              NaN
# Description                   Data logger: Chancellor's Wharf, Lune House
# Classification Group                                   EN.EN1 Data Logger
# Record                                                                NaN
# HVAC Ref                                                              NaN
# Element Description                                                   NaN
# Servicable Area                                                       NaN
# Model                                                                 NaN
# Make                                                                  NaN
# EIS ID                                                                NaN
# Logger Channel                                                          0
# Logger Upstream Comms Target                                          NaN
# Logger Modem Serial Number                                            NaN
# Logger IP Address                                                     NaN
# Logger Serial Number                                                  NaN
# Logger MAC Address                                                    NaN
# Logger SIM                                                            NaN
# Meter Pulse Value                                                     NaN
# Meter Units                                                           NaN
# Meter Capacity                                                        NaN
# Network Point ID                                                      NaN
# Tenant Meter.Name                                                     NaN
# Fiscal Meter.Name                                                     NaN
# EIS Space.Space number                                                NaN
# Utility Type.Name                                                     NaN
# Code                                                            OC005-L99
#
#                                                            OC006-B01  \
# BuildingNo.                                                    OC006
# Building                              Chancellor's Wharf, Kent House
# Locations.Space.Space number                                     NaN
# Space Name                                                       NaN
# Additional Location Info                                         NaN
# Description                        BMS Controller: Chancellors Wharf
# Classification Group                           EN.EN4 BMS Controller
# Record                                                           NaN
# HVAC Ref                                                         NaN
# Element Description                                              NaN
# Servicable Area                                                  NaN
# Model                                                      IQ3xact12
# Make                                                           Trend
# EIS ID                        {BBD3685B-B0DC-417F-A0E8-20139B1074E1}
# Logger Channel                                                     0
# Logger Upstream Comms Target                                     NaN
# Logger Modem Serial Number                                       NaN
# Logger IP Address                                                NaN
# Logger Serial Number                                             NaN
# Logger MAC Address                                               NaN
# Logger SIM                                                       NaN
# Meter Pulse Value                                                NaN
# Meter Units                                                      NaN
# Meter Capacity                                                   NaN
# Network Point ID                                                 NaN
# Tenant Meter.Name                                                NaN
# Fiscal Meter.Name                                                NaN
# EIS Space.Space number                                           NaN
# Utility Type.Name                                                NaN
# Code                                                       OC006-B01
#
#                                                                 OC006-L99  \
# BuildingNo.                                                         OC006
# Building                                   Chancellor's Wharf, Kent House
# Locations.Space.Space number                                          NaN
# Space Name                                                            NaN
# Additional Location Info                                              NaN
# Description                   Data logger: Chancellor's Wharf, Kent House
# Classification Group                                   EN.EN1 Data Logger
# Record                                                                NaN
# HVAC Ref                                                              NaN
# Element Description                                                   NaN
# Servicable Area                                                       NaN
# Model                                                                 NaN
# Make                                                                  NaN
# EIS ID                                                                NaN
# Logger Channel                                                          0
# Logger Upstream Comms Target                                          NaN
# Logger Modem Serial Number                                            NaN
# Logger IP Address                                                     NaN
# Logger Serial Number                                                  NaN
# Logger MAC Address                                                    NaN
# Logger SIM                                                            NaN
# Meter Pulse Value                                                     NaN
# Meter Units                                                           NaN
# Meter Capacity                                                        NaN
# Network Point ID                                                      NaN
# Tenant Meter.Name                                                     NaN
# Fiscal Meter.Name                                                     NaN
# EIS Space.Space number                                                NaN
# Utility Type.Name                                                     NaN
# Code                                                            OC006-L99
#
#                                                          OC007-L99  \
# BuildingNo.                                                  OC007
# Building                                   Hazelrigg Field Station
# Locations.Space.Space number                                   NaN
# Space Name                                                     NaN
# Additional Location Info                                       NaN
# Description                   Data logger: Hazelrigg Field Station
# Classification Group                            EN.EN1 Data Logger
# Record                                                         NaN
# HVAC Ref                                                       NaN
# Element Description                                            NaN
# Servicable Area                                                NaN
# Model                                                          NaN
# Make                                                           NaN
# EIS ID                                                         NaN
# Logger Channel                                                   0
# Logger Upstream Comms Target                                   NaN
# Logger Modem Serial Number                                     NaN
# Logger IP Address                                              NaN
# Logger Serial Number                                           NaN
# Logger MAC Address                                             NaN
# Logger SIM                                                     NaN
# Meter Pulse Value                                              NaN
# Meter Units                                                    NaN
# Meter Capacity                                                 NaN
# Network Point ID                                               NaN
# Tenant Meter.Name                                              NaN
# Fiscal Meter.Name                                              NaN
# EIS Space.Space number                                         NaN
# Utility Type.Name                                              NaN
# Code                                                     OC007-L99
#
#                                           OC008-L99  \
# BuildingNo.                                   OC008
# Building                                   Downings
# Locations.Space.Space number                    NaN
# Space Name                                      NaN
# Additional Location Info                        NaN
# Description                   Data logger: Downings
# Classification Group             EN.EN1 Data Logger
# Record                                          NaN
# HVAC Ref                                        NaN
# Element Description                             NaN
# Servicable Area                                 NaN
# Model                                           NaN
# Make                                            NaN
# EIS ID                                          NaN
# Logger Channel                                    0
# Logger Upstream Comms Target                    NaN
# Logger Modem Serial Number                      NaN
# Logger IP Address                               NaN
# Logger Serial Number                            NaN
# Logger MAC Address                              NaN
# Logger SIM                                      NaN
# Meter Pulse Value                               NaN
# Meter Units                                     NaN
# Meter Capacity                                  NaN
# Network Point ID                                NaN
# Tenant Meter.Name                               NaN
# Fiscal Meter.Name                               NaN
# EIS Space.Space number                          NaN
# Utility Type.Name                               NaN
# Code                                      OC008-L99
#
#                                               OC011-L99  \
# BuildingNo.                                       OC011
# Building                                   Wind Turbine
# Locations.Space.Space number                        NaN
# Space Name                                          NaN
# Additional Location Info                            NaN
# Description                   Data logger: Wind Turbine
# Classification Group                 EN.EN1 Data Logger
# Record                                              NaN
# HVAC Ref                                            NaN
# Element Description                                 NaN
# Servicable Area                                     NaN
# Model                                               NaN
# Make                                                NaN
# EIS ID                                              NaN
# Logger Channel                                        0
# Logger Upstream Comms Target                        NaN
# Logger Modem Serial Number                          NaN
# Logger IP Address                                   NaN
# Logger Serial Number                                NaN
# Logger MAC Address                                  NaN
# Logger SIM                                          NaN
# Meter Pulse Value                                   NaN
# Meter Units                                         NaN
# Meter Capacity                                      NaN
# Network Point ID                                    NaN
# Tenant Meter.Name                                   NaN
# Fiscal Meter.Name                                   NaN
# EIS Space.Space number                              NaN
# Utility Type.Name                                   NaN
# Code                                          OC011-L99
#
#                                                      OC012-L99
# BuildingNo.                                              OC012
# Building                                   North Lodge Cottage
# Locations.Space.Space number                               NaN
# Space Name                                                 NaN
# Additional Location Info                                   NaN
# Description                   Data logger: North Lodge Cottage
# Classification Group                        EN.EN1 Data Logger
# Record                                                     NaN
# HVAC Ref                                                   NaN
# Element Description                                        NaN
# Servicable Area                                            NaN
# Model                                                      NaN
# Make                                                       NaN
# EIS ID                                                     NaN
# Logger Channel                                               0
# Logger Upstream Comms Target                               NaN
# Logger Modem Serial Number                                 NaN
# Logger IP Address                                          NaN
# Logger Serial Number                                       NaN
# Logger MAC Address                                         NaN
# Logger SIM                                                 NaN
# Meter Pulse Value                                          NaN
# Meter Units                                                NaN
# Meter Capacity                                             NaN
# Network Point ID                                           NaN
# Tenant Meter.Name                                          NaN
# Fiscal Meter.Name                                          NaN
# EIS Space.Space number                                     NaN
# Utility Type.Name                                          NaN
# Code                                                 OC012-L99
#
# [30 rows x 359 columns]

# %%
master_loggerscontrollers_for_validation.T
# Out:
#                                                 AP000-L01  \
# Building Code                                       AP000
# Building Name                              Alexandra Park
# Space                                                  A0
# Description                   Data logger: Alexandra Park
# Classification Group                          Data logger
# Make                                              Enercom
# Model                                         Multilog G2
# Logger Serial Number                         050157C7ED00
# Logger Mac Address                      00-50-C2-2C-3E-43
# Logger Ip Address                              10.23.9.39
# Logger Modem Serial Number                            NaN
# Logger Sim                                            NaN
# Network Point Id                                      NaN
# Logger Upstream Comms Target                          NaN
# Additional Location Info        Graduatae 1-11 Plant Room
# Code                                            AP000-L01
#
#                                                 AP000-L02  \
# Building Code                                       AP000
# Building Name                              Alexandra Park
# Space                                                  A0
# Description                   Data logger: Alexandra Park
# Classification Group                          Data logger
# Make                                              Enercom
# Model                                         Multilog G2
# Logger Serial Number                             37475126
# Logger Mac Address                                    NaN
# Logger Ip Address                                     NaN
# Logger Modem Serial Number                            NaN
# Logger Sim                                            NaN
# Network Point Id                                      NaN
# Logger Upstream Comms Target                          NaN
# Additional Location Info      External Gas Meter Building
# Code                                            AP000-L02
#
#                                                  AP000-L03  \
# Building Code                                        AP000
# Building Name                               Alexandra Park
# Space                                                   A0
# Description                    Data logger: Alexandra Park
# Classification Group                           Data logger
# Make                                               Enercom
# Model                                          Multilog G2
# Logger Serial Number                              48015355
# Logger Mac Address                                     NaN
# Logger Ip Address                                      NaN
# Logger Modem Serial Number                             NaN
# Logger Sim                                             NaN
# Network Point Id                                       NaN
# Logger Upstream Comms Target                           NaN
# Additional Location Info      External Water Meter Chamber
# Code                                             AP000-L03
#
#                                                 AP000-L99  \
# Building Code                                       AP000
# Building Name                              Alexandra Park
# Space                                                 NaN
# Description                   Data logger: Alexandra Park
# Classification Group                          Data logger
# Make                                                  NaN
# Model                                                 NaN
# Logger Serial Number                                  NaN
# Logger Mac Address                                    NaN
# Logger Ip Address                                     NaN
# Logger Modem Serial Number                            NaN
# Logger Sim                                            NaN
# Network Point Id                                      NaN
# Logger Upstream Comms Target                          NaN
# Additional Location Info                              NaN
# Code                                            AP000-L99
#
#                                                                AP001-L01  \
# Building Code                                                      AP001
# Building Name                 House 01 - Bassenthwaite, Graduate College
# Space                                                               A104
# Description                      Data logger: Graduate College - House 1
# Classification Group                                         Data logger
# Make                                                             Enercom
# Model                                                        Multilog G2
# Logger Serial Number                                        0501E3E97100
# Logger Mac Address                                     00-50-C2-2C-3D-DE
# Logger Ip Address                                            10.23.12.36
# Logger Modem Serial Number                                           NaN
# Logger Sim                                                           NaN
# Network Point Id                                                     NaN
# Logger Upstream Comms Target                                         NaN
# Additional Location Info                                            A017
# Code                                                           AP001-L01
#
#                                                             AP009-L01  \
# Building Code                                                   AP009
# Building Name                     House 09 - Devoke, Graduate College
# Space                                                            A124
# Description                   Data logger: Graduate College - House 9
# Classification Group                                      Data logger
# Make                                                          Enercom
# Model                                                     Multilog G2
# Logger Serial Number                                     0501E38A6300
# Logger Mac Address                                  00-50-C2-2C-3D-CB
# Logger Ip Address                                                 NaN
# Logger Modem Serial Number                                        NaN
# Logger Sim                                                        NaN
# Network Point Id                                                  NaN
# Logger Upstream Comms Target                                      NaN
# Additional Location Info                      Devoke House, Room A124
# Code                                                        AP009-L01
#
#                                                              AP010-L01  \
# Building Code                                                    AP010
# Building Name                  House 10 - Elterwater, Graduate College
# Space                                                             A109
# Description                   Data logger: Graduate College - House 10
# Classification Group                                       Data logger
# Make                                                           Enercom
# Model                                                      Multilog G2
# Logger Serial Number                                      0501E3D07500
# Logger Mac Address                                   00-50-C2-2C-3D-D1
# Logger Ip Address                                          10.23.12.37
# Logger Modem Serial Number                                         NaN
# Logger Sim                                                         NaN
# Network Point Id                                                   NaN
# Logger Upstream Comms Target                                       NaN
# Additional Location Info                   Elderwater House, Room A109
# Code                                                         AP010-L01
#
#                                                              AP011-L01  \
# Building Code                                                    AP011
# Building Name                   House 11 - Ennerdale, Graduate College
# Space                                                             A102
# Description                   Data logger: Graduate College - House 11
# Classification Group                                       Data logger
# Make                                                           Enercom
# Model                                                      Multilog G2
# Logger Serial Number                                      0501E3839500
# Logger Mac Address                                   00-50-C2-2C-3D-A7
# Logger Ip Address                                          10.23.12.38
# Logger Modem Serial Number                                         NaN
# Logger Sim                                                         NaN
# Network Point Id                                                   NaN
# Logger Upstream Comms Target                                       NaN
# Additional Location Info                   Ennerdale House - Room A102
# Code                                                         AP011-L01
#
#                                                            AP057-L01  \
# Building Code                                                  AP057
# Building Name                              Alexandra Park Laundrette
# Space                                                             A0
# Description                   Data logger: Alexandra Park Laundrette
# Classification Group                                     Data logger
# Make                                                         Enercom
# Model                                                    Multilog G2
# Logger Serial Number                                    050157C16100
# Logger Mac Address                                               NaN
# Logger Ip Address                                 80.93.175.91:40455
# Logger Modem Serial Number                                       NaN
# Logger Sim                                                       NaN
# Network Point Id                                                 NaN
# Logger Upstream Comms Target                                     NaN
# Additional Location Info                          Cartmel Laundrette
# Code                                                       AP057-L01
#
#                                                              AP080-L01  \
# Building Code                                                    AP080
# Building Name                                Lonsdale House (Block 12)
# Space                                                              A13
# Description                   Data logger: Lonsdale House - Laundrette
# Classification Group                                       Data logger
# Make                                                           Enercom
# Model                                                      Multilog G2
# Logger Serial Number                                      050157AB6700
# Logger Mac Address                                   00-50-C2-2C-3D-1B
# Logger Ip Address                                           10.23.9.40
# Logger Modem Serial Number                                         NaN
# Logger Sim                                                         NaN
# Network Point Id                                                   NaN
# Logger Upstream Comms Target                                       NaN
# Additional Location Info                                Plant Room MCC
# Code                                                         AP080-L01
#
#                                             ...                 \
# Building Code                               ...
# Building Name                               ...
# Space                                       ...
# Description                                 ...
# Classification Group                        ...
# Make                                        ...
# Model                                       ...
# Logger Serial Number                        ...
# Logger Mac Address                          ...
# Logger Ip Address                           ...
# Logger Modem Serial Number                  ...
# Logger Sim                                  ...
# Network Point Id                            ...
# Logger Upstream Comms Target                ...
# Additional Location Info                    ...
# Code                                        ...
#
#                                                            OC004-B01  \
# Building Code                                                  OC004
# Building Name                                      Chancellors Wharf
# Space                                                            NaN
# Description                        BMS Controller: Chancellors Wharf
# Classification Group                                  BMS controller
# Make                                                           Trend
# Model                                                      IQ3xact12
# Logger Serial Number          {48352BB4-4B1B-4013-AB9F-14E143E83948}
# Logger Mac Address                                               NaN
# Logger Ip Address                         cw-meter03-plant.bms.local
# Logger Modem Serial Number                                       NaN
# Logger Sim                                                       NaN
# Network Point Id                                                 NaN
# Logger Upstream Comms Target                                     NaN
# Additional Location Info                                         NaN
# Code                                                       OC004-B01
#
#                                                                 OC004-L99  \
# Building Code                                                       OC004
# Building Name                              Chancellor's Wharf, Wyre House
# Space                                                                 NaN
# Description                   Data logger: Chancellor's Wharf, Wyre House
# Classification Group                                          Data logger
# Make                                                                  NaN
# Model                                                                 NaN
# Logger Serial Number                                                  NaN
# Logger Mac Address                                                    NaN
# Logger Ip Address                                                     NaN
# Logger Modem Serial Number                                            NaN
# Logger Sim                                                            NaN
# Network Point Id                                                      NaN
# Logger Upstream Comms Target                                          NaN
# Additional Location Info                                              NaN
# Code                                                            OC004-L99
#
#                                                            OC005-B01  \
# Building Code                                                  OC005
# Building Name                                      Chancellors Wharf
# Space                                                            NaN
# Description                        BMS Controller: Chancellors Wharf
# Classification Group                                  BMS controller
# Make                                                           Trend
# Model                                                      IQ3xact12
# Logger Serial Number          {281682DC-5479-4064-8290-E873933872B0}
# Logger Mac Address                                               NaN
# Logger Ip Address                         cw-meter02-plant.bms.local
# Logger Modem Serial Number                                       NaN
# Logger Sim                                                       NaN
# Network Point Id                                                 NaN
# Logger Upstream Comms Target                                     NaN
# Additional Location Info                                         NaN
# Code                                                       OC005-B01
#
#                                                                 OC005-L99  \
# Building Code                                                       OC005
# Building Name                              Chancellor's Wharf, Lune House
# Space                                                                 NaN
# Description                   Data logger: Chancellor's Wharf, Lune House
# Classification Group                                          Data logger
# Make                                                                  NaN
# Model                                                                 NaN
# Logger Serial Number                                                  NaN
# Logger Mac Address                                                    NaN
# Logger Ip Address                                                     NaN
# Logger Modem Serial Number                                            NaN
# Logger Sim                                                            NaN
# Network Point Id                                                      NaN
# Logger Upstream Comms Target                                          NaN
# Additional Location Info                                              NaN
# Code                                                            OC005-L99
#
#                                                            OC006-B01  \
# Building Code                                                  OC006
# Building Name                                      Chancellors Wharf
# Space                                                            NaN
# Description                        BMS Controller: Chancellors Wharf
# Classification Group                                  BMS controller
# Make                                                           Trend
# Model                                                      IQ3xact12
# Logger Serial Number          {BBD3685B-B0DC-417F-A0E8-20139B1074E1}
# Logger Mac Address                                               NaN
# Logger Ip Address                         cw-meter01-plant.bms.local
# Logger Modem Serial Number                                       NaN
# Logger Sim                                                       NaN
# Network Point Id                                                 NaN
# Logger Upstream Comms Target                                     NaN
# Additional Location Info                                         NaN
# Code                                                       OC006-B01
#
#                                                                 OC006-L99  \
# Building Code                                                       OC006
# Building Name                              Chancellor's Wharf, Kent House
# Space                                                                 NaN
# Description                   Data logger: Chancellor's Wharf, Kent House
# Classification Group                                          Data logger
# Make                                                                  NaN
# Model                                                                 NaN
# Logger Serial Number                                                  NaN
# Logger Mac Address                                                    NaN
# Logger Ip Address                                                     NaN
# Logger Modem Serial Number                                            NaN
# Logger Sim                                                            NaN
# Network Point Id                                                      NaN
# Logger Upstream Comms Target                                          NaN
# Additional Location Info                                              NaN
# Code                                                            OC006-L99
#
#                                                          OC007-L99  \
# Building Code                                                OC007
# Building Name                              Hazelrigg Field Station
# Space                                                          NaN
# Description                   Data logger: Hazelrigg Field Station
# Classification Group                                   Data logger
# Make                                                           NaN
# Model                                                          NaN
# Logger Serial Number                                           NaN
# Logger Mac Address                                             NaN
# Logger Ip Address                                              NaN
# Logger Modem Serial Number                                     NaN
# Logger Sim                                                     NaN
# Network Point Id                                               NaN
# Logger Upstream Comms Target                                   NaN
# Additional Location Info                                       NaN
# Code                                                     OC007-L99
#
#                                           OC008-L99  \
# Building Code                                 OC008
# Building Name                              Downings
# Space                                           NaN
# Description                   Data logger: Downings
# Classification Group                    Data logger
# Make                                            NaN
# Model                                           NaN
# Logger Serial Number                            NaN
# Logger Mac Address                              NaN
# Logger Ip Address                               NaN
# Logger Modem Serial Number                      NaN
# Logger Sim                                      NaN
# Network Point Id                                NaN
# Logger Upstream Comms Target                    NaN
# Additional Location Info                        NaN
# Code                                      OC008-L99
#
#                                               OC011-L99  \
# Building Code                                     OC011
# Building Name                              Wind Turbine
# Space                                               NaN
# Description                   Data logger: Wind Turbine
# Classification Group                        Data logger
# Make                                                NaN
# Model                                               NaN
# Logger Serial Number                                NaN
# Logger Mac Address                                  NaN
# Logger Ip Address                                   NaN
# Logger Modem Serial Number                          NaN
# Logger Sim                                          NaN
# Network Point Id                                    NaN
# Logger Upstream Comms Target                        NaN
# Additional Location Info                            NaN
# Code                                          OC011-L99
#
#                                                      OC012-L99
# Building Code                                            OC012
# Building Name                              North Lodge Cottage
# Space                                                      NaN
# Description                   Data logger: North Lodge Cottage
# Classification Group                               Data logger
# Make                                                       NaN
# Model                                                      NaN
# Logger Serial Number                                       NaN
# Logger Mac Address                                         NaN
# Logger Ip Address                                          NaN
# Logger Modem Serial Number                                 NaN
# Logger Sim                                                 NaN
# Network Point Id                                           NaN
# Logger Upstream Comms Target                               NaN
# Additional Location Info                                   NaN
# Code                                                 OC012-L99
#
# [16 rows x 378 columns]

# %% [markdown]
# Create dictionary that maps Planon column names onto Master.
#
# From Nicola:
# - EIS ID (Serial Number)
# - Make
# - Model
# - Description
# - Code (Asset Code)
# - Building Code
#
# `Building code` and `Building name` are implicitly included. `Logger IP` or `MAC` would be essential to include, as well as `Make` and `Model`. `Additional Location Info` is not essnetial but would be useful to have. Locations (`Locations.Space.Space number` and `Space Name`) are included in the Planon export - but this is their only viable data source, therefore are not validated against.

# %%
#Planon:Master
loggers_match_dict={
      "BuildingNo.":"Building Code",
      "Building":"Building Name",
      "Description":"Description",
      "EIS ID":"Logger Serial Number",
      "Make":"Make",
      "Model":"Model",
      "Code":"Code"
      }

# %%
master_loggerscontrollers_for_validation_filtered=master_loggerscontrollers_for_validation[list(loggers_match_dict.values())]
planon_loggerscontrollers_filtered=planon_loggerscontrollers[list(loggers_match_dict.keys())]

# %%
master_loggerscontrollers_for_validation_filtered.head(2)
# Out:
#             Building Name     Make Logger Serial Number Building Code  \
# AP000-L01  Alexandra Park  Enercom         050157C7ED00         AP000
# AP000-L02  Alexandra Park  Enercom             37475126         AP000
#
#                  Model                  Description       Code
# AP000-L01  Multilog G2  Data logger: Alexandra Park  AP000-L01
# AP000-L02  Multilog G2  Data logger: Alexandra Park  AP000-L02

# %%
planon_loggerscontrollers_filtered.head(2)
# Out:
#                  Building     Make        EIS ID BuildingNo.        Model  \
# AP000-L01  Alexandra Park  Enercom  050157C7ED00       AP000  Multilog G2
# AP000-L02  Alexandra Park  Enercom      37475126       AP000  Multilog G2
#
#                            Description       Code
# AP000-L01  Data logger: Alexandra Park  AP000-L01
# AP000-L02  Data logger: Alexandra Park  AP000-L02

# %%
planon_loggerscontrollers_filtered.columns=[loggers_match_dict[i] for i in planon_loggerscontrollers_filtered]

# %%
planon_loggerscontrollers_filtered.drop_duplicates(inplace=True)
master_loggerscontrollers_for_validation_filtered.drop_duplicates(inplace=True)
# Out:
# C:\Anaconda2\envs\python3\lib\site-packages\pandas\util\decorators.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return func(*args, **kwargs)

# %%
planon_loggerscontrollers_filtered.head(2)
# Out:
#             Building Name     Make Logger Serial Number Building Code  \
# AP000-L01  Alexandra Park  Enercom         050157C7ED00         AP000
# AP000-L02  Alexandra Park  Enercom             37475126         AP000
#
#                  Model                  Description       Code
# AP000-L01  Multilog G2  Data logger: Alexandra Park  AP000-L01
# AP000-L02  Multilog G2  Data logger: Alexandra Park  AP000-L02

# %%
master_loggerscontrollers_for_validation_filtered.head(2)
# Out:
#             Building Name     Make Logger Serial Number Building Code  \
# AP000-L01  Alexandra Park  Enercom         050157C7ED00         AP000
# AP000-L02  Alexandra Park  Enercom             37475126         AP000
#
#                  Model                  Description       Code
# AP000-L01  Multilog G2  Data logger: Alexandra Park  AP000-L01
# AP000-L02  Multilog G2  Data logger: Alexandra Park  AP000-L02

# %%
a=np.sort(list(set(planon_loggerscontrollers_filtered.index)))
b=np.sort(list(set(master_loggerscontrollers_for_validation_filtered.index)))
loggerscontrollers_not_in_planon=[]
for i in b:
    if i not in a:
        print(i+',',end=" "),
        loggerscontrollers_not_in_planon.append(i)
print('\n\nLoggers in Master, but not in Planon:',
      len(loggerscontrollers_not_in_planon),'/',len(b),':',
      round(len(loggerscontrollers_not_in_planon)/len(b)*100,3),'%')
# Out:
# MC032-L01, MC032-L03, MC044-L02, MC044-L03, MC044-L04, MC044-L05, MC046-L01, MC046-L03, MC046-L04, MC061-L01, MC076-B03, MC202-B17, MC202-L04, MC204-L03, MC204-L04, MC204-L07, MC204-L08, MC204-L09, MC207-L01,
#
# Loggers in Master, but not in Planon: 19 / 378 : 5.026 %

# %%
a=np.sort(list(set(planon_loggerscontrollers_filtered.index)))
b=np.sort(list(set(master_loggerscontrollers_for_validation_filtered.index)))
loggerscontrollers_not_in_master=[]
for i in a:
    if i not in b:
        print(i+',',end=" "),
        loggerscontrollers_not_in_master.append(i)
print('\n\nLoggers in Planon, not in Master:',
      len(loggerscontrollers_not_in_master),'/',len(a),':',
      round(len(loggerscontrollers_not_in_master)/len(a)*100,3),'%')
# Out:
# Loggers in Planon, not in Master: 0 / 359 : 0.0 %

# %%
print(len(planon_loggerscontrollers_filtered.index))
print(len(set(planon_loggerscontrollers_filtered.index)))
print(len(master_loggerscontrollers_for_validation_filtered.index))
print(len(set(master_loggerscontrollers_for_validation_filtered.index)))
# Out:
# 359
# 359
# 378
# 378

# %%
master_loggerscontrollers_for_validation_filtered[master_loggerscontrollers_for_validation_filtered.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Building Name, Make, Logger Serial Number, Building Code, Model, Description, Code]
# Index: []

# %%
comon_index=list(set(master_loggerscontrollers_for_validation_filtered.index).intersection(set(planon_loggerscontrollers_filtered.index)))

# %%
master_loggerscontrollers_for_validation_intersected=master_loggerscontrollers_for_validation_filtered.loc[comon_index].sort_index()
planon_loggerscontrollers_intersected=planon_loggerscontrollers_filtered.loc[comon_index].sort_index()

# %%
master_loggerscontrollers_for_validation_intersected.head(2)
# Out:
#             Building Name     Make Logger Serial Number Building Code  \
# AP000-L01  Alexandra Park  Enercom         050157C7ED00         AP000
# AP000-L02  Alexandra Park  Enercom             37475126         AP000
#
#                  Model                  Description       Code
# AP000-L01  Multilog G2  Data logger: Alexandra Park  AP000-L01
# AP000-L02  Multilog G2  Data logger: Alexandra Park  AP000-L02

# %%
planon_loggerscontrollers_intersected.head(2)
# Out:
#             Building Name     Make Logger Serial Number Building Code  \
# AP000-L01  Alexandra Park  Enercom         050157C7ED00         AP000
# AP000-L02  Alexandra Park  Enercom             37475126         AP000
#
#                  Model                  Description       Code
# AP000-L01  Multilog G2  Data logger: Alexandra Park  AP000-L01
# AP000-L02  Multilog G2  Data logger: Alexandra Park  AP000-L02

# %%
planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected
# Out:
#           Building Name   Make Logger Serial Number Building Code  Model  \
# AP000-L01          True   True                 True          True   True
# AP000-L02          True   True                False          True   True
# AP000-L03          True   True                False          True   True
# AP000-L99          True  False                False          True  False
# AP001-L01          True   True                 True          True   True
# AP009-L01          True   True                 True          True   True
# AP010-L01          True   True                 True          True   True
# AP011-L01          True   True                 True          True   True
# AP057-L01          True   True                 True          True   True
# AP080-L01          True   True                 True          True   True
# AP080-L79          True  False                False          True  False
# AP080-L80          True  False                False          True  False
# AP080-L81          True  False                False          True  False
# AP081-L01          True   True                 True          True   True
# EX000-L99          True  False                False          True  False
# EX001-B01         False   True                 True          True   True
# EX005-L99          True  False                False          True  False
# FH000-L99          True  False                False          True  False
# FH002-L99          True  False                False          True  False
# FH003-L99          True  False                False          True  False
# FH008-L99          True  False                False          True  False
# FH012-L99          True  False                False          True  False
# MC000-L01          True   True                 True          True   True
# MC000-L99          True  False                False          True  False
# MC001-B01          True   True                 True          True   True
# MC001-L01          True   True                 True          True   True
# MC001-L02          True   True                 True          True   True
# MC001-L82          True  False                False          True  False
# MC001-L99          True  False                False          True  False
# MC002-L99          True  False                False          True  False
# ...                 ...    ...                  ...           ...    ...
# MC204-L06          True   True                 True          True   True
# MC204-L73          True   True                 True          True   True
# MC204-L74          True   True                 True          True   True
# MC204-L75          True   True                 True          True   True
# MC204-L82          True  False                False          True  False
# MC204-L99          True   True                 True          True   True
# MC207-B01          True   True                 True          True   True
# MC207-L52          True   True                 True          True   True
# MC207-L53          True   True                 True          True   True
# MC207-L82          True  False                False          True  False
# MC210-B01          True   True                 True          True   True
# MC210-B02          True   True                 True          True   True
# MC210-B03          True   True                 True          True   True
# MC210-L01          True   True                False          True   True
# MC210-L02          True   True                False          True   True
# MC210-L82          True  False                False          True  False
# MC211-B01          True   True                 True          True   True
# MC211-L82          True  False                False          True  False
# OC001-L99          True  False                False          True  False
# OC003-L99          True  False                False          True  False
# OC004-B01         False   True                 True          True   True
# OC004-L99          True  False                False          True  False
# OC005-B01         False   True                 True          True   True
# OC005-L99          True  False                False          True  False
# OC006-B01         False   True                 True          True   True
# OC006-L99          True  False                False          True  False
# OC007-L99          True  False                False          True  False
# OC008-L99          True  False                False          True  False
# OC011-L99          True  False                False          True  False
# OC012-L99          True  False                False          True  False
#
#           Description  Code
# AP000-L01        True  True
# AP000-L02        True  True
# AP000-L03        True  True
# AP000-L99        True  True
# AP001-L01        True  True
# AP009-L01        True  True
# AP010-L01        True  True
# AP011-L01        True  True
# AP057-L01        True  True
# AP080-L01        True  True
# AP080-L79        True  True
# AP080-L80        True  True
# AP080-L81        True  True
# AP081-L01        True  True
# EX000-L99        True  True
# EX001-B01        True  True
# EX005-L99        True  True
# FH000-L99        True  True
# FH002-L99        True  True
# FH003-L99        True  True
# FH008-L99        True  True
# FH012-L99        True  True
# MC000-L01        True  True
# MC000-L99        True  True
# MC001-B01        True  True
# MC001-L01        True  True
# MC001-L02        True  True
# MC001-L82        True  True
# MC001-L99        True  True
# MC002-L99        True  True
# ...               ...   ...
# MC204-L06        True  True
# MC204-L73        True  True
# MC204-L74        True  True
# MC204-L75        True  True
# MC204-L82        True  True
# MC204-L99        True  True
# MC207-B01        True  True
# MC207-L52        True  True
# MC207-L53        True  True
# MC207-L82        True  True
# MC210-B01        True  True
# MC210-B02        True  True
# MC210-B03        True  True
# MC210-L01        True  True
# MC210-L02        True  True
# MC210-L82        True  True
# MC211-B01        True  True
# MC211-L82        True  True
# OC001-L99        True  True
# OC003-L99        True  True
# OC004-B01        True  True
# OC004-L99        True  True
# OC005-B01        True  True
# OC005-L99        True  True
# OC006-B01        True  True
# OC006-L99        True  True
# OC007-L99        True  True
# OC008-L99        True  True
# OC011-L99        True  True
# OC012-L99        True  True
#
# [359 rows x 7 columns]

# %% [markdown]
# Loggers matching

# %%
(planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected).sum()
# Out:
# Building Name           341
# Make                    302
# Logger Serial Number    288
# Building Code           359
# Model                   302
# Description             359
# Code                    359
# dtype: int64

# %% [markdown]
# Percentage matching

# %%
(planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100
# Out:
# Building Name            94.986072
# Make                     84.122563
# Logger Serial Number     80.222841
# Building Code           100.000000
# Model                    84.122563
# Description             100.000000
# Code                    100.000000
# dtype: float64

# %%
((planon_loggerscontrollers_intersected==master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100).plot(kind='bar')

# %% [markdown]
# Loggers not matching on `Building Name`.

# %%
sum(planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name'])
# Out:
# 18

# %%
planon_loggerscontrollers_intersected['Building Name']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in planon_loggerscontrollers_intersected['Building Name'].values]
master_loggerscontrollers_for_validation_intersected['Building Name']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ') for s in master_loggerscontrollers_for_validation_intersected['Building Name'].values]

# %%
sum(planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name'])
# Out:
# 16

# %% [markdown]
# That didnt help.

# %%
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name']].index:
    print(i,'\t\tPlanon:',planon_loggerscontrollers_intersected.loc[i]['Building Name'],'\t\tMaster:',master_loggerscontrollers_for_validation_intersected.loc[i]['Building Name'])
# Out:
# EX001-B01 		Planon: roads - main campus 		Master: underpass
# MC029-B01 		Planon: cetad 		Master: bowland hall cetad
# MC033-L03 		Planon: county john creed 		Master: john creed
# MC047-B02 		Planon: welcome centre 		Master: conference centre
# MC047-L01 		Planon: welcome centre 		Master: conference centre
# MC047-L02 		Planon: welcome centre 		Master: conference centre
# MC055-B01 		Planon: furness residences 		Master: furness blocks
# MC071-B01 		Planon: furness college 		Master: furness
# MC072-B02 		Planon: psc 		Master: psc building
# MC072-B04 		Planon: psc 		Master: psc building
# MC103-B01 		Planon: lancaster house hotel 		Master: hotel
# MC198-B01 		Planon: grizedale college - offices, bar & social space 		Master: grizedale
# MC198-B02 		Planon: grizedale college - offices, bar & social space 		Master: grizedale
# OC004-B01 		Planon: chancellor's wharf, wyre house 		Master: chancellors wharf
# OC005-B01 		Planon: chancellor's wharf, lune house 		Master: chancellors wharf
# OC006-B01 		Planon: chancellor's wharf, kent house 		Master: chancellors wharf

# %% [markdown]
# Follow up with lexical distance comparison. That would flag this as a match.

# %% [markdown]
# Loggers not matching on `Serial Number`.

# %%
sum(planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number'])
# Out:
# 71

# %%
planon_loggerscontrollers_intersected['Logger Serial Number']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ').replace('{','').replace('}','') for s in planon_loggerscontrollers_intersected['Logger Serial Number'].values]
master_loggerscontrollers_for_validation_intersected['Logger Serial Number']=[str(s).lower().strip().replace('  ',' ').replace('   ',' ').replace('{','').replace('}','') for s in master_loggerscontrollers_for_validation_intersected['Logger Serial Number'].values]

# %%
sum(planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number'])
# Out:
# 9

# %%
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number']].index:
    print(i,'\t\tPlanon:',planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'],'\t\tMaster:',master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number'])
# Out:
# MC032-L04 		Planon: 50198367 		Master: 050198367e00
# MC046-L05 		Planon: 50198895300 		Master: 050198895300
# MC063-L01 		Planon: 50198829500 		Master: 050198829500
# MC064-L03 		Planon: 50198872600 		Master: 050198872600
# MC071-L02 		Planon: 50201286300 		Master: 050201286300
# MC071-L05 		Planon: 50201221 		Master: 050201221e00
# MC071-L16 		Planon: 50198904000 		Master: 050198904000
# MC078-L03 		Planon: 50198864300 		Master: 050198864300
# MC102-L01 		Planon: 50157909800 		Master: 050157909800

# %% [markdown]
# Technically the same, but there is a number format error. Compare based on float value, if they match, replace one of them. This needs to be amended, as it will throw `cannot onvert to float` exception if strings are left in from the previous step.

# %%
z1=[]
z2=[]    
for i in planon_loggerscontrollers_intersected.index:
    if planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number']:
        if float(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])==\
          float(master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number']):
                z1.append(str(int(float(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number']))))
                z2.append(str(int(float(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number']))))
        else:
            z1.append(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])
            z2.append(master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number'])
    else:
        z1.append(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])
        z2.append(planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'])
planon_loggerscontrollers_intersected['Logger Serial Number']=z1
master_loggerscontrollers_for_validation_intersected['Logger Serial Number']=z2

# %%
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Logger Serial Number']!=master_loggerscontrollers_for_validation_intersected['Logger Serial Number']].index:
    print(i,'\t\tPlanon:',planon_loggerscontrollers_intersected.loc[i]['Logger Serial Number'],'\t\tMaster:',master_loggerscontrollers_for_validation_intersected.loc[i]['Logger Serial Number'])

# %% [markdown]
# New error percentage:

# %%
(planon_loggerscontrollers_intersected!=master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100
# Out:
# Building Name            4.456825
# Make                    15.877437
# Logger Serial Number     0.000000
# Building Code            0.000000
# Model                   15.877437
# Description              0.000000
# Code                     0.000000
# dtype: float64

# %% [markdown]
# (Bearing in my mind the above, this is technically 0)

# %%
a=np.sort(list(set(planon_meterssensors_filtered.index)))
b=np.sort(list(set(master_meterssensors_for_validation_filtered.index)))
meterssensors_not_in_planon=[]
for i in b:
    if i not in a:
        print(i+',',end=" "),
        meterssensors_not_in_planon.append(i)
print('\n\nMeters in Master, but not in Planon:',
      len(meterssensors_not_in_planon),'/',len(b),':',
      round(len(meterssensors_not_in_planon)/len(b)*100,3),'%')
# Out:
# AP000-L99/M303, AP000-L99/M308, AP080-L79/M001, AP080-L80/M001, AP080-L81/M001, EX001-B01/N1, EX001-B01/O1, EX001-B01/O2, EX001-B01/O3, MC000-L99/M201, MC000-L99/M202, MC000-L99/M203, MC000-L99/M506, MC001-B01/N1, MC001-L82-M972, MC001-L82-M973, MC001-L82-M974, MC001-L82-M975, MC001-L82-M976, MC001-L99/M100, MC001-L99/M222, MC001-L99/M224, MC001-L99/M306, MC001-L99/M508, MC003-B01/N1, MC003-L99/M207, MC003-L99/M304, MC003-L99/M509, MC007-L99/M211, MC007-L99/M511, MC008-L82-M916, MC008-L99/M302, MC010-L82-M745, MC010-L82-M746, MC010-L82-M747, MC010-L82-M748, MC010-L82-M749, MC010-L82-M750, MC010-L82-M751, MC010-L82-M752, MC010-L82-M753, MC010-L82-M754, MC010-L82-M755, MC010-L82-M756, MC010-L82-M757, MC010-L82-M758, MC010-L82-M759, MC010-L82-M760, MC010-L82-M761, MC010-L82-M762, MC010-L82-M763, MC010-L82-M764, MC010-L82-M765, MC010-L82-M766, MC010-L82-M767, MC010-L82-M768, MC010-L82-M769, MC010-L82-M770, MC010-L82-M771, MC010-L82-M772, MC011-B01/N1, MC011-B01/O2, MC011-L82-M953, MC011-L82-M954, MC014-B01/N1, MC014-B01/O2, MC014-B01/O3, MC014-B02/N1, MC014-B02/O2, MC014-B02/O3, MC014-B03/N1, MC014-B03/O2, MC014-B03/O3, MC014-B04/N1, MC014-B04/O2, MC014-B04/O3, MC014-B05/N1, MC014-B05/O2, MC014-B05/O3, MC014-B06/N1, MC014-B06/O2, MC014-B06/O3, MC014-B07/N1, MC014-B07/O2, MC014-B07/O3, MC014-B08/N1, MC014-B08/O2, MC014-B08/O3, MC014-B09/N1, MC014-B09/O2, MC014-B09/O3, MC014-B10/N1, MC014-B10/O2, MC014-B10/O3, MC014-B11/N1, MC014-B11/O2, MC014-B11/O3, MC014-B12/N1, MC014-B12/O2, MC014-B12/O3, MC014-B13/N1, MC014-B13/O2, MC014-B13/O3, MC014-B14/N1, MC014-B14/O2, MC014-B14/O3, MC029-B01/N1, MC030-B01/N1, MC030-B01/O1, MC030-B01/O2, MC030-B01/O3, MC031-B01/N1, MC031-B02/N1, MC031-B02/O1, MC031-B02/O2, MC031-B02/O3, MC032-B01/N1, MC032-B01/N10, MC032-B01/N11, MC032-B01/N2, MC032-B01/N3, MC032-B01/N6, MC032-B01/O1, MC032-B02/N1, MC032-B02/O2, MC032-B02/O3, MC032-B03/N1, MC032-B03/O1, MC032-B04/N1, MC032-B04/O1, MC032-B05/N1, MC032-B06/N1, MC032-B06/N2, MC032-B07/N1, MC032-B07/O1, MC032-B07/O2, MC032-B07/O3, MC032-L82-M773, MC032-L82-M774, MC033-B01/N1, MC033-L82-M898, MC033-L82-M899, MC043-B01/N1, MC043-B01/N10, MC043-B01/N11, MC043-B01/N3, MC043-B01/N6, MC044-B01/N1, MC044-B01/N2, MC044-B01/N6, MC044-B01/O1, MC044-B01/O2, MC044-B01/O3, MC044-B02/N1, MC044-B02/N2, MC044-B02/N3, MC044-B02/N6, MC044-B02/O1, MC044-B02/O3, MC044-B03/N1, MC044-B03/N3, MC044-B03/N6, MC044-B03/O1, MC044-B03/O2, MC044-B03/O3, MC044-B04/N1, MC044-B04/N10, MC044-B04/N11, MC044-B04/N12, MC044-B04/N13, MC044-B04/N14, MC044-B04/N3, MC044-B04/N6, MC044-B04/N9, MC044-B05/N1, MC044-B05/N2, MC044-B05/N3, MC044-B05/N6, MC044-B05/O1, MC044-B05/O2, MC044-B05/O3, MC044-B06/N1, MC044-B06/N3, MC044-B06/N4, MC044-B06/N6, MC044-B06/O1, MC044-B06/O2, MC044-B06/O3, MC044-B07/N1, MC044-B07/N2, MC044-B07/N3, MC044-B07/N4, MC044-B07/N5, MC044-B07/N6, MC044-B07/N7, MC044-B08/N1, MC044-B08/N2, MC044-B08/N3, MC044-B08/N6, MC044-B08/O2, MC044-B08/O3, MC044-B09/I1, MC044-B09/I2, MC044-B09/I3, MC044-B09/I4, MC044-B09/N1, MC044-B09/N10, MC044-B09/N11, MC044-B09/N2, MC044-B09/N3, MC044-B09/N4, MC044-B09/N5, MC044-B09/N6, MC044-B09/N7, MC044-B09/N8, MC044-B09/N9, MC044-B10/N1, MC044-B10/N10, MC044-B10/N100, MC044-B10/N101, MC044-B10/N102, MC044-B10/N103, MC044-B10/N104, MC044-B10/N105, MC044-B10/N106, MC044-B10/N107, MC044-B10/N108, MC044-B10/N109, MC044-B10/N11, MC044-B10/N110, MC044-B10/N111, MC044-B10/N112, MC044-B10/N113, MC044-B10/N114, MC044-B10/N115, MC044-B10/N116, MC044-B10/N117, MC044-B10/N118, MC044-B10/N119, MC044-B10/N12, MC044-B10/N120, MC044-B10/N121, MC044-B10/N122, MC044-B10/N123, MC044-B10/N124, MC044-B10/N125, MC044-B10/N126, MC044-B10/N127, MC044-B10/N128, MC044-B10/N129, MC044-B10/N13, MC044-B10/N130, MC044-B10/N131, MC044-B10/N132, MC044-B10/N133, MC044-B10/N134, MC044-B10/N135, MC044-B10/N136, MC044-B10/N137, MC044-B10/N138, MC044-B10/N139, MC044-B10/N14, MC044-B10/N140, MC044-B10/N141, MC044-B10/N142, MC044-B10/N143, MC044-B10/N144, MC044-B10/N145, MC044-B10/N146, MC04 ...
#
# Meters in Master, but not in Planon: 1311 / 30135 : 4.35 %

# %%
q1=pd.DataFrame(meterssensors_not_in_planon)

# %%
a=np.sort(list(set(planon_meterssensors_filtered.index)))
b=np.sort(list(set(master_meterssensors_for_validation_filtered.index)))
meterssensors_not_in_master=[]
for i in a:
    if i not in b:
        print(i+',',end=" "),
        meterssensors_not_in_master.append(i)
print('\n\nMeters in Planon, not in Master:',
      len(meterssensors_not_in_master),'/',len(a),':',
      round(len(meterssensors_not_in_master)/len(a)*100,3),'%')
# Out:
# Meters in Planon, not in Master: 0 / 28824 : 0.0 %

# %%
q2=pd.DataFrame(meterssensors_not_in_master)

# %%
a=np.sort(list(set(planon_loggerscontrollers_filtered.index)))
b=np.sort(list(set(master_loggerscontrollers_for_validation_filtered.index)))
loggerscontrollers_not_in_planon=[]
for i in b:
    if i not in a:
        print(i+',',end=" "),
        loggerscontrollers_not_in_planon.append(i)
print('\n\nLoggers in Master, but not in Planon:',
      len(loggerscontrollers_not_in_planon),'/',len(b),':',
      round(len(loggerscontrollers_not_in_planon)/len(b)*100,3),'%')
# Out:
# MC032-L01, MC032-L03, MC044-L02, MC044-L03, MC044-L04, MC044-L05, MC046-L01, MC046-L03, MC046-L04, MC061-L01, MC076-B03, MC202-B17, MC202-L04, MC204-L03, MC204-L04, MC204-L07, MC204-L08, MC204-L09, MC207-L01,
#
# Loggers in Master, but not in Planon: 19 / 378 : 5.026 %

# %%
q3=pd.DataFrame(loggerscontrollers_not_in_planon)

# %%
a=np.sort(list(set(planon_loggerscontrollers_filtered.index)))
b=np.sort(list(set(master_loggerscontrollers_for_validation_filtered.index)))
loggerscontrollers_not_in_master=[]
for i in a:
    if i not in b:
        print(i+',',end=" "),
        loggerscontrollers_not_in_master.append(i)
print('\n\nLoggers in Planon, not in Master:',
      len(loggerscontrollers_not_in_master),'/',len(a),':',
      round(len(loggerscontrollers_not_in_master)/len(a)*100,3),'%')
# Out:
# Loggers in Planon, not in Master: 0 / 359 : 0.0 %

# %%
q4=pd.DataFrame(loggerscontrollers_not_in_master)

# %%
q5=pd.DataFrame((planon_meterssensors_intersected!=master_meterssensors_for_validation_intersected).sum()/\
len(planon_meterssensors_intersected)*100)

# %%
q6=pd.DataFrame((planon_loggerscontrollers_intersected!=master_loggerscontrollers_for_validation_intersected).sum()/\
len(planon_loggerscontrollers_intersected)*100)

# %%
w1=[]
for i in planon_meterssensors_intersected[planon_meterssensors_intersected['Description']!=master_meterssensors_for_validation_intersected['Description']].index:
    w1.append({"Meter":i,'Planon':planon_meterssensors_intersected.loc[i]['Description'],
               'Master':master_meterssensors_for_validation_intersected.loc[i]['Description']})

# %%
q7=pd.DataFrame(w1)

# %%
w2=[]
for i in planon_loggerscontrollers_intersected[planon_loggerscontrollers_intersected['Building Name']!=master_loggerscontrollers_for_validation_intersected['Building Name']].index:
    w2.append({"Logger":i,'Planon':planon_loggerscontrollers_intersected.loc[i]['Building Name'],
               'Master':master_loggerscontrollers_for_validation_intersected.loc[i]['Building Name']})

# %%
q8=pd.DataFrame(w2)

# %%
writer = pd.ExcelWriter('final5.xlsx')
q1.to_excel(writer,'Meters Master, not Planon')
q2.to_excel(writer,'Meters Planon, not Master')
q3.to_excel(writer,'Loggers Master, not Planon')
q4.to_excel(writer,'Loggers Planon, not Master')
q5.to_excel(writer,'Meters error perc')
q6.to_excel(writer,'Loggers error perc')
q7.to_excel(writer,'Meters naming conflcits')
q8.to_excel(writer,'Loggers naming conflicts')
writer.save()
