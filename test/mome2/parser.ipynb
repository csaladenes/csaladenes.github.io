# %%
import pandas as pd
import bs4 as bs

# %%
dfs=pd.read_html('https://en.wikipedia.org/wiki/Research_stations_in_Antarctica#List_of_research_stations')

# %%
dfr=pd.read_html('https://en.wikipedia.org/wiki/Antarctic_field_camps')

# %%
df=dfs[1][1:]

# %%
df.columns=dfs[1].loc[0].values

# %%
df.to_excel('bases.xlsx')

# %%
import requests

# %%
url='https://en.wikipedia.org/wiki/Research_stations_in_Antarctica'
f=requests.get(url).content
soup = bs.BeautifulSoup(f, 'lxml')
parsed_table = soup.find_all('table')[1] 
data = [[''.join(td.strings)+'#'+td.a['href'] if td.find('a') else 
         ''.join(td.strings)
         for td in row.find_all('td')]
        for row in parsed_table.find_all('tr')]
headers=[''.join(row.strings)
        for row in parsed_table.find_all('th')]
df = pd.DataFrame(data[1:], columns=headers)

# %%
stations=[]
for i in df.T.iteritems():
    helper={}
    dummy=i[1][0].split('#')
    dummy0=dummy[0].split('[')[0].replace('\n',' ').replace('\n',' ').replace('\n',' ')
    helper['name']=dummy0
    helper['link']='https://en.wikipedia.org'+dummy[1]
    dummy=i[1][2].replace('\n',' ').replace('\n',' ').replace('\n',' ')
    if 'ummer since' in dummy:dummy='Permanent'
    dummy=dummy.split('[')[0]
    if 'emporary summer' in dummy:dummy='Summer'
    if 'intermittently Summer' in dummy:dummy='Summer'
    helper['type']=dummy
    dummy=i[1][3].split('#')[0].replace('\n',' |').replace(']','').replace('| |','|')[1:]
    if '' == dummy:dummy='Greenpeace'
    helper['country']=dummy
    dummy=i[1][4].replace('\n',' ').replace('\n',' ').replace('\n',' ').split(' ')[0]
    if 'eteo' in dummy:dummy='1958'
    helper['opened']=dummy
    dummy=i[1][5].split('#')[0].replace('\n',' | ').replace('| and |','|').split('[')[0].replace('.','')
    helper['program']=dummy
    dummy=i[1][6].split('#')[0].replace('\n',', ').replace('| and |','|').split('[')[0].replace('.','')
    helper['location']=dummy
    dummy=i[1][7].replace('\n',' ')
    if ' ' in dummy:
        if 'Active' in dummy: dummy='Active'
        elif 'Relocated to Union Glacier' in dummy: dummy='2014'
        elif 'Unmanned activity' in dummy: dummy='Active'
        elif 'Abandoned and lost' in dummy: dummy='1999'
        elif 'Dismantled 1992' in dummy: dummy='1992'
        elif 'Temporary abandoned since March 2017' in dummy: dummy='Active'
        elif 'Reopened 23 November 2017' in dummy: dummy='Active'
        elif 'Abandoned and lost' in dummy: dummy='1999'
        else: dummy=dummy.split(' ')[1]
    if dummy=='Active':
        helper['active']=True
        helper['closed']='9999'
    else:
        helper['active']=False
        helper['closed']=dummy
        if dummy=='Closed': 
            helper['active']=True
            helper['closed']='9999'
    dummy=i[1][8].replace('\n',', ').split('/')[2].split('(')[0].split('#')[0].split(',')[0].split('Coor')[0].split(u'\ufeff')[0].split(';')
    helper['latitude']=dummy[0][1:]
    helper['longitude']=dummy[1][1:]#.replace(' 0',' 0.001')[1:]
    
    stations.append(helper)

# %%
dta=pd.DataFrame(stations)
dta.to_excel('stations.xlsx')

# %%
import cesiumpy

# %%
dta
# Out:
#      active closed                   country    latitude  \
# 0      True   9999                   Finland  -73.042283
# 1     False   1957                     Chile  -62.933704
# 2      True   9999             United States         -90
# 3      True   9999                    Poland  -62.160140
# 4      True   9999               New Zealand  -77.830577
# 5      True   9999               New Zealand  -77.830016
# 6      True   9999                   Uruguay  -62.184444
# 7     False   2014                     Chile  -80.304170
# 8      True   9999                     Chile  -62.478889
# 9      True   9999                     Japan  -71.525950
# 10     True   9999                 Australia  -70.795115
# 11    False   1980                 Argentina     -77.767
# 12     True   9999                 Argentina  -77.873696
# 13    False   1984                 Argentina  -77.900556
# 14     True   9999                    Russia  -62.198591
# 15     True   9999                     India  -69.408030
# 16    False   1976              South Africa  -72.966667
# 17    False   1972             United States  -80.033333
# 18     True   9999                 Argentina  -64.895476
# 19    False   2005             United States   -80.01472
# 20     True   9999                 Argentina  -62.594847
# 21     True   9999                     Chile  -67.761201
# 22     True   9999                 Australia  -66.282514
# 23    False   1959                    France     -69.375
# 24     True   9999                     Chile  -62.169250
# 25     True   9999                    Brazil  -62.085379
# 26     True   9999            Italy | France  -75.099780
# 27    False   1990                     India  -69.406752
# 28     True   9999                   Germany  -62.238251
# 29     True   9999                 Australia  -68.576667
# ..      ...    ...                       ...         ...
# 132   False   1962            United Kingdom  -64.825276
# 133   False   1969            United Kingdom  -62.977231
# 134   False   1947            United Kingdom  -60.687642
# 135   False   1964            United Kingdom  -63.402478
# 136   False   1975            United Kingdom  -68.185678
# 137   False   1996            United Kingdom  -65.245791
# 138   False   1961            United Kingdom  -62.087217
# 139   False   1959            United Kingdom  -65.998516
# 140   False   1958            United Kingdom  -64.760032
# 141   False   1959            United Kingdom  -64.733333
# 142   False   1958            United Kingdom  -62.649306
# 143   False   1977            United Kingdom  -67.761201
# 144   False   1963            United Kingdom  -63.554392
# 145   False   1959            United Kingdom  -66.867006
# 146   False   1960            United Kingdom  -67.808285
# 147    True   9999                    Sweden  -74.583333
# 148    True   9999                     China  -73.863883
# 149    True   9999                    Norway  -71.889477
# 150    True   9999                    Norway  -72.011662
# 151    True   9999                     Chile   -79.76944
# 152    True   9999               New Zealand  -77.516667
# 153    True   9999                   Belarus  -67.659123
# 154    True   9999  Ukraine | United Kingdom  -65.245791
# 155    True   9999     Soviet Union | Russia  -78.463889
# 156   False   1957              Soviet Union  -72.133333
# 157    True   9999                    Sweden  -73.039901
# 158   False   1992    Russia | United States       -71.8
# 159   False   1992                Greenpeace    -77.6389
# 160    True   9999                     Chile   -64.87591
# 161    True   9999                     China  -69.373587
#
#                                                   link  \
# 0    https://en.wikipedia.org/wiki/Aboa_(research_s...
# 1    https://en.wikipedia.org/w/index.php?title=Agu...
# 2    https://en.wikipedia.org/wiki/Amundsen%E2%80%9...
# 3    https://en.wikipedia.org/wiki/Henryk_Arctowski...
# 4    https://en.wikipedia.org/w/index.php?title=Arr...
# 5    https://en.wikipedia.org/w/index.php?title=Arr...
# 6           https://en.wikipedia.org/wiki/Artigas_Base
# 7    https://en.wikipedia.org/wiki/Teniente_Arturo_...
# 8    https://en.wikipedia.org/wiki/Captain_Arturo_P...
# 9    https://en.wikipedia.org/wiki/Asuka_Station_(A...
# 10   https://en.wikipedia.org/w/index.php?title=Bea...
# 11       https://en.wikipedia.org/wiki/Belgrano_I_Base
# 12      https://en.wikipedia.org/wiki/Belgrano_II_Base
# 13     https://en.wikipedia.org/wiki/Belgrano_III_Base
# 14   https://en.wikipedia.org/wiki/Bellingshausen_S...
# 15   https://en.wikipedia.org/wiki/Bharati_(researc...
# 16   https://en.wikipedia.org/w/index.php?title=Bor...
# 17      https://en.wikipedia.org/wiki/Brockton_Station
# 18         https://en.wikipedia.org/wiki/Brown_Station
# 19          https://en.wikipedia.org/wiki/Byrd_Station
# 20      https://en.wikipedia.org/wiki/C%C3%A1mara_Base
# 21   https://en.wikipedia.org/wiki/Teniente_Luis_Ca...
# 22         https://en.wikipedia.org/wiki/Casey_Station
# 23   https://en.wikipedia.org/w/index.php?title=Cha...
# 24          https://en.wikipedia.org/wiki/Collins_Base
# 25   https://en.wikipedia.org/wiki/Comandante_Ferra...
# 26     https://en.wikipedia.org/wiki/Concordia_Station
# 27      https://en.wikipedia.org/wiki/Dakshin_Gangotri
# 28          https://en.wikipedia.org/wiki/Carlini_Base
# 29         https://en.wikipedia.org/wiki/Davis_Station
# ..                                                 ...
# 132         https://en.wikipedia.org/wiki/Port_Lockroy
# 133     https://en.wikipedia.org/wiki/Deception_Island
# 134          https://en.wikipedia.org/wiki/Cape_Geddes
# 135             https://en.wikipedia.org/wiki/Hope_Bay
# 136    https://en.wikipedia.org/wiki/Stonington_Island
# 137  https://en.wikipedia.org/wiki/Vernadsky_Resear...
# 138     https://en.wikipedia.org/wiki/Keller_Peninsula
# 139  https://en.wikipedia.org/wiki/Prospect_Point_(...
# 140       https://en.wikipedia.org/wiki/Arthur_Harbour
# 141         https://en.wikipedia.org/wiki/Danco_Island
# 142            https://en.wikipedia.org/wiki/Station_P
# 143  https://en.wikipedia.org/wiki/Teniente_Luis_Ca...
# 144           https://en.wikipedia.org/wiki/View_Point
# 145      https://en.wikipedia.org/wiki/Detaille_Island
# 146  https://en.wikipedia.org/wiki/Horseshoe_Island...
# 147  https://en.wikipedia.org/wiki/Svea_Research_St...
# 148  https://en.wikipedia.org/wiki/Antarctic_Taisha...
# 149  https://en.wikipedia.org/wiki/Tor_(research_st...
# 150  https://en.wikipedia.org/wiki/Troll_(research_...
# 151  https://en.wikipedia.org/wiki/Estaci%C3%B3n_Po...
# 152        https://en.wikipedia.org/wiki/Vanda_Station
# 153  https://en.wikipedia.org/w/index.php?title=Vec...
# 154  https://en.wikipedia.org/wiki/Vernadsky_Resear...
# 155       https://en.wikipedia.org/wiki/Vostok_Station
# 156  https://en.wikipedia.org/w/index.php?title=Vos...
# 157  https://en.wikipedia.org/wiki/Wasa_Research_St...
# 158  https://en.wikipedia.org/w/index.php?title=Wed...
# 159      https://en.wikipedia.org/wiki/World_Park_Base
# 160        https://en.wikipedia.org/wiki/Doumer_Island
# 161  https://en.wikipedia.org/wiki/Antarctic_Zhongs...
#
#                            location    longitude  \
# 0                   Queen Maud Land   -13.407350
# 1                  Deception Island  -60.5958931
# 2           Geographical South Pole            0
# 3                King George Island   -58.473247
# 4                       Ross Island   166.661174
# 5                       Ross Island   166.661659
# 6                King George Island   -58.903889
# 7                    Ellsworth Land  -81.3870573
# 8                  Greenwich Island   -59.664444
# 9                   Queen Maud Land    24.111409
# 10                      Beaver Lake    68.168909
# 11         Filchner-Ronne Ice Shelf      -38.183
# 12                       Coats Land   -34.627588
# 13                   Berkner Island   -45.783611
# 14               King George Island   -58.960547
# 15                  Larsemann Hills    76.187361
# 16                      Borg Massif         -3.8
# 17                   Ross Ice Shelf       -178.7
# 18                  Paradise Harbor   -62.870905
# 19                  Marie Byrd Land   -119.56556
# 20                 Half Moon Island   -59.918558
# 21                  Adelaide Island   -68.914365
# 22                    Vincennes Bay   110.526613
# 23                      Adélie Land   139.016667
# 24                 Fildes Peninsula   -58.851852
# 25               King George Island   -58.391513
# 26        Dome C, Antarctic Plateau   123.332196
# 27         Dakshin Gangotri Glacier    76.193379
# 28                  Carlini Station   -58.667764
# 29          Princess Elizabeth Land      77.9675
# ..                              ...          ...
# 132                  Goudier Island   -63.493688
# 133                Deception Island   -60.563809
# 134                     Cape Geddes   -44.573196
# 135                        Hope Bay   -56.990707
# 136               Stonington Island   -66.994815
# 137                 Galindez Island   -64.257786
# 138                   Admiralty Bay   -58.394049
# 139                  Prospect Point   -65.318273
# 140                   Anvers Island   -64.079991
# 141                    Danco Island   -62.600000
# 142                     Mateev Cove   -60.590278
# 143                 Adelaide Island   -68.914365
# 144                      View Point   -57.378279
# 145                 Detaille Island   -66.797971
# 146                Horseshoe Island   -67.294266
# 147                 Queen Maud Land   -11.216667
# 148         Princess Elizabeth Land    76.974717
# 149                 Queen Maud Land     5.159545
# 150                 Queen Maud Land     2.535138
# 151                   Union Glacier    -82.90722
# 152                   Victoria Land   161.666667
# 153  Mount Vechernyaya, Thala Hills    46.158125
# 154                 Galindez Island   -64.257786
# 155             Antarctic Ice Sheet    106.83757
# 156                 East Antarctica    96.583333
# 157                 Queen Maud Land   -13.398584
# 158                     Weddell Sea   -51.716667
# 159                      Cape Evans    -166.4139
# 160        South Bay, Doumer Island   -63.583721
# 161      Larsemann Hills, Prydz Bay    76.371652
#
#                                   name opened  \
# 0                                 Aboa   1989
# 1                        Aguirre Cerda   1955
# 2            Amundsen–Scott South Pole   1957
# 3                            Arctowski   1977
# 4           Arrival Heights Laboratory   1959
# 5    Arrival Heights Satellite Station   1959
# 6                              Artigas   1984
# 7                        Arturo Parodi   1999
# 8                          Arturo Prat   1947
# 9                                Asuka   1985
# 10                         Beaver Lake   1995
# 11                          Belgrano I   1955
# 12                         Belgrano II   1979
# 13                        Belgrano III   1980
# 14                      Bellingshausen   1968
# 15                             Bharati   2012
# 16                               Borga   1969
# 17                            Brockton   1965
# 18                               Brown   1951
# 19                                Byrd   1957
# 20                              Cámara   1953
# 21             Carvajal (ex Station T)   1984
# 22                               Casey   1957
# 23                             Charcot   1957
# 24                             Collins   2006
# 25                   Comandante Ferraz   1984
# 26                           Concordia   2005
# 27                    Dakshin Gangotri   1983
# 28                            Dallmann   1994
# 29                               Davis   1957
# ..                                 ...    ...
# 132                          Station A   1944
# 133                          Station B   1944
# 134                          Station C   1946
# 135                          Station D   1945
# 136                          Station E   1946
# 137                          Station F   1947
# 138                          Station G   1947
# 139                          Station J   1957
# 140                          Station N   1955
# 141                          Station O   1956
# 142                          Station P   1957
# 143                          Station T   1961
# 144                          Station V   1953
# 145                          Station W   1956
# 146                          Station Y   1955
# 147                               Svea   1988
# 148                            Taishan   2014
# 149                                Tor   1993
# 150                              Troll   1990
# 151                      Union Glacier   2014
# 152                              Vanda   1969
# 153                        Vechernyaya   2007
# 154           Vernadsky (ex Station F)   1994
# 155                             Vostok   1957
# 156                           Vostok I   1957
# 157                               Wasa   1989
# 158                          Weddell 1   1992
# 159                         World Park   1987
# 160                             Yelcho   1962
# 161                          Zhongshan   1989
#
#                                                program       type
# 0                   Finnish Antarctic Research Program     Summer
# 1                          Instituto Antártico Chileno     Summer
# 2                      United States Antarctic Program  Permanent
# 3                           Polish Academy of Sciences  Permanent
# 4                               Antarctica New Zealand  Permanent
# 5                               Antarctica New Zealand  Permanent
# 6                        Uruguayan Antarctic Institute  Permanent
# 7                          Instituto Antártico Chileno     Summer
# 8                                         Chilean Navy  Permanent
# 9                 National Institute of Polar Research     Summer
# 10                       Australian Antarctic Division     Summer
# 11                       Instituto Antártico Argentino  Permanent
# 12                       Instituto Antartico Argentino  Permanent
# 13                       Instituto Antártico Argentino  Permanent
# 14                        Russian Antarctic Expedition  Permanent
# 15                            Indian Antarctic Program  Permanent
# 16          South African National Antarctic Programme     Summer
# 17                                  United States Navy     Summer
# 18                       Instituto Antártico Argentino     Summer
# 19                     United States Antarctic Program  Permanent
# 20                       Instituto Antartico Argentino     Summer
# 21                         Instituto Antártico Chileno     Summer
# 22                       Australian Antarctic Division  Permanent
# 23                              French Polar Institute  Permanent
# 24                         Instituto Antártico Chileno     Summer
# 25                         Brazilian Antarctic Program  Permanent
# 26          National Antarctic Research Program | IPEV  Permanent
# 27                            Indian Antarctic Program  Permanent
# 28                            Alfred Wegener Institute     Summer
# 29                       Australian Antarctic Division  Permanent
# ..                                                 ...        ...
# 132                           British Antarctic Survey     Summer
# 133  Falkland Islands and Dependencies Aerial Surve...  Permanent
# 134                           British Antarctic Survey     Summer
# 135                           British Antarctic Survey  Permanent
# 136                           British Antarctic Survey  Permanent
# 137                           British Antarctic Survey  Permanent
# 138                           British Antarctic Survey  Permanent
# 139                           British Antarctic Survey  Permanent
# 140                           British Antarctic Survey  Permanent
# 141                           British Antarctic Survey  Permanent
# 142                           British Antarctic Survey     Summer
# 143                           British Antarctic Survey  Permanent
# 144                           British Antarctic Survey  Permanent
# 145                           British Antarctic Survey  Permanent
# 146                           British Antarctic Survey  Permanent
# 147                 Swedish Polar Research Secretariat     Summer
# 148                  Polar Research Institute of China     Summer
# 149                          Norwegian Polar Institute     Summer
# 150                          Norwegian Polar Institute  Permanent
# 151  Chilean Army | Chilean Navy | Chilean Air Forc...     Summer
# 152                             Antarctica New Zealand  Permanent
# 153            National Academy of Sciences of Belarus     Summer
# 154    National Antarctic Scientific Center of Ukraine  Permanent
# 155                       Russian Antarctic Expedition  Permanent
# 156                        Russian Academy of Sciences  Permanent
# 157                 Swedish Polar Research Secretariat     Summer
# 158  Russian Antarctic Expedition | National Scienc...     Summer
# 159                                         Greenpeace  Permanent
# 160                        Instituto Antártico Chileno     Summer
# 161                  Polar Research Institute of China  Permanent
#
# [162 rows x 11 columns]

# %%
iso2=pd.read_html('https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2')[2]

# %%
iso22=iso2[1:].set_index(1)[[0]]

# %%
def cc(c):
    d=c.split('|')[0].strip()
    if d=='Czech Republic': return 'CZ'
    elif d=='Greenpeace': return 'AQ'
    elif d=='Soviet Union': return 'RU'
    elif d=='Russia': return 'RU'
    elif d=='United States': return 'US'
    elif d=='East Germany': return 'DE'
    elif d=='United Kingdom': return 'GB'
    elif d=='South Korea': return 'KR'
    else: return iso22.loc[d][0]
flags=[]
for i in dta['country']:
    flags.append('flags/glass2/'+cc(i).lower()+'.png')

# %%
dta['flag']=flags

# %%
dta[['name','link','active','type']].to_excel('links.xlsx')

# %% [markdown]
# Manually filled pop.xlsx

# %%
pop=pd.read_excel('pop.xlsx')

# %%
dta['summer']=pop['summer']
dta['winter']=pop['winter']

# %%
dta.to_excel('alldata.xlsx')

# %%
dta.set_index('name').T.to_json('antarctica.json')

# %%
v = cesiumpy.Viewer(animation=False, baseLayerPicker=True, fullscreenButton=True,
               geocoder=False, homeButton=False, infoBox=True, sceneModePicker=True,
               selectionIndicator=True, navigationHelpButton=False,
               timeline=False, navigationInstructionsInitiallyVisible=True)
x=dta[dta['active']]
for i, row in x.iterrows():
    r=0.7
    t=10000
    lon=float(row['longitude'])
    lat=float(row['latitude'])
    l0 = float(1**r)*t
    cyl = cesiumpy.Cylinder(position=[lon, lat, l0/2.], length=l0,
                            topRadius=2.5e4, bottomRadius=2.5e4, material='grey',\
                            name=row['name'])
    v.entities.add(cyl)
    l1 = (float(row['summer'])**r)*t
    cyl = cesiumpy.Cylinder(position=[lon, lat, l1/2.], length=l1*1.1,
                            topRadius=3e4, bottomRadius=3e4, material='crimson',\
                            name=row['name'])
    v.entities.add(cyl)
    
    l2 = float(row['winter']**r)*t
    cyl = cesiumpy.Cylinder(position=[lon, lat, l2/2.], length=l2*1.2,
                            topRadius=6e4, bottomRadius=6e4, material='royalBlue',\
                            name=row['name'])
    v.entities.add(cyl)
    
    pin = cesiumpy.Pin.fromText(row['name'], color=cesiumpy.color.GREEN)
    b = cesiumpy.Billboard(position=[float(row['longitude']), float(row['latitude']), l1*1.1+70000], \
                           image = row['flag'], scale=0.6,\
                           name=row['name'], pixelOffset = (0,0))
    v.entities.add(b)
    label = cesiumpy.Label(position=[float(row['longitude']), float(row['latitude']), l1*1.1+70000],\
                           text=row['name'], scale=0.6, name=row['name'],
                           pixelOffset = (0,22))
    v.entities.add(label)
    
with codecs.open("index.html", "w", encoding="utf-8") as f:
    f.write(v.to_html())
v
# Out:
# <script src="https://cesiumjs.org/Cesium/Build/Cesium/Cesium.js"></script>
# <link rel="stylesheet" href="https://cesiumjs.org/Cesium/Build/Cesium/Widgets/widgets.css" type="text/css">
# <div id="container-583141192" style="width:100%; height:100%;"><div>
# <script type="text/javascript">
#   var widget = new Cesium.Viewer("container-583141192", {animation : false, baseLayerPicker : true, fullscreenButton : true, geocoder : false, homeButton : false, infoBox : true, sceneModePicker : true, selectionIndicator : true, timeline : false, navigationHelpButton : false, navigationInstructionsInitiallyVisible : true});
#   widget.entities.add({name : "Aboa", position : Cesium.Cartesian3.fromDegrees(-13.40735, -73.042283, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Aboa", position : Cesium.Cartesian3.fromDegrees(-13.40735, -73.042283, 28470.6168376), cylinder : {length : 62635.3570427, topRadius : 30000.0, bottomRadius : 30000.0, material : Cesium.Color.CRIMSON}});
#   widget.entities.add({name : "Aboa", position : Cesium.Cartesian3.fromDegrees(-13.40735, -73.042283, 0.0), cylinder : {length : 0.0, topRadius : 60000.0, bottomRadius : 60000.0, material : Cesium.Color.ROYALBLUE}});
#   widget.entities.add({name : "Aboa", position : Cesium.Cartesian3.fromDegrees(-13.40735, -73.042283, 132635.357043), billboard : {image : "flags/glass2/fi.png", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 0.0)}});
#   widget.entities.add({name : "Aboa", position : Cesium.Cartesian3.fromDegrees(-13.40735, -73.042283, 132635.357043), label : {text : "Aboa", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 22.0)}});
#   widget.entities.add({name : "Amundsen–Scott South Pole", position : Cesium.Cartesian3.fromDegrees(0.0, -90.0, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Amundsen–Scott South Pole", position : Cesium.Cartesian3.fromDegrees(0.0, -90.0, 166814.533646), cylinder : {length : 366991.974022, topRadius : 30000.0, bottomRadius : 30000.0, material : Cesium.Color.CRIMSON}});
#   widget.entities.add({name : "Amundsen–Scott South Pole", position : Cesium.Cartesian3.fromDegrees(0.0, -90.0, 71815.5951613), cylinder : {length : 172357.428387, topRadius : 60000.0, bottomRadius : 60000.0, material : Cesium.Color.ROYALBLUE}});
#   widget.entities.add({name : "Amundsen–Scott South Pole", position : Cesium.Cartesian3.fromDegrees(0.0, -90.0, 436991.974022), billboard : {image : "flags/glass2/us.png", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 0.0)}});
#   widget.entities.add({name : "Amundsen–Scott South Pole", position : Cesium.Cartesian3.fromDegrees(0.0, -90.0, 436991.974022), label : {text : "Amundsen–Scott South Pole", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 22.0)}});
#   widget.entities.add({name : "Arctowski", position : Cesium.Cartesian3.fromDegrees(-58.473247, -62.16014, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Arctowski", position : Cesium.Cartesian3.fromDegrees(-58.473247, -62.16014, 71815.5951613), cylinder : {length : 157994.309355, topRadius : 30000.0, bottomRadius : 30000.0, material : Cesium.Color.CRIMSON}});
#   widget.entities.add({name : "Arctowski", position : Cesium.Cartesian3.fromDegrees(-58.473247, -62.16014, 23277.6836087), cylinder : {length : 55866.440661, topRadius : 60000.0, bottomRadius : 60000.0, material : Cesium.Color.ROYALBLUE}});
#   widget.entities.add({name : "Arctowski", position : Cesium.Cartesian3.fromDegrees(-58.473247, -62.16014, 227994.309355), billboard : {image : "flags/glass2/pl.png", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 0.0)}});
#   widget.entities.add({name : "Arctowski", position : Cesium.Cartesian3.fromDegrees(-58.473247, -62.16014, 227994.309355), label : {text : "Arctowski", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 22.0)}});
#   widget.entities.add({name : "Arrival Heights Laboratory", position : Cesium.Cartesian3.fromDegrees(166.661174, -77.830577, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Arrival Heights Laboratory", position : Cesium.Cartesian3.fromDegrees(166.661174, -77.830577, 0.0), cylinder : {length : 0.0, topRadius : 30000.0, bottomRadius : 30000.0, material : Cesium.Color.CRIMSON}});
#   widget.entities.add({name : "Arrival Heights Laboratory", position : Cesium.Cartesian3.fromDegrees(166.661174, -77.830577, 0.0), cylinder : {length : 0.0, topRadius : 60000.0, bottomRadius : 60000.0, material : Cesium.Color.ROYALBLUE}});
#   widget.entities.add({name : "Arrival Heights Laboratory", position : Cesium.Cartesian3.fromDegrees(166.661174, -77.830577, 70000.0), billboard : {image : "flags/glass2/nz.png", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 0.0)}});
#   widget.entities.add({name : "Arrival Heights Laboratory", position : Cesium.Cartesian3.fromDegrees(166.661174, -77.830577, 70000.0), label : {text : "Arrival Heights Laboratory", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 22.0)}});
#   widget.entities.add({name : "Arrival Heights Satellite Station", position : Cesium.Cartesian3.fromDegrees(166.661659, -77.830016, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Arrival Heights Satellite Station", position : Cesium.Cartesian3.fromDegrees(166.661659, -77.830016, 0.0), cylinder : {length : 0.0, topRadius : 30000.0, bottomRadius : 30000.0, material : Cesium.Color.CRIMSON}});
#   widget.entities.add({name : "Arrival Heights Satellite Station", position : Cesium.Cartesian3.fromDegrees(166.661659, -77.830016, 0.0), cylinder : {length : 0.0, topRadius : 60000.0, bottomRadius : 60000.0, material : Cesium.Color.ROYALBLUE}});
#   widget.entities.add({name : "Arrival Heights Satellite Station", position : Cesium.Cartesian3.fromDegrees(166.661659, -77.830016, 70000.0), billboard : {image : "flags/glass2/nz.png", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 0.0)}});
#   widget.entities.add({name : "Arrival Heights Satellite Station", position : Cesium.Cartesian3.fromDegrees(166.661659, -77.830016, 70000.0), label : {text : "Arrival Heights Satellite Station", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 22.0)}});
#   widget.entities.add({name : "Artigas", position : Cesium.Cartesian3.fromDegrees(-58.903889, -62.184444, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Artigas", position : Cesium.Cartesian3.fromDegrees(-58.903889, -62.184444, 87836.6734066), cylinder : {length : 193240.681494, topRadius : 30000.0, bottomRadius : 30000.0, material : Cesium.Color.CRIMSON}});
#   widget.entities.add({name : "Artigas", position : Cesium.Cartesian3.fromDegrees(-58.903889, -62.184444, 23277.6836087), cylinder : {length : 55866.440661, topRadius : 60000.0, bottomRadius : 60000.0, material : Cesium.Color.ROYALBLUE}});
#   widget.entities.add({name : "Artigas", position : Cesium.Cartesian3.fromDegrees(-58.903889, -62.184444, 263240.681494), billboard : {image : "flags/glass2/uy.png", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 0.0)}});
#   widget.entities.add({name : "Artigas", position : Cesium.Cartesian3.fromDegrees(-58.903889, -62.184444, 263240.681494), label : {text : "Artigas", scale : 0.6, pixelOffset : new Cesium.Cartesian2(0.0, 22.0)}});
#   widget.entities.add({name : "Arturo Prat", position : Cesium.Cartesian3.fromDegrees(-59.664444, -62.478889, 5000.0), cylinder : {length : 10000.0, topRadius : 25000.0, bottomRadius : 25000.0, material : Cesium.Color.GREY}});
#   widget.entities.add({name : "Arturo Prat", position : Cesium.Cartesian3.fromDegrees(-59.664444, -62.478889, 21435.
